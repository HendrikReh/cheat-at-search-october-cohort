# %% [markdown]
# # Query -> Category
#
# <small>
# (from <a href="http://maven.com/softwaredoug/cheat-at-search">Cheat at Search with LLMs</a> training course by Doug Turnbull.)
# </small>
#
# **Refinement** -- Use the -full list- of classifications, and allow a list to be returned
#
# We learned that we want to try to model aspects of the user's _information need_ not just make queries better.
#
# One such common dimension is query -> category classification

# %% [markdown]
# ## Boilerplate
#
# Install deps, mount GDrive, prompt for your OpenAI Key (placed in your GDrive)

# %%
# !pip install git+https://github.com/softwaredoug/cheat-at-search.git
from cheat_at_search.data_dir import mount
mount(use_gdrive=True)
# Out:
# Collecting git+https://github.com/softwaredoug/cheat-at-search.git
#   Cloning https://github.com/softwaredoug/cheat-at-search.git to /tmp/pip-req-build-k0s64jok
#   Running command git clone --filter=blob:none --quiet https://github.com/softwaredoug/cheat-at-search.git /tmp/pip-req-build-k0s64jok
#   Resolved https://github.com/softwaredoug/cheat-at-search.git to commit 7fbf2bf2845343912918f337a29127f9edc50bd2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-genai<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.31.0)
# Requirement already satisfied: openai<2.0.0,>=1.84.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.101.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.2.2)
# Collecting pyarrow<22.0.0,>=21.0.0 (from cheat_at_search==0.1.0)
#   Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.11.7)
# Collecting pystemmer<4.0.0,>=3.0.0 (from cheat_at_search==0.1.0)
#   Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting searcharray<0.0.73,>=0.0.72 (from cheat_at_search==0.1.0)
#   Downloading searcharray-0.0.72-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.4.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from searcharray<0.0.73,>=0.0.72->cheat_at_search==0.1.0) (3.0.12)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.6.1)
# Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 19.1 MB/s eta 0:00:00
# Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (745 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.3/745.3 kB 43.0 MB/s eta 0:00:00
# Downloading searcharray-0.0.72-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 60.3 MB/s eta 0:00:00
# Building wheels for collected packages: cheat_at_search
#   Building wheel for cheat_at_search (pyproject.toml) ... done
#   Created wheel for cheat_at_search: filename=cheat_at_search-0.1.0-py3-none-any.whl size=28125 sha256=d79ddefa4e5881651692ac6a334752165c4fd3a5b606f8abee953f566b5d58ce
#   Stored in directory: /tmp/pip-ephem-wheel-cache-275btbf_/wheels/ea/96/d3/e69453e5f86e6f891864e5b5baf2b11ffda2d0981d9f8a138e
# Successfully built cheat_at_search
# Installing collected packages: pystemmer, pyarrow, searcharray, cheat_at_search
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# Successfully installed cheat_at_search-0.1.0 pyarrow-21.0.0 pystemmer-3.0.0 searcharray-0.0.72
# Mounted at /content/drive
# 2025-08-31 21:07:04,795 - data_dir - INFO - Mounting data directory at /content/drive/MyDrive/cheat-at-search-data/
# INFO:data_dir:Mounting data directory at /content/drive/MyDrive/cheat-at-search-data/

# %% [markdown]
# ## Import helpers
#
# Helpers to compute ndcg of each query and other comparison functions

# %%
from cheat_at_search.data_dir import ensure_data_subdir
from cheat_at_search.search import run_strategy, graded_bm25, ndcgs, ndcg_delta, vs_ideal
# Out:
# 2025-08-31 21:07:05,507 - data_dir - INFO - Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# INFO:data_dir:Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# 2025-08-31 21:07:27,697 - data_dir - INFO - Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# INFO:data_dir:Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# 2025-08-31 21:07:30,270 - data_dir - INFO - Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# INFO:data_dir:Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# 2025-08-31 21:07:34,828 - data_dir - INFO - Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# INFO:data_dir:Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# 2025-08-31 21:07:34,838 - data_dir - INFO - Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# INFO:data_dir:Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# 2025-08-31 21:07:36,235 - data_dir - INFO - Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# INFO:data_dir:Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched

# %% [markdown]
# ## Import WANDS data
#
# Import [Wayfair Annotated Dataset](https://github.com/wayfair/WANDS) a labeled furniture e-commerce dataset

# %%
from cheat_at_search.wands_data import products

products
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features             category  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...           Furniture
# 1      [capacityquarts:7, producttype : slow cooker, ...  Kitchen & Tabletop
# 2      [features : keep warm setting, capacityquarts:...  Kitchen & Tabletop
# 3      [overallwidth-sidetoside:3.5, warrantylength :...     Browse By Brand
# 4      [compatibledoorthickness:1.375 '' , countryofo...    Home Improvement
# ...                                                  ...                  ...
# 42989  [producttype : shower panel, spraypattern : ra...    Home Improvement
# 42990  [basematerialdetails : steel,  : gray wood, of...           Furniture
# 42991  [additionaltoolsrequirednotincluded : power dr...           Furniture
# 42992  [legmaterialdetails : rubberwood, backheight-s...           Furniture
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...           Furniture
#
#                                  sub_category  \
# 0                          Bedroom Furniture
# 1                   Small Kitchen Appliances
# 2                   Small Kitchen Appliances
# 3                                    All-Clad
# 4                      Doors & Door Hardware
# ...                                       ...
# 42989   Bathroom Remodel & Bathroom Fixtures
# 42990             Kitchen & Dining Furniture
# 42991             Kitchen & Dining Furniture
# 42992                  Living Room Furniture
# 42993             Kitchen & Dining Furniture
#
#                                               cat_subcat
# 0                       Furniture  /  Bedroom Furniture
# 1       Kitchen & Tabletop  /  Small Kitchen Appliances
# 2       Kitchen & Tabletop  /  Small Kitchen Appliances
# 3                           Browse By Brand  /  All-Clad
# 4            Home Improvement  /  Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement  /  Bathroom Remodel & Bathro...
# 42990          Furniture  /  Kitchen & Dining Furniture
# 42991          Furniture  /  Kitchen & Dining Furniture
# 42992               Furniture  /  Living Room Furniture
# 42993          Furniture  /  Kitchen & Dining Furniture
#
# [42994 rows x 13 columns]

# %% [markdown]
# ## Query -> Full classification
#
# We'll first setup the model of query -> category and subcategory. We've precurated categories / subcategories for you to help.

# %%
from pydantic import BaseModel, Field
from typing import List, Literal
from cheat_at_search.enrich import AutoEnricher

from typing import Literal, get_args
FullyQualifiedClassifications = Literal[
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs',
 'Rugs / Area Rugs',
 'Furniture / Office Furniture / Desks',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows',
 'Furniture / Bedroom Furniture / Dressers & Chests',
 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities',
 'Furniture / Living Room Furniture / Console Tables',
 'Décor & Pillows / Art / All Wall Art',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs',
 'Furniture / Office Furniture / Office Chairs',
 'Décor & Pillows / Mirrors / All Mirrors',
 'Bed & Bath / Bedding / All Bedding',
 'Décor & Pillows / Wall Décor / Wall Accents',
 'Furniture / Living Room Furniture / Chairs & Seating / Recliners',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen and Dining Sets',
 'Décor & Pillows / Window Treatments / Curtains & Drapes',
 'Furniture / Living Room Furniture / Sectionals',
 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / TV Stands & Entertainment Centers',
 'Lighting / Ceiling Lights / Chandeliers',
 'Furniture / Bedroom Furniture / Nightstands',
 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Desks',
 'Décor & Pillows / Home Accessories / Decorative Objects',
 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards',
 'Furniture / Living Room Furniture / Sofas',
 'Furniture / Living Room Furniture / Cabinets & Chests',
 'Décor & Pillows / Clocks / Wall Clocks',
 'Storage & Organization / Bathroom Storage & Organization / Bathroom Cabinets & Shelving',
 'Lighting / Table & Floor Lamps / Table Lamps',
 'Furniture / Living Room Furniture / Ottomans & Poufs',
 'Furniture / Kitchen & Dining Furniture / Kitchen Islands & Carts',
 'Furniture / Living Room Furniture / Bookcases',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals',
 'Furniture / Office Furniture / Office Storage Cabinets',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables',
 'Contractor / Entry & Hallway / Coat Racks & Umbrella Stands',
 'Bed & Bath / Bedding Essentials / Mattress Pads & Toppers',
 'Home Improvement / Hardware / Home Hardware / Switch Plates',
 'Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Patio Furniture Covers',
 'Rugs / Doormats',
 'Rugs / Kitchen Mats',
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds',
 'Furniture / Bedroom Furniture / Daybeds',
 'Furniture / Living Room Furniture / Living Room Sets',
 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets',
 'Outdoor / Outdoor Décor / Statues & Sculptures',
 'Décor & Pillows / Art / All Wall Art / Green Wall Art',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets',
 'Furniture / Living Room Furniture / Chairs & Seating / Chaise Lounge Chairs',
 'Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables',
 'Décor & Pillows / Art / All Wall Art / Brown Wall Art',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools / Counter (24-27) Bar Stools & Counter Stools',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables',
 'Décor & Pillows / Window Treatments / Curtain Hardware & Accessories',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs / Side Kitchen & Dining Chairs',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs',
 'Furniture / Living Room Furniture / Chairs & Seating / Benches',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks',
 'Kitchen & Tabletop / Kitchen Organization / Food Pantries',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Deck Boxes & Patio Storage',
 'Outdoor / Garden / Planters',
 'Lighting / Wall Lights / Bathroom Vanity Lighting',
 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Bronze Cabinet & Drawer Pulls',
 'Storage & Organization / Storage Containers & Drawers / All Storage Containers',
 'Bed & Bath / Shower Curtains & Accessories / Shower Curtains & Shower Liners',
 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets',
 'Lighting / Light Bulbs & Hardware / Light Bulbs / All Light Bulbs / LED Light Bulbs',
 'Décor & Pillows / Art / All Wall Art / Blue Wall Art',
 'Bed & Bath / Mattresses & Foundations / Innerspring Mattresses',
 'Lighting / Outdoor Lighting / Outdoor Wall Lighting',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Natural Material Storage / Log Storage',
 'Bed & Bath / Bathroom Accessories & Organization / Countertop Bath Accessories',
 'Storage & Organization / Shoe Storage / All Shoe Storage',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Ceramic Floor Tiles & Wall Tiles',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls',
 'Bed & Bath / Mattresses & Foundations / Adjustable Beds',
 "Rugs / Area Rugs / 2' x 3' Area Rugs",
 'Commercial Business Furniture / Commercial Office Furniture / Office Storage & Filing / Office Carts & Stands / All Carts & Stands',
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets',
 "Rugs / Area Rugs / 4' x 6' Area Rugs",
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets',
 'Kitchen & Tabletop / Tableware & Drinkware / Table & Kitchen Linens / All Table Linens',
 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers',
 'Décor & Pillows / Flowers & Plants / Faux Flowers',
 'Bed & Bath / Bedding / All Bedding / Twin Bedding',
 'Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Porcelain Floor Tiles & Wall Tiles',
 'Home Improvement / Flooring, Walls & Ceiling / Flooring Installation & Accessories / Molding & Millwork / Wall Molding & Millwork',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Barn Door Hardware',
 'Bed & Bath / Bedding / Sheets & Pillowcases',
 'Furniture / Office Furniture / Chair Mats / Hard Floor Chair Mats',
 'Outdoor / Outdoor Fencing & Flooring / All Fencing',
 'Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks',
 'Kitchen & Tabletop / Kitchen Utensils & Tools / Colanders, Strainers, & Salad Spinners',
 'Outdoor / Hot Tubs & Saunas / Saunas',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Blue Throw Pillows',
 'Bed & Bath / Bedding Essentials / Bed Pillows',
 'Lighting / Wall Lights / Wall Sconces',
 'Outdoor / Front Door Décor & Curb Appeal / Mailboxes',
 'Outdoor / Garden / Greenhouses',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Faucets & Systems',
 'Bed & Bath / Mattresses & Foundations / Queen Mattresses',
 'Furniture / Bedroom Furniture / Jewelry Armoires',
 'Outdoor / Outdoor Shades / Awnings',
 'Baby & Kids / Nursery Bedding / Crib Bedding Sets',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Brass Cabinet & Drawer Knobs',
 'Décor & Pillows / Art / All Wall Art / Red Wall Art',
 'Lighting / Ceiling Lights / All Ceiling Lights',
 'Lighting / Light Bulbs & Hardware / Lighting Components',
 'Furniture / Game Tables & Game Room Furniture / Poker & Card Tables',
 'Appliances / Kitchen Appliances / Range Hoods / All Range Hoods',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools / Bar (28-33) Bar Stools & Counter Stools',
 'Outdoor / Outdoor Cooking & Tableware / Outdoor Serving & Tableware / Coolers, Baskets & Tubs / Picnic Baskets & Backpacks',
 'Décor & Pillows / Picture Frames & Albums / All Picture Frames',
 'Bed & Bath / Shower Curtains & Accessories / Shower Curtain Hooks',
 'Outdoor / Outdoor Shades / Outdoor Umbrellas / Patio Umbrella Stands & Bases',
 'Outdoor / Outdoor & Patio Furniture / Patio Bar Furniture / Patio Bar Stools',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Toilets & Bidets / Toilet Paper Holders / Free Standing Toilet Paper Holders',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Bike & Sport Racks',
 'Appliances / Kitchen Appliances / Refrigerators & Freezers / All Refrigerators / French Door Refrigerators',
 'Décor & Pillows / Home Accessories / Decorative Trays',
 'School Furniture and Supplies / School Spaces / Computer Lab Furniture / Podiums & Lecterns',
 'Lighting / Light Bulbs & Hardware / Lighting Shades',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Home Bars & Bar Sets',
 'Lighting / Table & Floor Lamps / Floor Lamps',
 'Décor & Pillows / Wall Décor / Wall Accents / Brown Wall Accents',
 'Kitchen & Tabletop / Small Kitchen Appliances / Pressure & Slow Cookers / Slow Cookers / Slow Slow Cookers',
 'Décor & Pillows / Window Treatments / Curtains & Drapes / 90 Inch Curtains & Drapes',
 'Furniture / Bedroom Furniture / Armoires & Wardrobes',
 'Kitchen & Tabletop / Tableware & Drinkware / Flatware & Cutlery / Serving Utensils',
 'Baby & Kids / Baby & Kids Décor & Lighting / All Baby & Kids Wall Art',
 'Furniture / Office Furniture / Desks / Writing Desks',
 'Furniture / Office Furniture / Office Chairs / Task Office Chairs',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Shower & Bathtub Doors',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Rocking Chairs & Gliders',
 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Wall Paneling',
 'Outdoor / Garden / Plant Stands & Accessories',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables / 4 Seat Kitchen & Dining Tables',
 'Décor & Pillows / Home Accessories / Vases, Urns, Jars & Bottles',
 'Lighting / Wall Lights / Under Cabinet Lighting / Strip Under Cabinet Lighting',
 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities',
 'Pet / Dog / Dog Bowls & Feeding Supplies / Pet Bowls & Feeders',
 'Décor & Pillows / Candles & Holders / Candle Holders',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Shower & Bathtub Accessories',
 'Furniture / Office Furniture / Office Chair Accessories / Seat Cushion Office Chair Accessories',
 'Furniture / Office Furniture / Chair Mats',
 'Furniture / Living Room Furniture / Chairs & Seating / Massage Chairs',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities / Modern & Contemporary Bathroom Vanities',
 'Lighting / Ceiling Fans / All Ceiling Fans',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Black Kitchen Faucets',
 'Lighting / Light Bulbs & Hardware / Light Bulbs / All Light Bulbs / Incandescent Light Bulbs',
 'Home Improvement / Flooring, Walls & Ceiling / Flooring Installation & Accessories / Molding & Millwork',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Bathtubs',
 'Décor & Pillows / Art / All Wall Art / Yellow Wall Art',
 'Pet / Dog / Pet Gates, Fences & Doors / Pet Gates',
 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel Bars, Racks, and Stands / Metal Towel Bars, Racks, and Stands',
 'Décor & Pillows / Art / All Wall Art / Pink Wall Art',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Smoke Detectors / Wall & Ceiling Mounted Smoke Detectors',
 'Outdoor / Garden / Planters / Plastic Planters',
 'Décor & Pillows / Mirrors / All Mirrors / Accent Mirrors',
 'Appliances / Kitchen Appliances / Range Hoods / All Range Hoods / Wall Mount Range Hoods',
 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Round Coffee Tables',
 'Kitchen & Tabletop / Tableware & Drinkware / Dinnerware / Dining Bowls',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads / Dual Shower Heads',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Glass Floor Tiles & Wall Tiles',
 'School Furniture and Supplies / Facilities & Maintenance / Trash & Recycling',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Nickel Cabinet & Drawer Pulls',
 'Storage & Organization / Closet Storage & Organization / Closet Systems',
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds',
 'Commercial Business Furniture / Commercial Office Furniture / Office Storage & Filing / Office Carts & Stands / All Carts & Stands / Printer Carts & Stands',
 'Storage & Organization / Closet Storage & Organization / Closet Accessories',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities / Traditional Bathroom Vanities',
 'Home Improvement / Plumbing / Core Plumbing / Parts & Components',
 'Holiday Décor / Christmas / Christmas Trees / All Christmas Trees',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Black Throw Pillows',
 'Furniture / Game Tables & Game Room Furniture / Sports Team Fan Shop & Memorabillia / Life Size Cutouts',
 'Lighting / Ceiling Lights / Pendant Lighting',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks',
 'Appliances / Washers & Dryers / Dryers / All Dryers / Gas Dryers',
 'Outdoor / Outdoor Recreation / Backyard Play / Kids Cars & Ride-On Toys',
 'Kitchen & Tabletop / Small Kitchen Appliances / Coffee, Espresso, & Tea / Coffee Makers',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals / Sectional Patio Sofas & Sectionals',
 'Lighting / Wall Lights / Under Cabinet Lighting',
 'Foodservice / Foodservice Tables / Table Parts',
 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting / Fence Post Cap Landscape Lighting',
 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables',
 'Commercial Business Furniture / Commercial Office Furniture / Office Storage & Filing / Office Carts & Stands / All Carts & Stands / Utility Carts & Stands',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs',
 'Furniture / Living Room Furniture / Chairs & Seating / Recliners / Brown Recliners',
 'Pet / Bird / Bird Perches & Play Gyms',
 'Décor & Pillows / Picture Frames & Albums / All Picture Frames / Single Picture Picture Frames',
 'Lighting / Outdoor Lighting / Outdoor Lanterns & Lamps',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls',
 'Bed Accessories',
 'Clips/Clamps',
 'Décor & Pillows / Wall Décor / Wall Decals',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles',
 'Bed & Bath / Bedding / Sheets & Pillowcases / Twin XL Sheets & Pillowcases',
 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters',
 'Holiday Décor / Holiday Lighting',
 'Décor & Pillows / Wall Décor / Memo Boards',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Toilets & Bidets / Toilet Paper Holders / Wall Mounted Toilet Paper Holders',
 'Décor & Pillows / Window Treatments / Curtains & Drapes / 63 Inch and Less Curtains & Drapes',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Knobs / Egg Door Knobs',
 'Décor & Pillows / Clocks / Wall Clocks / Analog Wall Clocks',
 'Home Improvement / Doors & Door Hardware / Interior Doors / Sliding Interior Doors',
 'Outdoor / Outdoor Recreation / Outdoor Games / All Outdoor Games',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Levers / Round Door Levers',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Sheds / Storage Sheds',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Levers',
 'School Furniture and Supplies / School Furniture / School Tables / Folding Tables / Wood Folding Tables',
 'Décor & Pillows / Wall Décor / Wall Accents / Green Wall Accents',
 'School Furniture and Supplies / Facilities & Maintenance / Commercial Signage',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Garage Storage Cabinets',
 'Furniture / Bedroom Furniture / Dressers & Chests / Beige Dressers & Chests',
 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves',
 'Furniture / Game Tables & Game Room Furniture / Dartboards & Cabinets',
 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions',
 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets / Two Person Patio Dining Sets',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Ivory & Cream Throw Pillows',
 'Appliances / Washers & Dryers / Washer & Dryer Sets / Black Washer & Dryer Sets',
 'School Furniture and Supplies / School Furniture / School Chairs & Seating / Stackable Chairs',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Brass Cabinet & Drawer Pulls',
 'School Furniture and Supplies / School Boards & Technology / AV, Mounts & Tech Accessories / Electronic Mounts & Stands / Computer Mounts',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Papasan Accent Chairs',
 'Storage & Organization / Shoe Storage / All Shoe Storage / Rack Shoe Storage',
 'Storage & Organization / Shoe Storage / All Shoe Storage / Cabinet Shoe Storage',
 'Storage & Organization / Storage Containers & Drawers / Storage Drawers',
 'Appliances / Kitchen Appliances / Wine & Beverage Coolers / Water Coolers',
 'Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs',
 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Bowls & Baskets / Serving Bowls / NA Serving Bowls',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Inflatable Projection Screens',
 'Appliances / Kitchen Appliances / Large Appliance Parts & Accessories',
 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets / Laundry Hampers & Laundry Baskets',
 'Furniture / Office Furniture / Office Stools',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs / Metal Outdoor Club Chairs',
 'School Furniture and Supplies / School Furniture / School Tables / Folding Tables',
 'Lighting / Wall Lights / Bathroom Vanity Lighting / Traditional Bathroom Vanity Lighting',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Centerset Bathroom Sink Faucets',
 'Décor & Pillows / Flowers & Plants / Faux Flowers / Orchid Faux Flowers',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Metal Floor Tiles & Wall Tiles',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Grill Covers / Charcoal Grill Grill Covers',
 'Outdoor / Outdoor Décor / Outdoor Wall Décor',
 'Storage & Organization / Cleaning & Laundry Organization / Laundry Room Organizers',
 'Reception Area / Reception Seating / Reception Sofas & Loveseats',
 'Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans / Steel Bread & Loaf Pans',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Wingback Accent Chairs',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads / Fixed Shower Heads',
 'Kitchen & Tabletop / Kitchen Utensils & Tools / Kitchen Gadgets / Pasta Makers & Accessories',
 'School Furniture and Supplies / School Furniture / School Chairs & Seating / Classroom Chairs / High School & College Classroom Chairs',
 'Furniture / Living Room Furniture / Sectionals / Stationary Sectionals',
 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets / Drawer Equipped Sideboards & Buffets',
 'Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans',
 'Kitchen & Tabletop / Kitchen Utensils & Tools / Cooking Utensils / All Cooking Utensils / Kitchen Cooking Utensils',
 'Décor & Pillows / Flowers & Plants / Live Plants',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Folding Frame Projection Screens',
 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars',
 'Outdoor / Outdoor Décor / Outdoor Fountains',
 'Outdoor / Outdoor Shades / Pergolas / Wood Pergolas',
 'Décor & Pillows / Candles & Holders / Candle Holders / Sconce Candle Holders',
 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Cake & Tiered Stands',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Chrome Kitchen Faucets',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / White Throw Pillows',
 'Outdoor / Outdoor Fencing & Flooring / Turf',
 'Décor & Pillows / Window Treatments / Valances & Kitchen Curtains',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Bronze Kitchen Faucets',
 'Appliances / Washers & Dryers / Washer & Dryer Sets',
 'Décor & Pillows / Clocks / Mantel & Tabletop Clocks',
 'Home Improvement / Doors & Door Hardware / Interior Doors',
 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves / Floating Wall & Display Shelves',
 'Outdoor / Outdoor Recreation / Backyard Play / Climbing Toys & Slides',
 'Home Improvement / Building Equipment / Dollies / Hand Truck Dollies',
 'Baby & Kids / Toddler & Kids Bedroom Furniture / Baby & Kids Dressers',
 'Décor & Pillows / Mirrors / All Mirrors / Leaning & Floor Mirrors',
 'Kitchen & Tabletop / Tableware & Drinkware / Drinkware / Mugs & Teacups',
 'Décor & Pillows / Flowers & Plants / Wreaths',
 'Outdoor / Outdoor Shades / Pergolas / Metal Pergolas',
 'Bed & Bath / Bedding / Sheets & Pillowcases / Twin Sheets & Pillowcases',
 'Outdoor / Outdoor Shades / Pergolas',
 'Reception Area / Reception Seating / Office Sofas & Loveseats',
 'Décor & Pillows / Home Accessories / Indoor Fountains',
 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Ceramic Kitchen Canisters & Jars',
 'Décor & Pillows / Window Treatments / Curtain Hardware & Accessories / Bracket Curtain Hardware & Accessories',
 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Accent Tiles / Ceramic Accent Tiles',
 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Accent Tiles',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Arm Accent Chairs',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Free Form Coffee Tables',
 'Décor & Pillows / Flowers & Plants / Faux Flowers / Rose Faux Flowers',
 'Bed & Bath / Mattresses & Foundations / Innerspring Mattresses / Twin Innerspring Mattresses',
 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Dining Chair Patio Furniture Cushions',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / TV Stands & Entertainment Centers / Traditional TV Stands & Entertainment Centers',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables / Square Plant Stands & Tables',
 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves / Corner Wall & Display Shelves',
 "Rugs / Area Rugs / 3' x 5' Area Rugs",
 'Kitchen & Tabletop / Tableware & Drinkware / Drinkware / Mugs & Teacups / Coffee Mugs & Teacups',
 'Contractor / Entry & Hallway / Coat Racks & Umbrella Stands / Wall Mounted Coat Racks & Umbrella Stands',
 "Baby & Kids / Toddler & Kids Playroom / Indoor Play / Kids' Playhouses",
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Square Coffee Tables',
 'Baby & Kids / Toddler & Kids Playroom / Indoor Play / Dollhouses & Accessories',
 'Bed & Bath / Bedding / All Bedding / Queen Bedding',
 'No Classification Fits'
]

classifications_list = sorted(get_args(FullyQualifiedClassifications))

known_categories = set([c.split(" / ")[0].strip() for c in classifications_list])
known_sub_categories = set([c.split(" / ")[1].strip() for c in classifications_list if len(c.split(" / ")) > 1])

known_sub_categories


class Query(BaseModel):
    """
    Base model for search queries, containing common query attributes.
    """
    keywords: str = Field(
        ...,
        description="The original search query keywords sent in as input"
    )


class QueryClassification(Query):
    """
    Structured representation of a search query for furniture e-commerce.
    Inherits keywords from the base Query model and adds category and sub-category.
    """
    classifications: list[FullyQualifiedClassifications] = Field(
        description="A possible classification for the product."
    )

    @property
    def categories(self):
        return set([c.split(" / ")[0] for c in self.classifications])

    @property
    def sub_categories(self):
        return set([c.split(" / ")[1] for c in self.classifications if len(c.split(" / ")) > 1])

# %% [markdown]
# ### Query classification code

# %%
enricher = AutoEnricher(
     model="openai/gpt-4o",
     system_prompt="You are a helpful furniture shopping agent that helps users construct search queries.",
     response_model=QueryClassification
)

def get_prompt_fully_qualified(query):
        prompt = f"""
        As a helpful agent, you'll recieve requests from users looking for furniture products.

        Your task is to search with a structured query against a furniture product catalog.

        Here is the users request:

        {query}

        Return the best classifications for this user's query.

        Try to pick as diverse a set of possible to ensure the customer finds what they need.
        (IE different top level categories are better than very similar classifications that share most of their tree / subtree)

        Return an empty list if no classification fits, or its too ambiguous.

        """

        return prompt

def fully_classified(query):
    prompt = get_prompt_fully_qualified(query)
    classification = enricher.enrich(prompt).model_copy()
    if "No Classification Fits" in classification.classifications:
        classification.classifications = []
    return classification

fully_classified("dinooosaur"), fully_classified("sofa loveseat")
# Out:
# 2025-08-31 21:07:50,917 - data_dir - INFO - Looking for openai in environment variables or globals...
# INFO:data_dir:Looking for openai in environment variables or globals...
# 2025-08-31 21:07:50,918 - data_dir - INFO - Reading openai_api_key API key from /content/drive/MyDrive/cheat-at-search-data//keys.json
# INFO:data_dir:Reading openai_api_key API key from /content/drive/MyDrive/cheat-at-search-data//keys.json
# 2025-08-31 21:07:51,147 - data_dir - INFO - openai_api_key key loaded successfully.
# INFO:data_dir:openai_api_key key loaded successfully.
# 2025-08-31 21:07:52,249 - query_parser - INFO - Loading enrich cache from /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3827e3cfb0a48ec60363a6165c09cbd1_cache.pkl
# INFO:query_parser:Loading enrich cache from /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3827e3cfb0a48ec60363a6165c09cbd1_cache.pkl
# 2025-08-31 21:07:53,509 - query_parser - ERROR - Error loading cache file /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3827e3cfb0a48ec60363a6165c09cbd1_cache.pkl: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# ERROR:query_parser:Error loading cache file /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3827e3cfb0a48ec60363a6165c09cbd1_cache.pkl: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# 2025-08-31 21:07:53,511 - query_parser - ERROR - Starting with empty cache due to error.
# ERROR:query_parser:Starting with empty cache due to error.
# (QueryClassification(keywords='dinooosaur', classifications=[]),
#  QueryClassification(keywords='sofa loveseat', classifications=['Furniture / Living Room Furniture / Sofas', 'Reception Area / Reception Seating / Reception Sofas & Loveseats', 'Reception Area / Reception Seating / Office Sofas & Loveseats']))

# %% [markdown]
# ### Redefine ground truth

# %%
from cheat_at_search.wands_data import labeled_query_products, queries

def get_top_categories(column, no_fit_label, cutoff=0.8):
    # Get relevant products per query
    top_products = labeled_query_products[labeled_query_products['grade'] == 2]

    # Aggregate top categories
    categories_per_query_ideal = top_products.groupby('query')[column].value_counts().reset_index()

    # Get as percentage of all categories for this query
    top_cat_proportion = categories_per_query_ideal.groupby(['query', column]).sum() / categories_per_query_ideal.groupby('query').sum()
    top_cat_proportion = top_cat_proportion.drop(columns=column).reset_index()

    # Only look at cases where the category is > 0.8
    top_cat_proportion = top_cat_proportion[top_cat_proportion['count'] > cutoff]
    top_cat_proportion[column].fillna(no_fit_label, inplace=True)
    ground_truth_cat = top_cat_proportion
    # Give No Category Fits to all others without dominant category
    ground_truth_cat = ground_truth_cat.merge(queries, how='right', on='query')[['query', column, 'count']]
    ground_truth_cat[column].fillna(no_fit_label, inplace=True)
    return ground_truth_cat

# The original ground truth by category
ground_truth_cat = get_top_categories('category', 'No Category Fits', cutoff=0.8)


ground_truth_cat_list = get_top_categories('category', 'No Category Fits', cutoff=0.05)

# Group by query, collect category into list
ground_truth_cat_list = ground_truth_cat_list.groupby('query').agg({'category': list}).reset_index()
# Remove empty items on "No Category Fits" from lists
ground_truth_cat_list['category'] = ground_truth_cat_list['category'].apply(lambda x: [y.strip() for y in x if y and y != 'No Category Fits'])
ground_truth_cat_list
# Out:
# /tmp/ipython-input-2868813019.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_cat_proportion[column].fillna(no_fit_label, inplace=True)
# /tmp/ipython-input-2868813019.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ground_truth_cat[column].fillna(no_fit_label, inplace=True)
# /tmp/ipython-input-2868813019.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_cat_proportion[column].fillna(no_fit_label, inplace=True)
# /tmp/ipython-input-2868813019.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ground_truth_cat[column].fillna(no_fit_label, inplace=True)
#                             query  \
# 0                   12v dirt bike
# 1          3 1/2 inch drawer pull
# 2    3 piece rug set with runners
# 3               3/4 size mattress
# 4         30 inch bathroom vanity
# ..                            ...
# 475              wrought tv stand
# 476                  zachary 72.5
# 477       zakariyah twin platform
# 478                           zen
# 479                 zodiac pillow
#
#                                          category
# 0                                              []
# 1                              [Home Improvement]
# 2                                          [Rugs]
# 3                                              []
# 4                              [Home Improvement]
# ..                                            ...
# 475                                   [Furniture]
# 476                                   [Furniture]
# 477                                 [Baby & Kids]
# 478  [Décor & Pillows, Home Improvement, Outdoor]
# 479                             [Décor & Pillows]
#
# [480 rows x 2 columns]

# %%
def get_preds(cat, column):
    if column == 'category':
        return cat.categories
    elif column == 'sub_category':
        return cat.sub_categories
    else:
        raise ValueError(f"Unknown column {column}")


def jaccard_sim(ground_truth, column, no_fit_label, classifier_fn):

    jaccard_sum = 0
    num_preds = 0
    for _, row in ground_truth.iterrows():
        query = row['query']
        expected_category = set(row[column])
        cat = classifier_fn(query)
        preds = set(get_preds(cat, column))
        if (len(preds) == 0) or (preds == [no_fit_label]):
            print(f"Skipping {query}")
            continue

        jaccard = len(preds.intersection(expected_category)) / len(preds.union(expected_category))
        print(f"{query} -- pred:{preds} == expected:{expected_category}")
        print(f"Jaccard: {jaccard}")
        jaccard_sum += jaccard
        num_preds += 1
    return jaccard_sum / num_preds, num_preds / len(ground_truth)


jaccard, coverage = jaccard_sim(ground_truth_cat_list, 'category', 'No Category Fits', fully_classified)
jaccard, coverage
# Out:
# Skipping 12v dirt bike
# 3 1/2 inch drawer pull -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# 3 piece rug set with runners -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# 3/4 size mattress -- pred:{'Bed & Bath'} == expected:set()
# Jaccard: 0.0
# 30 inch bathroom vanity -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# 46 inch closet door -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# 48 in entry table with side by side drawer -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# 48 inch bathroom vanity with trough sink -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# 48 inch kitchen hood -- pred:{'Appliances'} == expected:{'Appliances'}
# Jaccard: 1.0
# 48" sliding single track , barn door for laundry -- pred:{'Home Improvement'} == expected:{'Home Improvement', 'Sale'}
# Jaccard: 0.5
# 5 gang light switch -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# 54 in bench cushion -- pred:{'Outdoor', 'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# 7 draw white dresser -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# 70s inspired furniture -- pred:{'Furniture', 'Décor & Pillows'} == expected:{'Furniture'}
# Jaccard: 0.5
# 7qt slow cooker -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# above toilet cabinet -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# accent chair recliner -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# accent chairs living room -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# accent leather chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# acrylic clear chair -- pred:{'Furniture'} == expected:{'Furniture', 'School Furniture and Supplies'}
# Jaccard: 0.5
# adjustable height artist stool -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# aiden black velvet bed -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# almost heaven sauna -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# aloe vera plant pot -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 0.5
# Skipping alter furniture
# alyse 8 light -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# Skipping amarillo
# anchor decor -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows', 'Baby & Kids'}
# Jaccard: 0.5
# animal print handmade tufted wool beige/black area rug by allmodern -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# annex dresser -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# anti fatigue mat -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# antique brass faucet -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# antique silver entry table -- pred:{'Furniture', 'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# arched christmas tree -- pred:{'Holiday Décor'} == expected:set()
# Jaccard: 0.0
# Skipping argenteuil
# artificial orchid arrangement -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# arwen table lamp -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# attleboro drum coffee table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# auburn throw pillows -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# ayesha curry kitchen -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# bar room wall decor -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# bar stool 24 inches height -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# bar stool with backrest -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# barstool patio sets -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# basket planter -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Outdoor', 'Storage & Organization'}
# Jaccard: 0.3333333333333333
# bathroom freestanding cabinet -- pred:{'Home Improvement', 'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 0.5
# bathroom lighting -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# bathroom single faucet -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# bathroom vanity knobs -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# bathroom vanity with counter space -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# Skipping bathroom wastebasket
# beach blue headboard -- pred:{'Furniture', 'Décor & Pillows'} == expected:{'Furniture'}
# Jaccard: 0.5
# beaded curtains -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# Skipping bed risers
# bed side table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# bedroom accessories -- pred:{'Furniture', 'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 0.5
# bedroom wall decor floral, multicolored with some teal (prints) -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# beds that have leds -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping bee
# belchertown table lamp -- pred:{'Lighting'} == expected:set()
# Jaccard: 0.0
# benjiamino faux leather power lift chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# berenice 4 storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture'}
# Jaccard: 0.5
# betty resin free standing umbrella -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# big basket for dirty cloths -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# bistro sets patio -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# bistro table and chairs -- pred:{'Outdoor', 'Furniture'} == expected:{'Outdoor'}
# Jaccard: 0.5
# biycicle plant stands -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# black 5 drawer dresser by guilford -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# black fluffy stool -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# black frame 22 x 36 -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# black freestanding tub  with faucet -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# black hanging bookshelf -- pred:{'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 0.5
# blaylock bookcase headboard -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# blk 18x18 seat cushions -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Ergonomic Accessories'}
# Jaccard: 0.0
# block coffee table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# blue faux throw with pillows -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# board game storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture'}
# Jaccard: 0.5
# body pillow and case -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# body pillow case -- pred:{'Bed & Bath', 'Décor & Pillows'} == expected:{'Bed & Bath'}
# Jaccard: 0.5
# bohemian -- pred:{'Rugs', 'Furniture', 'Décor & Pillows'} == expected:{'Furniture', 'Rugs', 'Bed & Bath', 'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 0.6
# boho bed frame -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# bowersville ladder writing desk -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# breakfast bar table -- pred:{'Furniture'} == expected:{'Outdoor', 'Furniture'}
# Jaccard: 0.5
# brendon counter stool -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# broadway lever -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# brockham solid blackout thermal grommet curtain panels -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# Skipping brunk ship wheel
# brush nickel faucet bathroom -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# brushed gold wall decor -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# bubble guppies chair -- pred:{'Furniture', 'Baby & Kids'} == expected:set()
# Jaccard: 0.0
# burnt orange curtains -- pred:{'Décor & Pillows'} == expected:{'Rugs'}
# Jaccard: 0.0
# burruss patio sectional with cushions -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# butcher block island -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# cake cutlery -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# Skipping cake plates with tops
# calvin patio chair -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# Skipping camper
# Skipping canadian
# candace wingback upholstered bed -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# canvas map art -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows', 'Baby & Kids'}
# Jaccard: 0.5
# capricorn chest -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# card table -- pred:{'Furniture'} == expected:{'Furniture', 'School Furniture and Supplies'}
# Jaccard: 0.5
# carolyn console table -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# carpet 5x6 -- pred:{'Rugs'} == expected:set()
# Jaccard: 0.0
# ceramic tile sea shell -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# Skipping certified international melamine
# chabely 5 draw chest -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# chair and a half recliner -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# chair pillow cushion -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Outdoor'}
# Jaccard: 0.5
# chaise lounge couch -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# champagne velvet desk chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# chase utility laundry cart -- pred:{'Commercial Business Furniture', 'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 0.5
# chaves l-shape floating desk with hutch -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# china clock -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# chinese flower stand -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} == expected:{'Furniture'}
# Jaccard: 0.3333333333333333
# chrome bathroom 4 light vanity light -- pred:{'Lighting'} == expected:{'Lighting', 'Home Improvement'}
# Jaccard: 0.5
# chrome shower head and valve -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# circle cabinet pulls -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# clear shower curtain -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# cliffside 5 light candle style drum chandelier -- pred:{'Lighting'} == expected:set()
# Jaccard: 0.0
# closet pull out valet rod -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# closet storage with zipper -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# cloud modular sectional -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# coat rack for bedroom -- pred:{'Contractor', 'Storage & Organization'} == expected:{'Contractor'}
# Jaccard: 0.5
# coffee bar buffet -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# coffee container -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# coffee table fire pit -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# coma inducer comforter king set -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# comfortable accent chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# cortez pillow -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# Skipping counter top one cup hot water dispenser
# cover set for outdoor furniture -- pred:{'Outdoor', 'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 0.5
# cream queen duvet cover -- pred:{'Bed & Bath'} == expected:set()
# Jaccard: 0.0
# Skipping croscill ashton
# cushion replacement insert -- pred:{'Outdoor', 'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# dark gray dresser -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# day bed indian -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# decorative wall clocks -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# decorative white pillow -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# deer coat hooks -- pred:{'Home Improvement', 'Contractor'} == expected:{'Contractor'}
# Jaccard: 0.5
# Skipping delta trinsic
# delta trinsic double towel hook in champagne bronze -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# desk and chair set -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# desk for kids -- pred:{'Baby & Kids'} == expected:{'Baby & Kids'}
# Jaccard: 1.0
# desk for kids tjat ate 10 year old -- pred:{'Baby & Kids'} == expected:{'Baby & Kids'}
# Jaccard: 1.0
# dining room tables -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# dining table vinyl cloth -- pred:{'Furniture', 'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 0.5
# Skipping dinosaur
# dolomite subway tile -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# donaldson teak couch -- pred:{'Outdoor', 'Furniture'} == expected:set()
# Jaccard: 0.0
# door jewelry organizer -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 1.0
# door pulls bronze matte 4 inch -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# dorel vanity -- pred:{'Furniture', 'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 0.5
# driftwood mirror -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# Skipping drudge report
# drum picture -- pred:{'Décor & Pillows'} == expected:{'School Furniture and Supplies', 'Décor & Pillows'}
# Jaccard: 0.5
# dual monitor stand -- pred:{'Furniture'} == expected:{'Furniture', 'School Furniture and Supplies'}
# Jaccard: 0.5
# dull bed with shirt head board -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# Skipping dumbbells
# e12/candelabra -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# edge chair mat -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# eiffel tower wall art -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows', 'Baby & Kids'}
# Jaccard: 0.5
# elegant executive chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# elephant framed -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows', 'Baby & Kids'}
# Jaccard: 0.5
# emma headboard -- pred:{'Furniture'} == expected:{'Baby & Kids'}
# Jaccard: 0.0
# enclosed shoe rack -- pred:{'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 0.5
# end table between recliners -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# entertainment console -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# entertainment stand end table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# entrance table -- pred:{'Furniture', 'Contractor'} == expected:{'Furniture'}
# Jaccard: 0.5
# ergonomic chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# family lamp -- pred:{'Lighting'} == expected:set()
# Jaccard: 0.0
# farmhouse bread box -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# farmhouse cabinet -- pred:{'Home Improvement', 'Furniture', 'Storage & Organization'} == expected:{'Furniture'}
# Jaccard: 0.3333333333333333
# farmhouse hood vent -- pred:{'Home Improvement', 'Appliances'} == expected:set()
# Jaccard: 0.0
# fawkes 36" blue vanity -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# feather wall art -- pred:{'Décor & Pillows'} == expected:{'Contractor', 'Décor & Pillows'}
# Jaccard: 0.5
# filaret outdoor sofa -- pred:{'Outdoor'} == expected:set()
# Jaccard: 0.0
# flamingo -- pred:{'Décor & Pillows'} == expected:{'Outdoor', 'Décor & Pillows', 'Baby & Kids'}
# Jaccard: 0.3333333333333333
# fleur de lis living candle wall sconce bronze -- pred:{'Lighting', 'Décor & Pillows'} == expected:{'Lighting', 'Décor & Pillows'}
# Jaccard: 1.0
# floating bed -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# flour and sugar containers -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# fold in half table -- pred:{'Storage & Organization', 'Furniture', 'School Furniture and Supplies'} == expected:{'School Furniture and Supplies'}
# Jaccard: 0.3333333333333333
# fortunat coffee table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# foutains with brick look -- pred:{'Outdoor'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 0.5
# french molding -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# front door cabinet with doors -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture'}
# Jaccard: 0.5
# front porch furniture sets -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# full bed with trundle -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# full mattress padded liner -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# full metal bed rose gold -- pred:{'Furniture'} == expected:{'Baby & Kids'}
# Jaccard: 0.0
# gaia driftwood table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping garage door mail slot
# garage sports storage rack -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# Skipping gas detector
# Skipping ge top loading washer 4.5
# geralyn upholstered storage platform bed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# girl reading statue -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 1.0
# glass doors for bath -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# glass lsmp shades -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# glinda upholstered bench -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# glow in the dark silent wall clock -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# gnome fairy garden -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# gold -- pred:{'Lighting', 'Furniture', 'Décor & Pillows'} == expected:{'Furniture', 'Home Improvement', 'Bed & Bath', 'Décor & Pillows', 'Lighting'}
# Jaccard: 0.6
# golub dining table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# gowdy height adjustable standing desk -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# gracie oaks 62 oller 14 ceiling fan -- pred:{'Lighting'} == expected:set()
# Jaccard: 0.0
# grantola wall mirror -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# Skipping gravity feeder
# gray dresser -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# gray leather cocktail table -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# grill cover 73 -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# Skipping gurney  slade 56
# hardwood beds -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# hawaii vintage art -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# high weight capacity bunk beds -- pred:{'Furniture'} == expected:{'Baby & Kids'}
# Jaccard: 0.0
# hillsby oriental rug -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# hinged square ottoman -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# hitchcock mid-century wall shelf -- pred:{'Décor & Pillows', 'Storage & Organization'} == expected:set()
# Jaccard: 0.0
# home sweet home sign -- pred:{'Décor & Pillows'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 0.5
# hub leaning full length mirror -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# huge bookcase -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 1.0
# hulmeville writing desk with hutch -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# huntsville sectional sofa -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# hussain handmade tufted magenta rug -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# iittala bowl -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 0.5
# indoor multi tiered plant stand -- pred:{'Outdoor', 'Furniture', 'Storage & Organization'} == expected:{'Outdoor', 'Furniture'}
# Jaccard: 0.6666666666666666
# indoor water fountain -- pred:{'Décor & Pillows'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 0.5
# industrial -- pred:{'Lighting', 'Furniture'} == expected:{'Storage & Organization', 'Lighting', 'Furniture', 'Décor & Pillows'}
# Jaccard: 0.5
# industrial pipe dining  table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# ines shag rug w003096809 -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# infant girl crib bedding -- pred:{'Bed & Bath', 'Baby & Kids'} == expected:{'Baby & Kids'}
# Jaccard: 0.5
# island estate coffee table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping itchington butterfly
# jennie tufted upholstered low profile platform bed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# johan desk by laurel foundry -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# jordanna solid wood rocking -- pred:{'Outdoor', 'Furniture'} == expected:{'Outdoor'}
# Jaccard: 0.5
# kari 2 piece -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# kelly clarkson light fixtures -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# kids chair -- pred:{'Baby & Kids'} == expected:{'School Furniture and Supplies', 'Baby & Kids'}
# Jaccard: 0.5
# king adjustable bed including mattress -- pred:{'Bed & Bath', 'Furniture'} == expected:{'Bed & Bath'}
# Jaccard: 0.5
# king poster bed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# king size bed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping kisner
# kitchen anti fatigue mats -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# kitchen islands with seating -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# kitchen storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Home Improvement', 'Furniture', 'Kitchen & Tabletop'}
# Jaccard: 0.25
# kitchen storage shelves -- pred:{'Storage & Organization'} == expected:{'Kitchen & Tabletop', 'Storage & Organization'}
# Jaccard: 0.5
# kitchen wooden stand -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 1.0
# kohen 5 drawer dresser -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# kohler purist brushed bronze -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# kohler whitehaven farmhouse kitchen sink -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# kraus kitchen sink faucet oletto kpf 2820 sfs -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# landis wall mounted bathroom shelves -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# large bases -- pred:{'Outdoor', 'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# large cushion outdoor chair -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# large spoon and fork wall decor -- pred:{'Décor & Pillows'} == expected:{'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 0.5
# laundry basket with wheels -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# laundry vanity cabinet -- pred:{'Home Improvement', 'Storage & Organization'} == expected:{'Home Improvement', 'Furniture'}
# Jaccard: 0.3333333333333333
# leather chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# leather chairs -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# leather dining chairs -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# led 60 -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# led light strip -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# led nightstand -- pred:{'Lighting', 'Furniture', 'Décor & Pillows'} == expected:{'Furniture'}
# Jaccard: 0.3333333333333333
# liberty hardware francisco -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# light and navy blue decorative pillow -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# light wood nightstand with silver accents -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# ligth bulb -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# living curtains pearl -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# living room coffee table sets -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# living room designs -- pred:{'Furniture', 'Décor & Pillows'} == expected:{'Furniture', 'Décor & Pillows'}
# Jaccard: 1.0
# living room ideas -- pred:{'Lighting', 'Furniture', 'Décor & Pillows'} == expected:{'Furniture', 'Décor & Pillows'}
# Jaccard: 0.6666666666666666
# love seat wide faux leather tuxedo arm sofa -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# low profile loveseat recliner -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# lowes tile -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# Skipping luau string lights
# Skipping lunch bag
# mahone porch rocking chair -- pred:{'Outdoor', 'Furniture'} == expected:{'Outdoor'}
# Jaccard: 0.5
# Skipping malachi sled
# marble -- pred:{'Home Improvement', 'Furniture'} == expected:{'Furniture', 'Home Improvement', 'Bed & Bath', 'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 0.4
# marlon tufted queen bed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# maryford queen tufted bed -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# mattress foam topper queen -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# meade mirror -- pred:{'Décor & Pillows'} == expected:{'Sale', 'Décor & Pillows'}
# Jaccard: 0.5
# meditation -- pred:{'Furniture'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 0.0
# medium clips -- pred:{'Clips/Clamps'} == expected:{'Clips'}
# Jaccard: 0.0
# medium size chandelier -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# memory foam rug galveston -- pred:{'Rugs'} == expected:set()
# Jaccard: 0.0
# Skipping merlyn 6
# mexican art -- pred:{'Décor & Pillows'} == expected:{'Home Improvement', 'Décor & Pillows'}
# Jaccard: 0.5
# mid century modern -- pred:{'Furniture'} == expected:{'Furniture', 'Décor & Pillows'}
# Jaccard: 0.5
# midcentury tv unit -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# mila task chair -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# milk cow chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping minnestrista
# mission double vanity -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# mobley zero gravity adjustable bed with wireless remote -- pred:{'Bed & Bath', 'Furniture'} == expected:{'Bed & Bath'}
# Jaccard: 0.5
# modern farmhouse lighting semi flush mount -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# modern outdoor furniture -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# moen 5995 arbor one -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# moen matte black hooks -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# moen multi function dual shower head -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# mom urn -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# Skipping monthly calendar
# mud room sign -- pred:{'Décor & Pillows'} == expected:{'School Furniture and Supplies', 'Lighting', 'Décor & Pillows'}
# Jaccard: 0.3333333333333333
# multi color rug -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# music plug wall plate -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# mystic swivel -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# nautical platters -- pred:{'Kitchen & Tabletop', 'Décor & Pillows'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 0.5
# navy and peach bedding -- pred:{'Bed & Bath'} == expected:set()
# Jaccard: 0.0
# nectar queen mattress -- pred:{'Bed & Bath'} == expected:set()
# Jaccard: 0.0
# Skipping nespresso vertuo next premium by breville with aeroccino
# nesting tray set -- pred:{'Kitchen & Tabletop', 'Décor & Pillows'} == expected:{'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 1.0
# nettie 5 pc bar set -- pred:{'Furniture'} == expected:{'Outdoor'}
# Jaccard: 0.0
# non slip shower floor tile -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# novara pergola -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# nursery end table -- pred:{'Furniture', 'Baby & Kids'} == expected:set()
# Jaccard: 0.0
# odum velvet -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# olive green console table -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# Skipping oliver parsons
# ombre rug -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# Skipping one alium way
# oriental vanity -- pred:{'Furniture', 'Home Improvement'} == expected:set()
# Jaccard: 0.0
# orren ellis l shape desk -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# orren ellis l shaped desk -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# osgood mirror -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# ottoman bed queen -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# outdoor clock -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 1.0
# outdoor light fixtures -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# outdoor lounge chair -- pred:{'Outdoor'} == expected:{'Outdoor', 'Furniture'}
# Jaccard: 0.5
# outdoor lounge cushions -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# outdoor movie screen -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# outdoor privacy wall -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# outdoor seat/back cushion -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# outdoor sectional dining -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# outdoor sectional doning -- pred:{'Outdoor'} == expected:set()
# Jaccard: 0.0
# outdoor storage -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# outdoor waterproof chest -- pred:{'Outdoor', 'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 0.5
# outdoor welcome rug -- pred:{'Outdoor', 'Rugs'} == expected:{'Rugs'}
# Jaccard: 0.5
# overstreet rustic pub stools -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping owl
# palram harmony greenhouses -- pred:{'Outdoor'} == expected:set()
# Jaccard: 0.0
# pantry grey -- pred:{'Kitchen & Tabletop', 'Storage & Organization'} == expected:set()
# Jaccard: 0.0
# papasan chair frame only -- pred:{'Furniture'} == expected:{'Outdoor', 'Furniture', 'Baby & Kids'}
# Jaccard: 0.3333333333333333
# Skipping parakeet toy
# parsons chairs -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# pasta tools -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# pastel pink desk chair -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# patio design -- pred:{'Outdoor'} == expected:{'Outdoor', 'Storage & Organization'}
# Jaccard: 0.5
# peacock -- pred:{'Décor & Pillows'} == expected:{'Outdoor', 'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 0.3333333333333333
# pedistole sink -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# pennfield playhouse -- pred:{'Baby & Kids'} == expected:set()
# Jaccard: 0.0
# penny round tile -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# picasso -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# pictures to hang over fireplace -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# Skipping pineapple
# platform bed side table -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# podium with locking cabinet -- pred:{'Furniture', 'School Furniture and Supplies'} == expected:{'School Furniture and Supplies'}
# Jaccard: 0.5
# Skipping pool floats
# porcelain loaf pan -- pred:{'Kitchen & Tabletop'} == expected:set()
# Jaccard: 0.0
# power lift chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping printers
# Skipping promo codes or discounts
# Skipping propane gas dryer
# pull out sleeper loveseat -- pred:{'Furniture'} == expected:{'Reception Area', 'Furniture'}
# Jaccard: 0.5
# queen ann style living room chair -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# queen wingback chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# rack glass -- pred:{'Storage & Organization'} == expected:{'Kitchen & Tabletop', 'Storage & Organization'}
# Jaccard: 0.5
# Skipping rattan truck
# real touch roses floral arrangements in glass vase -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# Skipping refrigerator with ice an water in door
# regner power loom red -- pred:{'Rugs', 'Décor & Pillows'} == expected:{'Rugs'}
# Jaccard: 0.5
# retractable side awning -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# rock climbing wall kids -- pred:{'Outdoor', 'Baby & Kids'} == expected:{'Holiday Décor'}
# Jaccard: 0.0
# rolande heavy duty power lift assist recliner -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# rooster decor -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# rose gold lounge -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# round outdoor patio cover -- pred:{'Outdoor', 'Storage & Organization'} == expected:set()
# Jaccard: 0.0
# royal blue counter height chairs -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# ruckus chair -- pred:{'Furniture'} == expected:{'School Furniture and Supplies', 'Baby & Kids'}
# Jaccard: 0.0
# rug for teen room -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# rug plum -- pred:{'Rugs'} == expected:{'Rugs'}
# Jaccard: 1.0
# rustic storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 1.0
# rustic twig -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 0.5
# salon chair -- pred:{'Furniture'} == expected:{'Commercial Business Furniture', 'Furniture'}
# Jaccard: 0.5
# sancroft armchair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# seat cushions desk -- pred:{'Furniture'} == expected:{'Shop Product Type', 'Furniture'}
# Jaccard: 0.5
# self enclosed planters -- pred:{'Outdoor'} == expected:set()
# Jaccard: 0.0
# semi flush foyer light -- pred:{'Lighting'} == expected:{'Lighting'}
# Jaccard: 1.0
# serta kleinmon -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# sheets for twinxl -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# sheffield home bath set -- pred:{'Bed & Bath', 'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 0.5
# shoe bench entryway -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Storage & Organization'}
# Jaccard: 1.0
# shoe closet -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# shower hooks -- pred:{'Bed & Bath', 'Home Improvement'} == expected:{'Bed & Bath'}
# Jaccard: 0.5
# side table with storage -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# sinks bed frame -- pred:{'Furniture', 'Home Improvement'} == expected:set()
# Jaccard: 0.0
# sliding closet mirror -- pred:{'Storage & Organization', 'Furniture', 'Décor & Pillows'} == expected:{'Home Improvement', 'Furniture'}
# Jaccard: 0.25
# small curtain rods -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# small ladies rocker swivel recliner -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# small loving roomtables -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# small space dining table and chairs sets -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# small wardrobe grey -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# small woven pouf -- pred:{'Furniture', 'Décor & Pillows'} == expected:{'Furniture'}
# Jaccard: 0.5
# smart coffee table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# sofa with ottoman -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# solid teak end table -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# stainless steel colander set -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# stainless steel free standing shower caddy -- pred:{'Storage & Organization'} == expected:{'Home Improvement'}
# Jaccard: 0.0
# star wars rug -- pred:{'Rugs', 'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# stoneford end tables white and wood -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# storage dresser -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.3333333333333333
# sugar canister -- pred:{'Kitchen & Tabletop'} == expected:{'Kitchen & Tabletop'}
# Jaccard: 1.0
# sunflower -- pred:{'Décor & Pillows'} == expected:{'Outdoor', 'Rugs', 'Kitchen & Tabletop', 'Décor & Pillows'}
# Jaccard: 0.25
# sunjoy lantern -- pred:{'Outdoor', 'Lighting'} == expected:{'Lighting'}
# Jaccard: 0.5
# super bright lights -- pred:{'Lighting'} == expected:{'Home Improvement', 'Lighting', 'Furniture', 'Holiday Décor'}
# Jaccard: 0.25
# Skipping surge protector
# tall buffet cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture'}
# Jaccard: 0.5
# tall free standing pet gate -- pred:{'Pet'} == expected:{'Pet'}
# Jaccard: 1.0
# tall storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture', 'Kitchen & Tabletop', 'Storage & Organization'}
# Jaccard: 0.6666666666666666
# teal chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# tile backsplash -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# toddler couch fold out -- pred:{'Furniture', 'Baby & Kids'} == expected:{'Baby & Kids'}
# Jaccard: 0.5
# togo chair -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# toilet paper stand -- pred:{'Home Improvement'} == expected:{'Home Improvement', 'Kitchen & Tabletop'}
# Jaccard: 0.5
# tollette teal outdoor rug -- pred:{'Outdoor', 'Rugs'} == expected:{'Rugs'}
# Jaccard: 0.5
# town & country living curtains -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# tressler rug -- pred:{'Rugs'} == expected:set()
# Jaccard: 0.0
# trinaic towel rod -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# trundle daybed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# tufted chair with gold legs -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# tufted upholstered bed diamond -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# turquoise chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# turquoise pillows -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# twin bed frame -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# twin over full bunk beds cool desins -- pred:{'Furniture'} == expected:{'Baby & Kids'}
# Jaccard: 0.0
# tye dye duvet cover -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# unique coffee tables -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# upholstered bed -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# upholstered girls bed -- pred:{'Furniture', 'Baby & Kids'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 1.0
# urban outfitters duvet -- pred:{'Bed & Bath'} == expected:set()
# Jaccard: 0.0
# velvet chaise -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping verden callan
# vlad modular sectional -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# wainscoting ideas -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# wall art fiji -- pred:{'Décor & Pillows'} == expected:set()
# Jaccard: 0.0
# wall design shelf -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# wall sconce with usb port -- pred:{'Lighting'} == expected:{'Lighting', 'Home Improvement', 'Décor & Pillows'}
# Jaccard: 0.3333333333333333
# wall shelves -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# wand bunk beds -- pred:{'Furniture', 'Baby & Kids'} == expected:set()
# Jaccard: 0.0
# waterfall faucet -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# wayfair coffee table -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# wayfair comforters -- pred:{'Bed & Bath'} == expected:{'Bed & Bath'}
# Jaccard: 1.0
# wayfair sleep zippered -- pred:{'Bed & Bath'} == expected:{'Bed & Bath', 'Décor & Pillows'}
# Jaccard: 0.5
# wayfair tension rod -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# welcome sign -- pred:{'Outdoor', 'Décor & Pillows'} == expected:{'Outdoor', 'Rugs', 'Décor & Pillows'}
# Jaccard: 0.6666666666666666
# westling coffee table -- pred:{'Furniture'} == expected:set()
# Jaccard: 0.0
# whimsical solar lights -- pred:{'Lighting'} == expected:{'Outdoor', 'Lighting'}
# Jaccard: 0.5
# white abstract -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# white bathroom vanity black hardware -- pred:{'Home Improvement'} == expected:set()
# Jaccard: 0.0
# Skipping white splashproof shiplap wallpaper
# window wall accent -- pred:{'Décor & Pillows'} == expected:{'Outdoor', 'Décor & Pillows'}
# Jaccard: 0.5
# wine bar -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# wire basket with dividers -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# wisdom stone river 3-3/4 -- pred:{'Home Improvement'} == expected:{'Home Improvement'}
# Jaccard: 1.0
# wishbone chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# wood bar stools -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# wood coffee table set by storage -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# wood floor protector mat -- pred:{'Furniture', 'Storage & Organization'} == expected:{'Furniture'}
# Jaccard: 0.5
# wood rack wide -- pred:{'Storage & Organization'} == expected:{'Storage & Organization'}
# Jaccard: 1.0
# wooden chair outdoor -- pred:{'Outdoor'} == expected:{'Outdoor'}
# Jaccard: 1.0
# worn leather office chair -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# writing desk -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# writing desk 48" -- pred:{'Furniture'} == expected:{'Furniture', 'Baby & Kids'}
# Jaccard: 0.5
# wrought tv stand -- pred:{'Furniture'} == expected:{'Furniture'}
# Jaccard: 1.0
# Skipping zachary 72.5
# zakariyah twin platform -- pred:{'Furniture'} == expected:{'Baby & Kids'}
# Jaccard: 0.0
# zen -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} == expected:{'Outdoor', 'Home Improvement', 'Décor & Pillows'}
# Jaccard: 0.5
# zodiac pillow -- pred:{'Décor & Pillows'} == expected:{'Décor & Pillows'}
# Jaccard: 1.0
# (0.6449576597382601, 0.9020833333333333)

# %% [markdown]
# ### Maybe a better question -- do we recall the most important prediction?

# %%
def recall_when_pred(categorized, ground_truth_cat):
    """When we retrieve a category, is it correct?"""
    hits = []
    misses = []
    idx = 0
    for _, row in ground_truth_cat.iterrows():
        query = row['query']
        expected_category = row['category']

        cat = categorized(query)
        if len(cat.classifications) == 0:
            print(f"{idx} Skipping {query}")
            continue
        if expected_category != "No Category Fits":
            if expected_category.strip() in cat.categories:
                print(f"{idx} q:{query} -- pred:{cat.categories} == expected:{expected_category.strip()}")
                hits.append((expected_category, cat))
            else:
                print("***")
                print(f"{query} -- pred:{cat.categories} != expected:{expected_category.strip()}")
                print(cat.classifications)
                misses.append((expected_category, cat))
                num_so_far = len(hits) + len(misses)
                print(f"{idx} recall (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
        idx += 1

    return len(hits) / (len(hits) + len(misses)), hits, misses

prec, hits, misses = recall_when_pred(fully_classified, ground_truth_cat)
prec
# Out:
# 1 q:smart coffee table -- pred:{'Furniture'} == expected:Furniture
# 2 Skipping dinosaur
# 2 q:turquoise pillows -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 3 q:chair and a half recliner -- pred:{'Furniture'} == expected:Furniture
# 4 q:sofa with ottoman -- pred:{'Furniture'} == expected:Furniture
# 6 q:driftwood mirror -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 7 q:home sweet home sign -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# ***
# coffee table fire pit -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor Décor / Outdoor Fountains']
# 8 recall (N=7) -- 0.8571428571428571
# 9 q:king poster bed -- pred:{'Furniture'} == expected:Furniture
# 10 q:ombre rug -- pred:{'Rugs'} == expected:Rugs
# 11 q:large spoon and fork wall decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 12 q:outdoor privacy wall -- pred:{'Outdoor'} == expected:Outdoor
# 13 q:beds that have leds -- pred:{'Furniture'} == expected:Furniture
# 14 q:black 5 drawer dresser by guilford -- pred:{'Furniture'} == expected:Furniture
# 16 q:closet storage with zipper -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 17 q:chrome bathroom 4 light vanity light -- pred:{'Lighting'} == expected:Lighting
# 18 Skipping gurney  slade 56
# ***
# foutains with brick look -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor Décor / Outdoor Fountains']
# 18 recall (N=16) -- 0.875
# 19 q:living curtains pearl -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 20 q:light and navy blue decorative pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 22 q:wood coffee table set by storage -- pred:{'Furniture'} == expected:Furniture
# 24 q:leather chairs -- pred:{'Furniture'} == expected:Furniture
# 25 q:outdoor welcome rug -- pred:{'Outdoor', 'Rugs'} == expected:Rugs
# 26 q:rooster decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 27 q:bathroom vanity knobs -- pred:{'Home Improvement'} == expected:Home Improvement
# 28 q:3 1/2 inch drawer pull -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# burnt orange curtains -- pred:{'Décor & Pillows'} != expected:Rugs
# ['Décor & Pillows / Window Treatments / Curtains & Drapes', 'Décor & Pillows / Window Treatments / Curtains & Drapes / 90 Inch Curtains & Drapes', 'Décor & Pillows / Window Treatments / Curtains & Drapes / 63 Inch and Less Curtains & Drapes']
# 29 recall (N=25) -- 0.88
# 30 q:dark gray dresser -- pred:{'Furniture'} == expected:Furniture
# 31 q:non slip shower floor tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 32 q:bar stool with backrest -- pred:{'Furniture'} == expected:Furniture
# 33 q:enclosed shoe rack -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 34 q:laundry basket with wheels -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 35 q:bar stool 24 inches height -- pred:{'Furniture'} == expected:Furniture
# 36 q:calvin patio chair -- pred:{'Outdoor'} == expected:Outdoor
# 37 q:door jewelry organizer -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 38 q:elegant executive chair -- pred:{'Furniture'} == expected:Furniture
# 39 q:closet pull out valet rod -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 40 q:toddler couch fold out -- pred:{'Furniture', 'Baby & Kids'} == expected:Baby & Kids
# 41 q:solid teak end table -- pred:{'Furniture'} == expected:Furniture
# 42 q:chrome shower head and valve -- pred:{'Home Improvement'} == expected:Home Improvement
# 43 q:70s inspired furniture -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 44 q:beach blue headboard -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 46 q:arwen table lamp -- pred:{'Lighting'} == expected:Lighting
# 48 q:tufted chair with gold legs -- pred:{'Furniture'} == expected:Furniture
# 49 q:kohen 5 drawer dresser -- pred:{'Furniture'} == expected:Furniture
# 53 q:tollette teal outdoor rug -- pred:{'Outdoor', 'Rugs'} == expected:Rugs
# 55 q:jordanna solid wood rocking -- pred:{'Outdoor', 'Furniture'} == expected:Outdoor
# 56 q:medium size chandelier -- pred:{'Lighting'} == expected:Lighting
# 57 q:broadway lever -- pred:{'Home Improvement'} == expected:Home Improvement
# 58 q:capricorn chest -- pred:{'Furniture'} == expected:Furniture
# 59 q:overstreet rustic pub stools -- pred:{'Furniture'} == expected:Furniture
# 60 q:7qt slow cooker -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 61 Skipping monthly calendar
# 61 Skipping zachary 72.5
# 61 q:gnome fairy garden -- pred:{'Outdoor'} == expected:Outdoor
# 62 q:novara pergola -- pred:{'Outdoor'} == expected:Outdoor
# 66 q:annex dresser -- pred:{'Furniture'} == expected:Furniture
# 67 q:infant girl crib bedding -- pred:{'Bed & Bath', 'Baby & Kids'} == expected:Baby & Kids
# 68 q:fold in half table -- pred:{'Storage & Organization', 'Furniture', 'School Furniture and Supplies'} == expected:School Furniture and Supplies
# 69 Skipping certified international melamine
# 69 q:serta kleinmon -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 70 q:sheffield home bath set -- pred:{'Bed & Bath', 'Home Improvement'} == expected:Home Improvement
# 71 q:46 inch closet door -- pred:{'Home Improvement'} == expected:Home Improvement
# 72 q:sancroft armchair -- pred:{'Furniture'} == expected:Furniture
# 73 q:dorel vanity -- pred:{'Furniture', 'Home Improvement'} == expected:Home Improvement
# 76 q:orren ellis l shape desk -- pred:{'Furniture'} == expected:Furniture
# 77 q:bathroom vanity with counter space -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# full metal bed rose gold -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames']
# 79 recall (N=63) -- 0.9365079365079365
# 83 q:rose gold lounge -- pred:{'Furniture'} == expected:Furniture
# 84 q:whimsical solar lights -- pred:{'Lighting'} == expected:Lighting
# 86 q:industrial pipe dining  table -- pred:{'Furniture'} == expected:Furniture
# 88 q:outdoor sectional dining -- pred:{'Outdoor'} == expected:Outdoor
# 89 q:kohler whitehaven farmhouse kitchen sink -- pred:{'Home Improvement'} == expected:Home Improvement
# 90 q:entertainment stand end table -- pred:{'Furniture'} == expected:Furniture
# 91 q:bar room wall decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 92 q:regner power loom red -- pred:{'Rugs', 'Décor & Pillows'} == expected:Rugs
# 95 q:tufted upholstered bed diamond -- pred:{'Furniture'} == expected:Furniture
# 96 q:48 in entry table with side by side drawer -- pred:{'Furniture'} == expected:Furniture
# 98 q:kitchen anti fatigue mats -- pred:{'Rugs'} == expected:Rugs
# 101 Skipping bed risers
# 101 q:front porch furniture sets -- pred:{'Outdoor'} == expected:Outdoor
# 102 q:ayesha curry kitchen -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 103 q:hillsby oriental rug -- pred:{'Rugs'} == expected:Rugs
# 105 Skipping delta trinsic
# 105 Skipping pineapple
# 105 q:led light strip -- pred:{'Lighting'} == expected:Lighting
# 106 q:geralyn upholstered storage platform bed -- pred:{'Furniture'} == expected:Furniture
# 110 q:body pillow case -- pred:{'Bed & Bath', 'Décor & Pillows'} == expected:Bed & Bath
# 112 q:zodiac pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 113 q:upholstered bed -- pred:{'Furniture'} == expected:Furniture
# 114 q:king size bed -- pred:{'Furniture'} == expected:Furniture
# 115 q:entrance table -- pred:{'Furniture', 'Contractor'} == expected:Furniture
# 116 q:unique coffee tables -- pred:{'Furniture'} == expected:Furniture
# 117 q:boho bed frame -- pred:{'Furniture'} == expected:Furniture
# 118 q:leather dining chairs -- pred:{'Furniture'} == expected:Furniture
# 119 q:wine bar -- pred:{'Furniture'} == expected:Furniture
# 120 q:block coffee table -- pred:{'Furniture'} == expected:Furniture
# 121 q:wainscoting ideas -- pred:{'Home Improvement'} == expected:Home Improvement
# 122 q:entertainment console -- pred:{'Furniture'} == expected:Furniture
# 123 q:kids chair -- pred:{'Baby & Kids'} == expected:Baby & Kids
# 124 q:farmhouse cabinet -- pred:{'Home Improvement', 'Furniture', 'Storage & Organization'} == expected:Furniture
# 125 q:outdoor light fixtures -- pred:{'Lighting'} == expected:Lighting
# 127 q:low profile loveseat recliner -- pred:{'Furniture'} == expected:Furniture
# 129 q:orren ellis l shaped desk -- pred:{'Furniture'} == expected:Furniture
# 130 q:glass doors for bath -- pred:{'Home Improvement'} == expected:Home Improvement
# 132 q:wire basket with dividers -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 133 q:podium with locking cabinet -- pred:{'Furniture', 'School Furniture and Supplies'} == expected:School Furniture and Supplies
# 135 q:queen wingback chair -- pred:{'Furniture'} == expected:Furniture
# 136 q:rug plum -- pred:{'Rugs'} == expected:Rugs
# 137 q:liberty hardware francisco -- pred:{'Home Improvement'} == expected:Home Improvement
# 139 q:drum picture -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 142 Skipping dumbbells
# 142 q:leather chair -- pred:{'Furniture'} == expected:Furniture
# 143 q:wishbone chair -- pred:{'Furniture'} == expected:Furniture
# 145 q:floating bed -- pred:{'Furniture'} == expected:Furniture
# 146 q:papasan chair frame only -- pred:{'Furniture'} == expected:Furniture
# 147 q:velvet chaise -- pred:{'Furniture'} == expected:Furniture
# 148 q:led nightstand -- pred:{'Lighting', 'Furniture', 'Décor & Pillows'} == expected:Furniture
# 151 q:accent chair recliner -- pred:{'Furniture'} == expected:Furniture
# 152 q:turquoise chair -- pred:{'Furniture'} == expected:Furniture
# 154 q:modern outdoor furniture -- pred:{'Outdoor'} == expected:Outdoor
# 155 q:kitchen storage shelves -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 156 q:feather wall art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 157 Skipping camper
# 157 Skipping printers
# 157 q:coffee bar buffet -- pred:{'Furniture'} == expected:Furniture
# 160 q:picasso -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 161 q:bedroom accessories -- pred:{'Furniture', 'Décor & Pillows'} == expected:Décor & Pillows
# 163 q:basket planter -- pred:{'Outdoor', 'Décor & Pillows'} == expected:Outdoor
# 164 q:mexican art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 165 q:rustic storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 166 q:almost heaven sauna -- pred:{'Outdoor'} == expected:Outdoor
# 167 Skipping promo codes or discounts
# ***
# outdoor lounge cushions -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs / Metal Outdoor Club Chairs']
# 167 recall (N=122) -- 0.9590163934426229
# 168 q:e12/candelabra -- pred:{'Lighting'} == expected:Lighting
# 169 q:penny round tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 170 q:farmhouse bread box -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# ***
# sugar canister -- pred:{'Kitchen & Tabletop'} != expected:
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Ceramic Kitchen Canisters & Jars', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars']
# 171 recall (N=126) -- 0.9523809523809523
# 172 Skipping lunch bag
# 172 q:board game storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 173 q:bedroom wall decor floral, multicolored with some teal (prints) -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 174 q:big basket for dirty cloths -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 175 q:benjiamino faux leather power lift chair -- pred:{'Furniture'} == expected:Furniture
# 179 q:black freestanding tub  with faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 181 q:desk for kids tjat ate 10 year old -- pred:{'Baby & Kids'} == expected:Baby & Kids
# 182 Skipping cake plates with tops
# 183 q:ceramic tile sea shell -- pred:{'Home Improvement'} == expected:Home Improvement
# 185 q:full mattress padded liner -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 186 Skipping ge top loading washer 4.5
# 186 q:fleur de lis living candle wall sconce bronze -- pred:{'Lighting', 'Décor & Pillows'} == expected:Décor & Pillows
# 187 q:ines shag rug w003096809 -- pred:{'Rugs'} == expected:Rugs
# 188 q:grill cover 73 -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 192 q:love seat wide faux leather tuxedo arm sofa -- pred:{'Furniture'} == expected:Furniture
# ***
# nettie 5 pc bar set -- pred:{'Furniture'} != expected:Outdoor
# ['Furniture / Kitchen & Dining Furniture / Bar Furniture / Home Bars & Bar Sets', 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools']
# 194 recall (N=139) -- 0.9496402877697842
# 195 q:kraus kitchen sink faucet oletto kpf 2820 sfs -- pred:{'Home Improvement'} == expected:Home Improvement
# 198 q:music plug wall plate -- pred:{'Home Improvement'} == expected:Home Improvement
# 201 q:sheets for twinxl -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 202 q:small space dining table and chairs sets -- pred:{'Furniture'} == expected:Furniture
# 203 q:small loving roomtables -- pred:{'Furniture'} == expected:Furniture
# 204 q:wisdom stone river 3-3/4 -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# twin over full bunk beds cool desins -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds']
# 205 recall (N=146) -- 0.9452054794520548
# 206 Skipping white splashproof shiplap wallpaper
# 206 q:power lift chair -- pred:{'Furniture'} == expected:Furniture
# 207 Skipping owl
# 207 Skipping bee
# 207 q:waterfall faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 209 q:anti fatigue mat -- pred:{'Rugs'} == expected:Rugs
# 210 q:storage dresser -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 211 q:kelly clarkson light fixtures -- pred:{'Lighting'} == expected:Lighting
# 212 q:artificial orchid arrangement -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 213 Skipping bathroom wastebasket
# 213 q:3 piece rug set with runners -- pred:{'Rugs'} == expected:Rugs
# 214 q:cloud modular sectional -- pred:{'Furniture'} == expected:Furniture
# ***
# outdoor seat/back cushion -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions', 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Dining Chair Patio Furniture Cushions']
# 215 recall (N=155) -- 0.9419354838709677
# 216 q:bathroom single faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 217 q:eiffel tower wall art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 218 q:decorative wall clocks -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 219 q:accent leather chair -- pred:{'Furniture'} == expected:Furniture
# 222 q:anchor decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 223 q:clear shower curtain -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 224 q:beaded curtains -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 225 Skipping surge protector
# 225 q:bistro table and chairs -- pred:{'Outdoor', 'Furniture'} == expected:Outdoor
# 226 q:multi color rug -- pred:{'Rugs'} == expected:Rugs
# 228 q:accent chairs living room -- pred:{'Furniture'} == expected:Furniture
# 229 q:antique brass faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 230 q:comfortable accent chair -- pred:{'Furniture'} == expected:Furniture
# ***
# high weight capacity bunk beds -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds']
# 232 recall (N=168) -- 0.9404761904761905
# 233 q:living room coffee table sets -- pred:{'Furniture'} == expected:Furniture
# 234 q:breakfast bar table -- pred:{'Furniture'} == expected:Furniture
# 236 q:retractable side awning -- pred:{'Outdoor'} == expected:Outdoor
# 238 q:bathroom freestanding cabinet -- pred:{'Home Improvement', 'Storage & Organization'} == expected:Storage & Organization
# 239 q:small curtain rods -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 240 q:cortez pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 242 q:champagne velvet desk chair -- pred:{'Furniture'} == expected:Furniture
# 243 q:dolomite subway tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 244 q:betty resin free standing umbrella -- pred:{'Outdoor'} == expected:Outdoor
# 246 q:edge chair mat -- pred:{'Furniture'} == expected:Furniture
# 247 q:chinese flower stand -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} == expected:Furniture
# 248 Skipping oliver parsons
# ***
# stainless steel free standing shower caddy -- pred:{'Storage & Organization'} != expected:Home Improvement
# ['Storage & Organization / Bathroom Storage & Organization / Bathroom Cabinets & Shelving', 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets']
# 248 recall (N=180) -- 0.9388888888888889
# 249 q:gowdy height adjustable standing desk -- pred:{'Furniture'} == expected:Furniture
# 250 q:hinged square ottoman -- pred:{'Furniture'} == expected:Furniture
# 252 q:barstool patio sets -- pred:{'Outdoor'} == expected:Outdoor
# 253 Skipping parakeet toy
# 253 q:marlon tufted queen bed -- pred:{'Furniture'} == expected:Furniture
# 255 Skipping brunk ship wheel
# 255 q:grantola wall mirror -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 256 q:gaia driftwood table -- pred:{'Furniture'} == expected:Furniture
# 258 q:48" sliding single track , barn door for laundry -- pred:{'Home Improvement'} == expected:Home Improvement
# 260 q:cover set for outdoor furniture -- pred:{'Outdoor', 'Storage & Organization'} == expected:Storage & Organization
# 262 q:coma inducer comforter king set -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 264 q:front door cabinet with doors -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 265 q:decorative white pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 266 q:wood floor protector mat -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 268 q:end table between recliners -- pred:{'Furniture'} == expected:Furniture
# ***
# zakariyah twin platform -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames']
# 269 recall (N=194) -- 0.9381443298969072
# 270 q:seat cushions desk -- pred:{'Furniture'} == expected:Furniture
# 271 q:small woven pouf -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 272 q:animal print handmade tufted wool beige/black area rug by allmodern -- pred:{'Rugs'} == expected:Rugs
# 273 q:circle cabinet pulls -- pred:{'Home Improvement'} == expected:Home Improvement
# 274 q:mattress foam topper queen -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 275 q:hawaii vintage art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 276 Skipping merlyn 6
# 276 q:ligth bulb -- pred:{'Lighting'} == expected:Lighting
# 277 q:mobley zero gravity adjustable bed with wireless remote -- pred:{'Bed & Bath', 'Furniture'} == expected:Bed & Bath
# 278 q:real touch roses floral arrangements in glass vase -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 279 q:led 60 -- pred:{'Lighting'} == expected:Lighting
# 282 q:odum velvet -- pred:{'Furniture'} == expected:Furniture
# 283 q:coat rack for bedroom -- pred:{'Contractor', 'Storage & Organization'} == expected:Contractor
# 284 Skipping malachi sled
# 284 q:body pillow and case -- pred:{'Bed & Bath'} == expected:Bed & Bath
# ***
# medium clips -- pred:{'Clips/Clamps'} != expected:Clips
# ['Clips/Clamps']
# 285 recall (N=208) -- 0.9375
# 286 q:rolande heavy duty power lift assist recliner -- pred:{'Furniture'} == expected:Furniture
# 287 q:hulmeville writing desk with hutch -- pred:{'Furniture'} == expected:Furniture
# 288 q:sunjoy lantern -- pred:{'Outdoor', 'Lighting'} == expected:Lighting
# 289 q:landis wall mounted bathroom shelves -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 290 q:blaylock bookcase headboard -- pred:{'Furniture'} == expected:Furniture
# 291 q:hussain handmade tufted magenta rug -- pred:{'Rugs'} == expected:Rugs
# 293 q:hub leaning full length mirror -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 294 q:chase utility laundry cart -- pred:{'Commercial Business Furniture', 'Storage & Organization'} == expected:Storage & Organization
# 295 q:outdoor waterproof chest -- pred:{'Outdoor', 'Storage & Organization'} == expected:Storage & Organization
# 296 q:bowersville ladder writing desk -- pred:{'Furniture'} == expected:Furniture
# 297 q:kohler purist brushed bronze -- pred:{'Home Improvement'} == expected:Home Improvement
# 298 q:golub dining table -- pred:{'Furniture'} == expected:Furniture
# 299 q:wayfair tension rod -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 300 q:kari 2 piece -- pred:{'Furniture'} == expected:Furniture
# 301 q:upholstered girls bed -- pred:{'Furniture', 'Baby & Kids'} == expected:Furniture
# 302 q:attleboro drum coffee table -- pred:{'Furniture'} == expected:Furniture
# 303 q:stainless steel colander set -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 304 Skipping itchington butterfly
# 304 Skipping canadian
# 304 q:mystic swivel -- pred:{'Furniture'} == expected:Furniture
# 305 q:iittala bowl -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 306 q:mahone porch rocking chair -- pred:{'Outdoor', 'Furniture'} == expected:Outdoor
# ***
# ruckus chair -- pred:{'Furniture'} != expected:School Furniture and Supplies
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Office Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs']
# 307 recall (N=229) -- 0.9388646288209607
# 308 q:berenice 4 storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 309 q:canvas map art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 310 q:brendon counter stool -- pred:{'Furniture'} == expected:Furniture
# 316 Skipping one alium way
# 318 Skipping amarillo
# ***
# pennfield playhouse -- pred:{'Baby & Kids'} != expected:
# ["Baby & Kids / Toddler & Kids Playroom / Indoor Play / Kids' Playhouses"]
# 318 recall (N=233) -- 0.9356223175965666
# 320 Skipping argenteuil
# 321 q:tall free standing pet gate -- pred:{'Pet'} == expected:Pet
# 323 q:french molding -- pred:{'Home Improvement'} == expected:Home Improvement
# 325 Skipping kisner
# 326 q:fortunat coffee table -- pred:{'Furniture'} == expected:Furniture
# 327 Skipping croscill ashton
# 327 Skipping gas detector
# 327 Skipping drudge report
# 327 q:wooden chair outdoor -- pred:{'Outdoor'} == expected:Outdoor
# 328 q:pasta tools -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 329 q:wrought tv stand -- pred:{'Furniture'} == expected:Furniture
# 330 q:rug for teen room -- pred:{'Rugs'} == expected:Rugs
# 331 q:milk cow chair -- pred:{'Furniture'} == expected:Furniture
# 332 Skipping verden callan
# 335 q:island estate coffee table -- pred:{'Furniture'} == expected:Furniture
# 339 Skipping gravity feeder
# 340 Skipping counter top one cup hot water dispenser
# 340 Skipping minnestrista
# 340 q:dining table vinyl cloth -- pred:{'Furniture', 'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 342 Skipping alter furniture
# 344 q:brush nickel faucet bathroom -- pred:{'Home Improvement'} == expected:Home Improvement
# 348 Skipping propane gas dryer
# 350 q:alyse 8 light -- pred:{'Lighting'} == expected:Lighting
# 353 Skipping 12v dirt bike
# 354 q:glass lsmp shades -- pred:{'Lighting'} == expected:Lighting
# 355 q:modern farmhouse lighting semi flush mount -- pred:{'Lighting'} == expected:Lighting
# 356 q:wood rack wide -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 359 Skipping refrigerator with ice an water in door
# 359 q:huge bookcase -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 360 q:girl reading statue -- pred:{'Outdoor', 'Décor & Pillows'} == expected:Outdoor
# 361 q:teal chair -- pred:{'Furniture'} == expected:Furniture
# 362 Skipping pool floats
# 363 q:jennie tufted upholstered low profile platform bed -- pred:{'Furniture'} == expected:Furniture
# 364 q:burruss patio sectional with cushions -- pred:{'Outdoor'} == expected:Outdoor
# 365 q:shower hooks -- pred:{'Bed & Bath', 'Home Improvement'} == expected:Bed & Bath
# 366 q:toilet paper stand -- pred:{'Home Improvement'} == expected:Home Improvement
# 369 q:writing desk -- pred:{'Furniture'} == expected:Furniture
# 371 q:tile backsplash -- pred:{'Home Improvement'} == expected:Home Improvement
# 372 q:dining room tables -- pred:{'Furniture'} == expected:Furniture
# 373 q:ergonomic chair -- pred:{'Furniture'} == expected:Furniture
# 374 q:wall shelves -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 375 q:wayfair comforters -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 376 q:side table with storage -- pred:{'Furniture'} == expected:Furniture
# 377 q:outdoor storage -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 381 q:30 inch bathroom vanity -- pred:{'Home Improvement'} == expected:Home Improvement
# 383 q:butcher block island -- pred:{'Furniture'} == expected:Furniture
# 384 q:trundle daybed -- pred:{'Furniture'} == expected:Furniture
# 385 q:bathroom lighting -- pred:{'Lighting'} == expected:Lighting
# 386 q:shoe closet -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 388 q:kitchen islands with seating -- pred:{'Furniture'} == expected:Furniture
# 390 q:parsons chairs -- pred:{'Furniture'} == expected:Furniture
# 391 q:wood bar stools -- pred:{'Furniture'} == expected:Furniture
# 392 q:desk for kids -- pred:{'Baby & Kids'} == expected:Baby & Kids
# 393 q:above toilet cabinet -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 395 q:outdoor lounge chair -- pred:{'Outdoor'} == expected:Outdoor
# 396 q:chaise lounge couch -- pred:{'Furniture'} == expected:Furniture
# 397 q:card table -- pred:{'Furniture'} == expected:Furniture
# 398 q:tall buffet cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 399 q:bed side table -- pred:{'Furniture'} == expected:Furniture
# 403 q:midcentury tv unit -- pred:{'Furniture'} == expected:Furniture
# 405 q:deer coat hooks -- pred:{'Home Improvement', 'Contractor'} == expected:Contractor
# 406 q:wall design shelf -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 409 q:tye dye duvet cover -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 410 q:small wardrobe grey -- pred:{'Furniture'} == expected:Furniture
# 411 Skipping luau string lights
# 412 q:bistro sets patio -- pred:{'Outdoor'} == expected:Outdoor
# 413 q:cake cutlery -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 414 q:white abstract -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# ***
# rock climbing wall kids -- pred:{'Outdoor', 'Baby & Kids'} != expected:Holiday Décor
# ['Outdoor / Outdoor Recreation / Backyard Play / Climbing Toys & Slides', "Baby & Kids / Toddler & Kids Playroom / Indoor Play / Kids' Playhouses"]
# 415 recall (N=287) -- 0.9442508710801394
# 417 q:glow in the dark silent wall clock -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 418 q:garage sports storage rack -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 420 q:adjustable height artist stool -- pred:{'Furniture'} == expected:Furniture
# 421 q:window wall accent -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 424 Skipping rattan truck
# 425 q:worn leather office chair -- pred:{'Furniture'} == expected:Furniture
# 426 Skipping garage door mail slot
# ***
# emma headboard -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 427 recall (N=293) -- 0.9419795221843004
# 428 q:48 inch kitchen hood -- pred:{'Appliances'} == expected:Appliances
# 429 q:rustic twig -- pred:{'Outdoor', 'Décor & Pillows'} == expected:Décor & Pillows
# 430 Skipping nespresso vertuo next premium by breville with aeroccino
# 0.9423728813559322

# %%
def recall_all(categorized, ground_truth):
    """When we retrieve a category, is it correct?"""
    hits = []
    misses = []
    idx = 0
    for _, row in ground_truth.sample(frac=1).iterrows():
        query = row['query']
        expected_category = row['category']

        cat = categorized(query)
        if len(cat.classifications) == 0:
            print(f"{idx} Skipping {query}")
            continue
        # ***
        # Now also consider this a miss, we should not have predicted any caterogies
        if expected_category == "No Category Fits" and len(cat.categories) > 0:
            print("!**")
            print(f"{query} -- pred:{cat.categories} != expected:{expected_category.strip()}")
            print(cat.classifications)
            misses.append((expected_category, cat))
            num_so_far = len(hits) + len(misses)
            print(f"{idx} recall (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
        if expected_category.strip() in cat.categories:
            print(f"{idx} q:{query} -- pred:{cat.categories} == expected:{expected_category.strip()}")
            hits.append((expected_category, cat))
        else:
            print("***")
            print(f"{query} -- pred:{cat.categories} != expected:{expected_category.strip()}")
            print(cat.classifications)
            misses.append((expected_category, cat))
            num_so_far = len(hits) + len(misses)
            print(f"{idx} recall (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
        idx += 1

    return len(hits) / (len(hits) + len(misses)), hits, misses

recall, hits, misses = recall_all(fully_classified, ground_truth_cat)
recall
# Out:
# 0 q:hussain handmade tufted magenta rug -- pred:{'Rugs'} == expected:Rugs
# 1 q:golub dining table -- pred:{'Furniture'} == expected:Furniture
# 2 q:hulmeville writing desk with hutch -- pred:{'Furniture'} == expected:Furniture
# 3 q:tile backsplash -- pred:{'Home Improvement'} == expected:Home Improvement
# 4 q:ombre rug -- pred:{'Rugs'} == expected:Rugs
# !**
# acrylic clear chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Office Chairs', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs']
# 5 recall (N=6) -- 0.8333333333333334
# ***
# acrylic clear chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Office Chairs', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs']
# 5 recall (N=7) -- 0.7142857142857143
# !**
# blue faux throw with pillows -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Blue Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 6 recall (N=8) -- 0.625
# ***
# blue faux throw with pillows -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Blue Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 6 recall (N=9) -- 0.5555555555555556
# 7 q:multi color rug -- pred:{'Rugs'} == expected:Rugs
# 8 q:card table -- pred:{'Furniture'} == expected:Furniture
# !**
# porcelain loaf pan -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans']
# 9 recall (N=12) -- 0.5833333333333334
# ***
# porcelain loaf pan -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans']
# 9 recall (N=13) -- 0.5384615384615384
# 10 q:block coffee table -- pred:{'Furniture'} == expected:Furniture
# 11 q:kelly clarkson light fixtures -- pred:{'Lighting'} == expected:Lighting
# !**
# oriental vanity -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities']
# 12 recall (N=16) -- 0.5625
# ***
# oriental vanity -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities']
# 12 recall (N=17) -- 0.5294117647058824
# 13 q:hub leaning full length mirror -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# ***
# burnt orange curtains -- pred:{'Décor & Pillows'} != expected:Rugs
# ['Décor & Pillows / Window Treatments / Curtains & Drapes', 'Décor & Pillows / Window Treatments / Curtains & Drapes / 90 Inch Curtains & Drapes', 'Décor & Pillows / Window Treatments / Curtains & Drapes / 63 Inch and Less Curtains & Drapes']
# 14 recall (N=19) -- 0.5263157894736842
# 15 q:wainscoting ideas -- pred:{'Home Improvement'} == expected:Home Improvement
# 16 q:kohen 5 drawer dresser -- pred:{'Furniture'} == expected:Furniture
# 17 q:bar stool with backrest -- pred:{'Furniture'} == expected:Furniture
# 18 q:chase utility laundry cart -- pred:{'Commercial Business Furniture', 'Storage & Organization'} == expected:Storage & Organization
# !**
# huntsville sectional sofa -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sectionals', 'Furniture / Living Room Furniture / Sofas']
# 19 recall (N=24) -- 0.5833333333333334
# ***
# huntsville sectional sofa -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sectionals', 'Furniture / Living Room Furniture / Sofas']
# 19 recall (N=25) -- 0.56
# !**
# bubble guppies chair -- pred:{'Furniture', 'Baby & Kids'} != expected:No Category Fits
# ['Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 20 recall (N=26) -- 0.5384615384615384
# ***
# bubble guppies chair -- pred:{'Furniture', 'Baby & Kids'} != expected:No Category Fits
# ['Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 20 recall (N=27) -- 0.5185185185185185
# 21 q:picasso -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 22 Skipping propane gas dryer
# 22 q:outdoor waterproof chest -- pred:{'Outdoor', 'Storage & Organization'} == expected:Storage & Organization
# 23 q:body pillow case -- pred:{'Bed & Bath', 'Décor & Pillows'} == expected:Bed & Bath
# 24 q:orren ellis l shape desk -- pred:{'Furniture'} == expected:Furniture
# 25 q:rolande heavy duty power lift assist recliner -- pred:{'Furniture'} == expected:Furniture
# 26 q:medium size chandelier -- pred:{'Lighting'} == expected:Lighting
# !**
# pastel pink desk chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Furniture / Office Furniture / Office Chairs / Task Office Chairs', 'Furniture / Office Furniture / Office Chairs / Task Office Chairs']
# 27 recall (N=34) -- 0.5882352941176471
# ***
# pastel pink desk chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Furniture / Office Furniture / Office Chairs / Task Office Chairs', 'Furniture / Office Furniture / Office Chairs / Task Office Chairs']
# 27 recall (N=35) -- 0.5714285714285714
# 28 q:30 inch bathroom vanity -- pred:{'Home Improvement'} == expected:Home Improvement
# 29 Skipping promo codes or discounts
# 29 q:huge bookcase -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 30 q:zodiac pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# white bathroom vanity black hardware -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 31 recall (N=39) -- 0.5897435897435898
# ***
# white bathroom vanity black hardware -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 31 recall (N=40) -- 0.575
# 32 q:sheets for twinxl -- pred:{'Bed & Bath'} == expected:Bed & Bath
# !**
# wayfair coffee table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Round Coffee Tables']
# 33 recall (N=42) -- 0.5714285714285714
# ***
# wayfair coffee table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Round Coffee Tables']
# 33 recall (N=43) -- 0.5581395348837209
# 34 Skipping alter furniture
# 34 q:decorative white pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# ottoman bed queen -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds', 'Furniture / Living Room Furniture / Ottomans & Poufs']
# 35 recall (N=45) -- 0.5555555555555556
# ***
# ottoman bed queen -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds', 'Furniture / Living Room Furniture / Ottomans & Poufs']
# 35 recall (N=46) -- 0.5434782608695652
# !**
# welcome sign -- pred:{'Outdoor', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Outdoor / Outdoor Décor / Outdoor Wall Décor']
# 36 recall (N=47) -- 0.5319148936170213
# ***
# welcome sign -- pred:{'Outdoor', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Outdoor / Outdoor Décor / Outdoor Wall Décor']
# 36 recall (N=48) -- 0.5208333333333334
# !**
# pull out sleeper loveseat -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Living Room Sets', 'Furniture / Living Room Furniture / Sectionals']
# 37 recall (N=49) -- 0.5102040816326531
# ***
# pull out sleeper loveseat -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Living Room Sets', 'Furniture / Living Room Furniture / Sectionals']
# 37 recall (N=50) -- 0.5
# 38 q:calvin patio chair -- pred:{'Outdoor'} == expected:Outdoor
# 39 q:adjustable height artist stool -- pred:{'Furniture'} == expected:Furniture
# 40 Skipping pool floats
# !**
# olive green console table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Console Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables', 'Furniture / Living Room Furniture / Cabinets & Chests']
# 40 recall (N=53) -- 0.5094339622641509
# ***
# olive green console table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Console Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables', 'Furniture / Living Room Furniture / Cabinets & Chests']
# 40 recall (N=54) -- 0.5
# !**
# 3/4 size mattress -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Mattresses & Foundations / Innerspring Mattresses', 'Bed & Bath / Mattresses & Foundations / Adjustable Beds', 'Bed & Bath / Mattresses & Foundations / Queen Mattresses']
# 41 recall (N=55) -- 0.4909090909090909
# ***
# 3/4 size mattress -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Mattresses & Foundations / Innerspring Mattresses', 'Bed & Bath / Mattresses & Foundations / Adjustable Beds', 'Bed & Bath / Mattresses & Foundations / Queen Mattresses']
# 41 recall (N=56) -- 0.48214285714285715
# 42 q:smart coffee table -- pred:{'Furniture'} == expected:Furniture
# 43 q:kids chair -- pred:{'Baby & Kids'} == expected:Baby & Kids
# !**
# mud room sign -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Décor & Pillows / Wall Décor / Wall Decals', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 44 recall (N=59) -- 0.4915254237288136
# ***
# mud room sign -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Décor & Pillows / Wall Décor / Wall Decals', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 44 recall (N=60) -- 0.48333333333333334
# 45 q:turquoise chair -- pred:{'Furniture'} == expected:Furniture
# 46 q:driftwood mirror -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# nautical platters -- pred:{'Kitchen & Tabletop', 'Décor & Pillows'} != expected:No Category Fits
# ['Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters', 'Décor & Pillows / Home Accessories / Decorative Trays']
# 47 recall (N=63) -- 0.49206349206349204
# ***
# nautical platters -- pred:{'Kitchen & Tabletop', 'Décor & Pillows'} != expected:No Category Fits
# ['Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters', 'Décor & Pillows / Home Accessories / Decorative Trays']
# 47 recall (N=64) -- 0.484375
# 48 Skipping merlyn 6
# 48 q:48 inch kitchen hood -- pred:{'Appliances'} == expected:Appliances
# 49 q:broadway lever -- pred:{'Home Improvement'} == expected:Home Improvement
# 50 q:milk cow chair -- pred:{'Furniture'} == expected:Furniture
# ***
# sugar canister -- pred:{'Kitchen & Tabletop'} != expected:
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Ceramic Kitchen Canisters & Jars', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars']
# 51 recall (N=68) -- 0.5
# !**
# shoe bench entryway -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks', 'Furniture / Living Room Furniture / Chairs & Seating / Benches', 'Storage & Organization / Shoe Storage / All Shoe Storage / Rack Shoe Storage']
# 52 recall (N=69) -- 0.4927536231884058
# ***
# shoe bench entryway -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks', 'Furniture / Living Room Furniture / Chairs & Seating / Benches', 'Storage & Organization / Shoe Storage / All Shoe Storage / Rack Shoe Storage']
# 52 recall (N=70) -- 0.4857142857142857
# 53 q:hillsby oriental rug -- pred:{'Rugs'} == expected:Rugs
# 54 q:clear shower curtain -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 55 q:music plug wall plate -- pred:{'Home Improvement'} == expected:Home Improvement
# 56 Skipping zachary 72.5
# !**
# china clock -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Clocks / Wall Clocks', 'Décor & Pillows / Clocks / Mantel & Tabletop Clocks']
# 56 recall (N=74) -- 0.5
# ***
# china clock -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Clocks / Wall Clocks', 'Décor & Pillows / Clocks / Mantel & Tabletop Clocks']
# 56 recall (N=75) -- 0.49333333333333335
# 57 Skipping canadian
# 57 q:accent leather chair -- pred:{'Furniture'} == expected:Furniture
# 58 q:chrome shower head and valve -- pred:{'Home Improvement'} == expected:Home Improvement
# 59 q:mobley zero gravity adjustable bed with wireless remote -- pred:{'Bed & Bath', 'Furniture'} == expected:Bed & Bath
# 60 q:sheffield home bath set -- pred:{'Bed & Bath', 'Home Improvement'} == expected:Home Improvement
# !**
# full bed with trundle -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 61 recall (N=80) -- 0.5125
# ***
# full bed with trundle -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 61 recall (N=81) -- 0.5061728395061729
# !**
# kitchen storage cabinet -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves', 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets', 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units']
# 62 recall (N=82) -- 0.5
# ***
# kitchen storage cabinet -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves', 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets', 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units']
# 62 recall (N=83) -- 0.4939759036144578
# !**
# living room ideas -- pred:{'Lighting', 'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Art / All Wall Art', 'Lighting / Ceiling Lights / Chandeliers']
# 63 recall (N=84) -- 0.4880952380952381
# ***
# living room ideas -- pred:{'Lighting', 'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Art / All Wall Art', 'Lighting / Ceiling Lights / Chandeliers']
# 63 recall (N=85) -- 0.4823529411764706
# 64 q:wine bar -- pred:{'Furniture'} == expected:Furniture
# 65 q:46 inch closet door -- pred:{'Home Improvement'} == expected:Home Improvement
# 66 q:midcentury tv unit -- pred:{'Furniture'} == expected:Furniture
# !**
# light wood nightstand with silver accents -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Nightstands', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 67 recall (N=89) -- 0.4943820224719101
# ***
# light wood nightstand with silver accents -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Nightstands', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 67 recall (N=90) -- 0.4888888888888889
# 68 q:kitchen anti fatigue mats -- pred:{'Rugs'} == expected:Rugs
# 69 q:dining table vinyl cloth -- pred:{'Furniture', 'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# !**
# stoneford end tables white and wood -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables']
# 70 recall (N=93) -- 0.4946236559139785
# ***
# stoneford end tables white and wood -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables']
# 70 recall (N=94) -- 0.48936170212765956
# 71 q:leather dining chairs -- pred:{'Furniture'} == expected:Furniture
# 72 q:podium with locking cabinet -- pred:{'Furniture', 'School Furniture and Supplies'} == expected:School Furniture and Supplies
# 73 q:love seat wide faux leather tuxedo arm sofa -- pred:{'Furniture'} == expected:Furniture
# !**
# auburn throw pillows -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Black Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / White Throw Pillows']
# 74 recall (N=98) -- 0.5
# ***
# auburn throw pillows -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Black Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / White Throw Pillows']
# 74 recall (N=99) -- 0.494949494949495
# 75 q:storage dresser -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# !**
# writing desk 48" -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks / Writing Desks']
# 76 recall (N=101) -- 0.49504950495049505
# ***
# writing desk 48" -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks / Writing Desks']
# 76 recall (N=102) -- 0.49019607843137253
# 77 q:artificial orchid arrangement -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# candace wingback upholstered bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 78 recall (N=104) -- 0.49038461538461536
# ***
# candace wingback upholstered bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 78 recall (N=105) -- 0.4857142857142857
# 79 Skipping lunch bag
# 79 q:gowdy height adjustable standing desk -- pred:{'Furniture'} == expected:Furniture
# 80 Skipping bed risers
# 80 q:bathroom vanity knobs -- pred:{'Home Improvement'} == expected:Home Improvement
# !**
# fawkes 36" blue vanity -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities']
# 81 recall (N=108) -- 0.49074074074074076
# ***
# fawkes 36" blue vanity -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities']
# 81 recall (N=109) -- 0.48623853211009177
# 82 q:anchor decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# outdoor movie screen -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Inflatable Projection Screens', 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Folding Frame Projection Screens']
# 83 recall (N=111) -- 0.4864864864864865
# ***
# outdoor movie screen -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Inflatable Projection Screens', 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Folding Frame Projection Screens']
# 83 recall (N=112) -- 0.48214285714285715
# 84 q:king size bed -- pred:{'Furniture'} == expected:Furniture
# 85 Skipping minnestrista
# !**
# trinaic towel rod -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel Bars, Racks, and Stands / Metal Towel Bars, Racks, and Stands', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks']
# 85 recall (N=114) -- 0.4824561403508772
# ***
# trinaic towel rod -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel Bars, Racks, and Stands / Metal Towel Bars, Racks, and Stands', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks']
# 85 recall (N=115) -- 0.4782608695652174
# 86 q:dolomite subway tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 87 Skipping monthly calendar
# 87 q:stainless steel colander set -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 88 q:berenice 4 storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 89 q:fold in half table -- pred:{'Storage & Organization', 'Furniture', 'School Furniture and Supplies'} == expected:School Furniture and Supplies
# 90 q:shower hooks -- pred:{'Bed & Bath', 'Home Improvement'} == expected:Bed & Bath
# 91 q:garage sports storage rack -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 92 Skipping white splashproof shiplap wallpaper
# !**
# arched christmas tree -- pred:{'Holiday Décor'} != expected:No Category Fits
# ['Holiday Décor / Christmas / Christmas Trees / All Christmas Trees']
# 92 recall (N=122) -- 0.5
# ***
# arched christmas tree -- pred:{'Holiday Décor'} != expected:No Category Fits
# ['Holiday Décor / Christmas / Christmas Trees / All Christmas Trees']
# 92 recall (N=123) -- 0.4959349593495935
# 93 Skipping bathroom wastebasket
# 93 q:canvas map art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 94 q:small wardrobe grey -- pred:{'Furniture'} == expected:Furniture
# 95 q:end table between recliners -- pred:{'Furniture'} == expected:Furniture
# !**
# wand bunk beds -- pred:{'Furniture', 'Baby & Kids'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds']
# 96 recall (N=127) -- 0.5039370078740157
# ***
# wand bunk beds -- pred:{'Furniture', 'Baby & Kids'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds']
# 96 recall (N=128) -- 0.5
# 97 q:non slip shower floor tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 98 q:chinese flower stand -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} == expected:Furniture
# 99 q:farmhouse bread box -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 100 q:closet pull out valet rod -- pred:{'Storage & Organization'} == expected:Storage & Organization
# !**
# flamingo -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 101 recall (N=133) -- 0.5112781954887218
# ***
# flamingo -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 101 recall (N=134) -- 0.5074626865671642
# !**
# 54 in bench cushion -- pred:{'Outdoor', 'Décor & Pillows'} != expected:No Category Fits
# ['Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions', 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Dining Chair Patio Furniture Cushions', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 102 recall (N=135) -- 0.5037037037037037
# ***
# 54 in bench cushion -- pred:{'Outdoor', 'Décor & Pillows'} != expected:No Category Fits
# ['Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions', 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Dining Chair Patio Furniture Cushions', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 102 recall (N=136) -- 0.5
# 103 q:bar stool 24 inches height -- pred:{'Furniture'} == expected:Furniture
# 104 q:seat cushions desk -- pred:{'Furniture'} == expected:Furniture
# ***
# emma headboard -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 105 recall (N=139) -- 0.5035971223021583
# 106 q:bistro table and chairs -- pred:{'Outdoor', 'Furniture'} == expected:Outdoor
# 107 Skipping gas detector
# 107 q:dark gray dresser -- pred:{'Furniture'} == expected:Furniture
# 108 Skipping oliver parsons
# 108 q:penny round tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 109 Skipping dinosaur
# 109 q:teal chair -- pred:{'Furniture'} == expected:Furniture
# 110 Skipping refrigerator with ice an water in door
# 110 q:home sweet home sign -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 111 q:iittala bowl -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# !**
# laundry vanity cabinet -- pred:{'Home Improvement', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Bathroom Storage & Organization / Bathroom Cabinets & Shelving', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities']
# 112 recall (N=146) -- 0.5205479452054794
# ***
# laundry vanity cabinet -- pred:{'Home Improvement', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Bathroom Storage & Organization / Bathroom Cabinets & Shelving', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities']
# 112 recall (N=147) -- 0.5170068027210885
# 113 q:novara pergola -- pred:{'Outdoor'} == expected:Outdoor
# 114 Skipping amarillo
# 114 q:leather chair -- pred:{'Furniture'} == expected:Furniture
# !**
# westling coffee table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables']
# 115 recall (N=150) -- 0.52
# ***
# westling coffee table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables']
# 115 recall (N=151) -- 0.5165562913907285
# !**
# meade mirror -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Mirrors / All Mirrors / Accent Mirrors', 'Décor & Pillows / Mirrors / All Mirrors / Leaning & Floor Mirrors']
# 116 recall (N=152) -- 0.5131578947368421
# ***
# meade mirror -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Mirrors / All Mirrors / Accent Mirrors', 'Décor & Pillows / Mirrors / All Mirrors / Leaning & Floor Mirrors']
# 116 recall (N=153) -- 0.5098039215686274
# 117 q:animal print handmade tufted wool beige/black area rug by allmodern -- pred:{'Rugs'} == expected:Rugs
# 118 Skipping kisner
# 118 q:hinged square ottoman -- pred:{'Furniture'} == expected:Furniture
# 119 q:glass lsmp shades -- pred:{'Lighting'} == expected:Lighting
# 120 q:eiffel tower wall art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# wayfair sleep zippered -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / Sheets & Pillowcases', 'Bed & Bath / Bedding Essentials / Mattress Pads & Toppers', 'Bed & Bath / Bedding Essentials / Bed Pillows']
# 121 recall (N=158) -- 0.5189873417721519
# ***
# wayfair sleep zippered -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / Sheets & Pillowcases', 'Bed & Bath / Bedding Essentials / Mattress Pads & Toppers', 'Bed & Bath / Bedding Essentials / Bed Pillows']
# 121 recall (N=159) -- 0.5157232704402516
# !**
# mid century modern -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Office Furniture / Desks']
# 122 recall (N=160) -- 0.5125
# ***
# mid century modern -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Office Furniture / Desks']
# 122 recall (N=161) -- 0.5093167701863354
# !**
# moen matte black hooks -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 123 recall (N=162) -- 0.5061728395061729
# ***
# moen matte black hooks -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 123 recall (N=163) -- 0.5030674846625767
# 124 Skipping cake plates with tops
# 124 q:blaylock bookcase headboard -- pred:{'Furniture'} == expected:Furniture
# 125 q:industrial pipe dining  table -- pred:{'Furniture'} == expected:Furniture
# 126 q:modern farmhouse lighting semi flush mount -- pred:{'Lighting'} == expected:Lighting
# !**
# delta trinsic double towel hook in champagne bronze -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Brass Cabinet & Drawer Pulls', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Brass Cabinet & Drawer Knobs']
# 127 recall (N=167) -- 0.5089820359281437
# ***
# delta trinsic double towel hook in champagne bronze -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Brass Cabinet & Drawer Pulls', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Brass Cabinet & Drawer Knobs']
# 127 recall (N=168) -- 0.5059523809523809
# 128 q:rooster decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# !**
# pedistole sink -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets']
# 129 recall (N=170) -- 0.5058823529411764
# ***
# pedistole sink -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets']
# 129 recall (N=171) -- 0.5029239766081871
# ***
# full metal bed rose gold -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames']
# 130 recall (N=172) -- 0.5
# !**
# sunflower -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Flowers & Plants / Faux Flowers', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 131 recall (N=173) -- 0.49710982658959535
# ***
# sunflower -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Flowers & Plants / Faux Flowers', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 131 recall (N=174) -- 0.4942528735632184
# 132 q:chaise lounge couch -- pred:{'Furniture'} == expected:Furniture
# !**
# marble -- pred:{'Home Improvement', 'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables']
# 133 recall (N=176) -- 0.4943181818181818
# ***
# marble -- pred:{'Home Improvement', 'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables']
# 133 recall (N=177) -- 0.4915254237288136
# 134 q:body pillow and case -- pred:{'Bed & Bath'} == expected:Bed & Bath
# !**
# royal blue counter height chairs -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools / Counter (24-27) Bar Stools & Counter Stools', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs / Side Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 135 recall (N=179) -- 0.49162011173184356
# ***
# royal blue counter height chairs -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools / Counter (24-27) Bar Stools & Counter Stools', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs / Side Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 135 recall (N=180) -- 0.4888888888888889
# 136 q:almost heaven sauna -- pred:{'Outdoor'} == expected:Outdoor
# 137 q:small curtain rods -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 138 q:outdoor privacy wall -- pred:{'Outdoor'} == expected:Outdoor
# 139 q:comfortable accent chair -- pred:{'Furniture'} == expected:Furniture
# !**
# hitchcock mid-century wall shelf -- pred:{'Décor & Pillows', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves', 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves / Floating Wall & Display Shelves', 'Décor & Pillows / Wall Décor / Wall Accents']
# 140 recall (N=185) -- 0.4972972972972973
# ***
# hitchcock mid-century wall shelf -- pred:{'Décor & Pillows', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves', 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves / Floating Wall & Display Shelves', 'Décor & Pillows / Wall Décor / Wall Accents']
# 140 recall (N=186) -- 0.4946236559139785
# !**
# togo chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Chaise Lounge Chairs']
# 141 recall (N=187) -- 0.4919786096256685
# ***
# togo chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Chaise Lounge Chairs']
# 141 recall (N=188) -- 0.48936170212765956
# 142 q:decorative wall clocks -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 143 q:rose gold lounge -- pred:{'Furniture'} == expected:Furniture
# 144 q:led light strip -- pred:{'Lighting'} == expected:Lighting
# 145 q:beds that have leds -- pred:{'Furniture'} == expected:Furniture
# 146 q:modern outdoor furniture -- pred:{'Outdoor'} == expected:Outdoor
# 147 q:led 60 -- pred:{'Lighting'} == expected:Lighting
# 148 q:low profile loveseat recliner -- pred:{'Furniture'} == expected:Furniture
# 149 q:bar room wall decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 150 q:wall design shelf -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 151 q:front porch furniture sets -- pred:{'Outdoor'} == expected:Outdoor
# 152 q:tye dye duvet cover -- pred:{'Bed & Bath'} == expected:Bed & Bath
# !**
# dull bed with shirt head board -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 153 recall (N=200) -- 0.515
# ***
# dull bed with shirt head board -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 153 recall (N=201) -- 0.5124378109452736
# !**
# coffee container -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers']
# 154 recall (N=202) -- 0.5099009900990099
# ***
# coffee container -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers']
# 154 recall (N=203) -- 0.5073891625615764
# 155 q:fortunat coffee table -- pred:{'Furniture'} == expected:Furniture
# 156 q:cake cutlery -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# ***
# high weight capacity bunk beds -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds']
# 157 recall (N=206) -- 0.5097087378640777
# 158 q:cloud modular sectional -- pred:{'Furniture'} == expected:Furniture
# 159 q:outdoor light fixtures -- pred:{'Lighting'} == expected:Lighting
# !**
# 7 draw white dresser -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 160 recall (N=209) -- 0.5119617224880383
# ***
# 7 draw white dresser -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 160 recall (N=210) -- 0.5095238095238095
# 161 q:arwen table lamp -- pred:{'Lighting'} == expected:Lighting
# !**
# gray leather cocktail table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables']
# 162 recall (N=212) -- 0.5094339622641509
# ***
# gray leather cocktail table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables']
# 162 recall (N=213) -- 0.5070422535211268
# 163 q:ligth bulb -- pred:{'Lighting'} == expected:Lighting
# 164 q:tufted chair with gold legs -- pred:{'Furniture'} == expected:Furniture
# 165 q:48" sliding single track , barn door for laundry -- pred:{'Home Improvement'} == expected:Home Improvement
# !**
# mila task chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs / Task Office Chairs', 'Furniture / Office Furniture / Office Chairs']
# 166 recall (N=217) -- 0.511520737327189
# ***
# mila task chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs / Task Office Chairs', 'Furniture / Office Furniture / Office Chairs']
# 166 recall (N=218) -- 0.5091743119266054
# 167 q:waterfall faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 168 q:kraus kitchen sink faucet oletto kpf 2820 sfs -- pred:{'Home Improvement'} == expected:Home Improvement
# 169 Skipping malachi sled
# 169 q:front door cabinet with doors -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# !**
# tall storage cabinet -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves', 'Furniture / Living Room Furniture / Cabinets & Chests', 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units']
# 170 recall (N=222) -- 0.5135135135135135
# ***
# tall storage cabinet -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves', 'Furniture / Living Room Furniture / Cabinets & Chests', 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units']
# 170 recall (N=223) -- 0.5112107623318386
# 171 q:bedroom wall decor floral, multicolored with some teal (prints) -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 172 q:trundle daybed -- pred:{'Furniture'} == expected:Furniture
# 173 q:odum velvet -- pred:{'Furniture'} == expected:Furniture
# !**
# sinks bed frame -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets', 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames']
# 174 recall (N=227) -- 0.5154185022026432
# ***
# sinks bed frame -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets', 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames']
# 174 recall (N=228) -- 0.5131578947368421
# 175 q:chair and a half recliner -- pred:{'Furniture'} == expected:Furniture
# 176 q:bathroom vanity with counter space -- pred:{'Home Improvement'} == expected:Home Improvement
# 177 q:elegant executive chair -- pred:{'Furniture'} == expected:Furniture
# ***
# coffee table fire pit -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor Décor / Outdoor Fountains']
# 178 recall (N=232) -- 0.5172413793103449
# 179 q:white abstract -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 180 Skipping gravity feeder
# !**
# biycicle plant stands -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Outdoor / Garden / Plant Stands & Accessories', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables']
# 180 recall (N=234) -- 0.5170940170940171
# ***
# biycicle plant stands -- pred:{'Outdoor', 'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Outdoor / Garden / Plant Stands & Accessories', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables']
# 180 recall (N=235) -- 0.5148936170212766
# 181 q:alyse 8 light -- pred:{'Lighting'} == expected:Lighting
# 182 q:anti fatigue mat -- pred:{'Rugs'} == expected:Rugs
# !**
# osgood mirror -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ...
# 369 recall (N=487) -- 0.4887063655030801
# ***
# gray dresser -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests', 'Furniture / Bedroom Furniture / Dressers & Chests / Beige Dressers & Chests']
# 369 recall (N=488) -- 0.48770491803278687
# 370 q:boho bed frame -- pred:{'Furniture'} == expected:Furniture
# 371 q:landis wall mounted bathroom shelves -- pred:{'Storage & Organization'} == expected:Storage & Organization
# !**
# maryford queen tufted bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 372 recall (N=491) -- 0.48879837067209775
# ***
# maryford queen tufted bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 372 recall (N=492) -- 0.4878048780487805
# 373 q:deer coat hooks -- pred:{'Home Improvement', 'Contractor'} == expected:Contractor
# ***
# rock climbing wall kids -- pred:{'Outdoor', 'Baby & Kids'} != expected:Holiday Décor
# ['Outdoor / Outdoor Recreation / Backyard Play / Climbing Toys & Slides', "Baby & Kids / Toddler & Kids Playroom / Indoor Play / Kids' Playhouses"]
# 374 recall (N=494) -- 0.48785425101214575
# 375 q:edge chair mat -- pred:{'Furniture'} == expected:Furniture
# 376 q:fleur de lis living candle wall sconce bronze -- pred:{'Lighting', 'Décor & Pillows'} == expected:Décor & Pillows
# 377 Skipping itchington butterfly
# !**
# nesting tray set -- pred:{'Kitchen & Tabletop', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Trays', 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters']
# 377 recall (N=497) -- 0.48893360160965793
# ***
# nesting tray set -- pred:{'Kitchen & Tabletop', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Trays', 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters']
# 377 recall (N=498) -- 0.4879518072289157
# !**
# black frame 22 x 36 -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Picture Frames & Albums / All Picture Frames']
# 378 recall (N=499) -- 0.48697394789579157
# ***
# black frame 22 x 36 -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Picture Frames & Albums / All Picture Frames']
# 378 recall (N=500) -- 0.486
# 379 q:burruss patio sectional with cushions -- pred:{'Outdoor'} == expected:Outdoor
# !**
# family lamp -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Table & Floor Lamps / Floor Lamps', 'Lighting / Table & Floor Lamps / Table Lamps', 'Lighting / Ceiling Lights / All Ceiling Lights']
# 380 recall (N=502) -- 0.4860557768924303
# ***
# family lamp -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Table & Floor Lamps / Floor Lamps', 'Lighting / Table & Floor Lamps / Table Lamps', 'Lighting / Ceiling Lights / All Ceiling Lights']
# 380 recall (N=503) -- 0.4850894632206759
# 381 q:wayfair tension rod -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 382 q:outdoor sectional dining -- pred:{'Outdoor'} == expected:Outdoor
# 383 q:whimsical solar lights -- pred:{'Lighting'} == expected:Lighting
# !**
# urban outfitters duvet -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding', 'Bed & Bath / Bedding / Sheets & Pillowcases']
# 384 recall (N=507) -- 0.48717948717948717
# ***
# urban outfitters duvet -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding', 'Bed & Bath / Bedding / Sheets & Pillowcases']
# 384 recall (N=508) -- 0.4862204724409449
# !**
# super bright lights -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / All Ceiling Lights', 'Lighting / Wall Lights / Wall Sconces', 'Lighting / Outdoor Lighting / Outdoor Wall Lighting']
# 385 recall (N=509) -- 0.48526522593320237
# ***
# super bright lights -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / All Ceiling Lights', 'Lighting / Wall Lights / Wall Sconces', 'Lighting / Outdoor Lighting / Outdoor Wall Lighting']
# 385 recall (N=510) -- 0.4843137254901961
# !**
# aiden black velvet bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 386 recall (N=511) -- 0.48336594911937375
# ***
# aiden black velvet bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 386 recall (N=512) -- 0.482421875
# !**
# donaldson teak couch -- pred:{'Outdoor', 'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals']
# 387 recall (N=513) -- 0.48148148148148145
# ***
# donaldson teak couch -- pred:{'Outdoor', 'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals']
# 387 recall (N=514) -- 0.4805447470817121
# !**
# moen 5995 arbor one -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Chrome Kitchen Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets']
# 388 recall (N=515) -- 0.4796116504854369
# ***
# moen 5995 arbor one -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Chrome Kitchen Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets']
# 388 recall (N=516) -- 0.4786821705426357
# 389 q:floating bed -- pred:{'Furniture'} == expected:Furniture
# 390 q:rustic twig -- pred:{'Outdoor', 'Décor & Pillows'} == expected:Décor & Pillows
# 391 q:sunjoy lantern -- pred:{'Outdoor', 'Lighting'} == expected:Lighting
# 392 q:retractable side awning -- pred:{'Outdoor'} == expected:Outdoor
# 393 Skipping owl
# 393 q:70s inspired furniture -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# !**
# desk and chair set -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks', 'Furniture / Office Furniture / Office Chairs', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs']
# 394 recall (N=522) -- 0.4827586206896552
# ***
# desk and chair set -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks', 'Furniture / Office Furniture / Office Chairs', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs']
# 394 recall (N=523) -- 0.4818355640535373
# 395 q:kohler whitehaven farmhouse kitchen sink -- pred:{'Home Improvement'} == expected:Home Improvement
# 396 q:papasan chair frame only -- pred:{'Furniture'} == expected:Furniture
# !**
# pictures to hang over fireplace -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Wall Décor / Wall Accents']
# 397 recall (N=526) -- 0.4828897338403042
# ***
# pictures to hang over fireplace -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Wall Décor / Wall Accents']
# 397 recall (N=527) -- 0.4819734345351044
# !**
# cliffside 5 light candle style drum chandelier -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / Chandeliers']
# 398 recall (N=528) -- 0.4810606060606061
# ***
# cliffside 5 light candle style drum chandelier -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / Chandeliers']
# 398 recall (N=529) -- 0.48015122873345933
# ***
# pennfield playhouse -- pred:{'Baby & Kids'} != expected:
# ["Baby & Kids / Toddler & Kids Playroom / Indoor Play / Kids' Playhouses"]
# 399 recall (N=530) -- 0.47924528301886793
# 400 q:overstreet rustic pub stools -- pred:{'Furniture'} == expected:Furniture
# !**
# large bases -- pred:{'Outdoor', 'Décor & Pillows'} != expected:No Category Fits
# ['Outdoor / Outdoor Shades / Outdoor Umbrellas / Patio Umbrella Stands & Bases', 'Décor & Pillows / Candles & Holders / Candle Holders / Sconce Candle Holders', 'Décor & Pillows / Home Accessories / Vases, Urns, Jars & Bottles']
# 401 recall (N=532) -- 0.4793233082706767
# ***
# large bases -- pred:{'Outdoor', 'Décor & Pillows'} != expected:No Category Fits
# ['Outdoor / Outdoor Shades / Outdoor Umbrellas / Patio Umbrella Stands & Bases', 'Décor & Pillows / Candles & Holders / Candle Holders / Sconce Candle Holders', 'Décor & Pillows / Home Accessories / Vases, Urns, Jars & Bottles']
# 401 recall (N=533) -- 0.47842401500938087
# 402 q:betty resin free standing umbrella -- pred:{'Outdoor'} == expected:Outdoor
# !**
# small ladies rocker swivel recliner -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 403 recall (N=535) -- 0.4785046728971963
# ***
# small ladies rocker swivel recliner -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 403 recall (N=536) -- 0.47761194029850745
# 404 Skipping rattan truck
# 404 q:chrome bathroom 4 light vanity light -- pred:{'Lighting'} == expected:Lighting
# 405 q:wooden chair outdoor -- pred:{'Outdoor'} == expected:Outdoor
# ***
# outdoor seat/back cushion -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions', 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Dining Chair Patio Furniture Cushions']
# 406 recall (N=539) -- 0.47866419294990725
# 407 q:unique coffee tables -- pred:{'Furniture'} == expected:Furniture
# 408 q:champagne velvet desk chair -- pred:{'Furniture'} == expected:Furniture
# 409 q:dining room tables -- pred:{'Furniture'} == expected:Furniture
# !**
# wall sconce with usb port -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Wall Lights / Wall Sconces']
# 410 recall (N=543) -- 0.48066298342541436
# ***
# wall sconce with usb port -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Wall Lights / Wall Sconces']
# 410 recall (N=544) -- 0.4797794117647059
# 411 q:antique brass faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 412 q:marlon tufted queen bed -- pred:{'Furniture'} == expected:Furniture
# 413 q:grantola wall mirror -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 414 q:brendon counter stool -- pred:{'Furniture'} == expected:Furniture
# 415 q:mattress foam topper queen -- pred:{'Bed & Bath'} == expected:Bed & Bath
# !**
# farmhouse hood vent -- pred:{'Home Improvement', 'Appliances'} != expected:No Category Fits
# ['Appliances / Kitchen Appliances / Range Hoods / All Range Hoods', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Bronze Kitchen Faucets', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Black Kitchen Faucets']
# 416 recall (N=550) -- 0.48363636363636364
# ***
# farmhouse hood vent -- pred:{'Home Improvement', 'Appliances'} != expected:No Category Fits
# ['Appliances / Kitchen Appliances / Range Hoods / All Range Hoods', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Bronze Kitchen Faucets', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Black Kitchen Faucets']
# 416 recall (N=551) -- 0.4827586206896552
# 417 q:island estate coffee table -- pred:{'Furniture'} == expected:Furniture
# 418 q:breakfast bar table -- pred:{'Furniture'} == expected:Furniture
# 419 q:door jewelry organizer -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 420 q:orren ellis l shaped desk -- pred:{'Furniture'} == expected:Furniture
# 421 q:toilet paper stand -- pred:{'Home Improvement'} == expected:Home Improvement
# 422 q:basket planter -- pred:{'Outdoor', 'Décor & Pillows'} == expected:Outdoor
# 423 q:wood rack wide -- pred:{'Storage & Organization'} == expected:Storage & Organization
# !**
# large cushion outdoor chair -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs']
# 424 recall (N=559) -- 0.4883720930232558
# ***
# large cushion outdoor chair -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs']
# 424 recall (N=560) -- 0.4875
# 425 q:brush nickel faucet bathroom -- pred:{'Home Improvement'} == expected:Home Improvement
# 426 q:upholstered girls bed -- pred:{'Furniture', 'Baby & Kids'} == expected:Furniture
# !**
# indoor water fountain -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Indoor Fountains']
# 427 recall (N=563) -- 0.48845470692717585
# ***
# indoor water fountain -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Indoor Fountains']
# 427 recall (N=564) -- 0.4875886524822695
# 428 q:desk for kids -- pred:{'Baby & Kids'} == expected:Baby & Kids
# 429 q:circle cabinet pulls -- pred:{'Home Improvement'} == expected:Home Improvement
# 430 Skipping parakeet toy
# 430 q:tufted upholstered bed diamond -- pred:{'Furniture'} == expected:Furniture
# !**
# carolyn console table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Console Tables']
# 431 recall (N=568) -- 0.4894366197183099
# ***
# carolyn console table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Console Tables']
# 431 recall (N=569) -- 0.48857644991212656
# !**
# memory foam rug galveston -- pred:{'Rugs'} != expected:No Category Fits
# ['Rugs / Area Rugs', 'Rugs / Kitchen Mats']
# 432 recall (N=570) -- 0.48771929824561405
# ***
# memory foam rug galveston -- pred:{'Rugs'} != expected:No Category Fits
# ['Rugs / Area Rugs', 'Rugs / Kitchen Mats']
# 432 recall (N=571) -- 0.4868651488616462
# 0.4868651488616462

# %% [markdown]
# ## Run Category search strategy with classifier

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np


class CategorySearch(SearchStrategy):
    def __init__(self, products, query_to_cat,
                 name_boost=9.3,
                 description_boost=4.1,
                 category_boost=10,
                 sub_category_boost=5):
        super().__init__(products)
        self.index = products
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'], snowball_tokenizer)
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)

        cat_split = products['category hierarchy'].fillna('').str.split("/")

        products['category'] = cat_split.apply(
            lambda x: x[0].strip() if len(x) > 0 else ""
        )
        products['subcategory'] = cat_split.apply(
            lambda x: x[1].strip() if len(x) > 1 else ""
        )
        self.index['category_snowball'] = SearchArray.index(
            products['category'], snowball_tokenizer
        )
        self.index['subcategory_snowball'] = SearchArray.index(
            products['subcategory'], snowball_tokenizer
        )

        self.query_to_cat = query_to_cat
        self.name_boost = name_boost
        self.description_boost = description_boost
        self.category_boost = category_boost
        self.sub_category_boost = sub_category_boost

    def search(self, query, k=10):
        """Dumb baseline lexical search, but add a constant boost when
           the desired category or subcategory"""
        bm25_scores = np.zeros(len(self.index))
        structured = self.query_to_cat(query)
        tokenized = snowball_tokenizer(query)

        # ****
        # Baseline BM25 search from before
        for token in tokenized:
            bm25_scores += self.index['product_name_snowball'].array.score(token) * self.name_boost
            bm25_scores += self.index['product_description_snowball'].array.score(
                token) * self.description_boost

        # ****
        # If there's a subcategory, boost that by a constant amount
        for sub_category in structured.sub_categories:
            tokenized_subcategory = snowball_tokenizer(sub_category)
            subcategory_match = np.zeros(len(self.index))
            if tokenized_subcategory:
                subcategory_match = self.index['subcategory_snowball'].array.score(tokenized_subcategory) > 0
            bm25_scores[subcategory_match] += self.sub_category_boost

        # ****
        # If there's a category, boost that by a constant amount
        for category in structured.categories:
            tokenized_category = snowball_tokenizer(category)
            category_match = np.zeros(len(self.index))
            if tokenized_category:
                category_match = self.index['category_snowball'].array.score(tokenized_category) > 0
            bm25_scores[category_match] += self.category_boost

        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores

# %%
categorized_search = CategorySearch(products, fully_classified)
graded_categorized = run_strategy(categorized_search)
graded_categorized
# Out:
# 2025-08-31 21:26:06,889 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-08-31 21:26:06,909 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-08-31 21:26:06,912 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-08-31 21:26:07,628 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-08-31 21:26:08,299 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-08-31 21:26:09,187 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-08-31 21:26:10,089 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-08-31 21:26:10,397 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-08-31 21:26:10,408 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-08-31 21:26:10,416 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-08-31 21:26:10,482 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-08-31 21:26:10,559 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-08-31 21:26:10,562 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-08-31 21:26:10,623 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-08-31 21:26:10,664 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-08-31 21:26:10,678 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-08-31 21:26:10,681 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-08-31 21:26:12,584 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-08-31 21:26:14,193 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-08-31 21:26:15,380 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-08-31 21:26:16,556 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-08-31 21:26:17,079 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-08-31 21:26:17,113 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-08-31 21:26:17,145 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-08-31 21:26:17,707 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-08-31 21:26:17,959 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-08-31 21:26:17,961 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-08-31 21:26:18,154 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-08-31 21:26:18,343 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-08-31 21:26:18,351 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-08-31 21:26:18,353 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-08-31 21:26:18,543 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-08-31 21:26:18,736 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-08-31 21:26:18,923 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-08-31 21:26:19,114 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-08-31 21:26:19,273 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-08-31 21:26:19,276 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-08-31 21:26:19,279 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-08-31 21:26:19,289 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-08-31 21:26:19,296 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-08-31 21:26:19,298 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-08-31 21:26:19,315 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-08-31 21:26:19,328 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-08-31 21:26:19,341 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-08-31 21:26:19,343 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-08-31 21:26:19,566 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-08-31 21:26:19,784 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-08-31 21:26:20,002 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-08-31 21:26:20,214 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-08-31 21:26:20,385 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-08-31 21:26:20,387 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-08-31 21:26:20,391 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-08-31 21:26:20,406 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-08-31 21:26:20,416 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-08-31 21:26:20,418 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-08-31 21:26:20,448 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# Searching: 100%|██████████| 480/480 [00:12<00:00, 37.28it/s]
#       product_id                                       product_name  \
# 0           7465                                   hair salon chair
# 1          25431                      barberpub salon massage chair
# 2           7468  mercer41 hair salon chair hydraulic styling ch...
# 3          39461         professional salon reclining massage chair
# 4          39428               barber salon reclining massage chair
# ...          ...                                                ...
# 4795       22194                                    wine glass rack
# 4796       40243                    madisen hanging wine glass rack
# 4797       40244                       kena hanging wine glass rack
# 4798       39976                       wall mounted wine glass rack
# 4799       40247                       winn hanging wine glass rack
#
#                  product_class  \
# 0     Massage Chairs|Recliners
# 1               Massage Chairs
# 2               Massage Chairs
# 3               Massage Chairs
# 4     Massage Chairs|Recliners
# ...                        ...
# 4795      Kitchen Sink Storage
# 4796                Wine Racks
# 4797                Wine Racks
# 4798                Wine Racks
# 4799                Wine Racks
#
#                                      category hierarchy  \
# 0     Furniture / Living Room Furniture / Chairs & S...
# 1     Furniture / Living Room Furniture / Chairs & S...
# 2     Furniture / Living Room Furniture / Chairs & S...
# 3     Furniture / Living Room Furniture / Chairs & S...
# 4     Furniture / Living Room Furniture / Chairs & S...
# ...                                                 ...
# 4795  Kitchen & Tabletop / Kitchen Organization / Co...
# 4796  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4797  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4798  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4799  Kitchen & Tabletop / Tableware & Drinkware / B...
#
#                                     product_description  \
# 0     offers a wide selection of professional salon ...
# 1     salon chairs are a wonderful avenue for hairst...
# 2     mercer41 beauty offers a wide selection profes...
# 3     new and in a good condition . first-rate metal...
# 4     heavy-duty hydraulic recline barber chair salo...
# ...                                                 ...
# 4795  drip-dry up to eight wineglasses with this cle...
# 4796  complement your farmhouse kitchen decor with t...
# 4797  spruce up your farmhouse kitchen decor with th...
# 4798  the latest addition to this collection , this ...
# 4799  are you looking for a safe and decorative solu...
#
#                                        product_features  rating_count  \
# 0     fauxleathertype : pu|legheight-toptobottom:18|...          69.0
# 1     supplierintendedandapproveduse : non residenti...           4.0
# 2     seatfillmaterial : foam|waterrepellant : no re...           1.0
# 3     overalldepth-fronttoback:39.4|warrantylength:1...           NaN
# 4     seatwidth-sidetoside:19|upholsterycolor : blac...           1.0
# ...                                                 ...           ...
# 4795  glasscapacity:8|countryoforigin : united state...           5.0
# 4796  producttype : wine glass rack|overallwidth-sid...          29.0
# 4797  warrantylength:1 year|producttype : wine glass...          23.0
# 4798  overallheight-toptobottom:4|design : wall moun...          34.0
# 4799  overallheight-toptobottom:1.5|overallwidth-sid...         305.0
#
#       average_rating  review_count  \
# 0                4.5          53.0
# 1                5.0           4.0
# 2                5.0           1.0
# 3                NaN           NaN
# 4                5.0           0.0
# ...              ...           ...
# 4795             4.5           3.0
# 4796             5.0          20.0
# 4797             5.0          18.0
# 4798             4.5          18.0
# 4799             5.0         187.0
#
#                                                features  ... query_id rank  \
# 0     [fauxleathertype : pu, legheight-toptobottom:1...  ...        0    1
# 1     [supplierintendedandapproveduse : non resident...  ...        0    2
# 2     [seatfillmaterial : foam, waterrepellant : no ...  ...        0    3
# 3     [overalldepth-fronttoback:39.4, warrantylength...  ...        0    4
# 4     [seatwidth-sidetoside:19, upholsterycolor : bl...  ...        0    5
# ...                                                 ...  ...      ...  ...
# 4795  [glasscapacity:8, countryoforigin : united sta...  ...      487    6
# 4796  [producttype : wine glass rack, overallwidth-s...  ...      487    7
# 4797  [warrantylength:1 year, producttype : wine gla...  ...      487    8
# 4798  [overallheight-toptobottom:4, design : wall mo...  ...      487    9
# 4799  [overallheight-toptobottom:1.5, overallwidth-s...  ...      487   10
#
#          query_class     id  label grade  discounted_gain      idcg       dcg  \
# 0     Massage Chairs   80.0  Exact   2.0             3.00  8.786905  8.586905
# 1     Massage Chairs   29.0  Exact   2.0             1.50  8.786905  8.586905
# 2     Massage Chairs  104.0  Exact   2.0             1.00  8.786905  8.586905
# 3     Massage Chairs  114.0  Exact   2.0             0.75  8.786905  8.586905
# 4     Massage Chairs   25.0  Exact   2.0             0.60  8.786905  8.586905
# ...              ...    ...    ...   ...              ...       ...       ...
# 4795             NaN    NaN    NaN   0.0             0.00  8.786905  0.000000
# 4796             NaN    NaN    NaN   0.0             0.00  8.786905  0.000000
# 4797             NaN    NaN    NaN   0.0             0.00  8.786905  0.000000
# 4798             NaN    NaN    NaN   0.0             0.00  8.786905  0.000000
# 4799             NaN    NaN    NaN   0.0             0.00  8.786905  0.000000
#
#           ndcg
# 0     0.977239
# 1     0.977239
# 2     0.977239
# 3     0.977239
# 4     0.977239
# ...        ...
# 4795  0.000000
# 4796  0.000000
# 4797  0.000000
# 4798  0.000000
# 4799  0.000000
#
# [4800 rows x 26 columns]

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_categorized).mean()
# Out:
# (np.float64(0.5411098691836396), np.float64(0.5662156211895406))

# %%
deltas = ndcg_delta(graded_categorized, graded_bm25)

# %%
sig_improved = len(deltas[deltas > 0.1])
print(f"Num Significatly Improved: {sig_improved}")
deltas[deltas > 0.1]
# Out:
# Num Significatly Improved: 47
# query
# drum picture                                                       0.506435
# bathroom vanity knobs                                              0.486519
# non slip shower floor tile                                         0.477081
# wood rack wide                                                     0.469449
# outdoor lounge chair                                               0.456442
# modern outdoor furniture                                           0.365533
# twin bed frame                                                     0.359391
# podium with locking cabinet                                        0.332656
# outdoor light fixtures                                             0.320553
# wisdom stone river 3-3/4                                           0.317708
# turquoise chair                                                    0.310979
# liberty hardware francisco                                         0.292914
# accent leather chair                                               0.248882
# glass doors for bath                                               0.244140
# hardwood beds                                                      0.235334
# storage dresser                                                    0.213386
# ayesha curry kitchen                                               0.211173
# wooden chair outdoor                                               0.200063
# acrylic clear chair                                                0.199160
# china clock                                                        0.189044
# beds that have leds                                                0.186289
# wainscoting ideas                                                  0.182089
# moen 5995 arbor one                                                0.179876
# family lamp                                                        0.178612
# dark gray dresser                                                  0.175902
# door jewelry organizer                                             0.170709
# bathroom lighting                                                  0.167547
# teal chair                                                         0.164251
# carpet 5x6                                                         0.158831
# town & country living curtains                                     0.154089
# driftwood mirror                                                   0.151199
# above toilet cabinet                                               0.138238
# closet storage with zipper                                         0.138193
# oriental vanity                                                    0.137967
# odum velvet                                                        0.135483
# upholstered girls bed                                              0.125186
# light and navy blue decorative pillow                              0.124690
# auburn throw pillows                                               0.122341
# medium size chandelier                                             0.119812
# foutains with brick look                                           0.118683
# bedroom wall decor floral, multicolored with some teal (prints)    0.116651
# farmhouse cabinet                                                  0.115702
# small wardrobe grey                                                0.113806
# anchor decor                                                       0.113128
# industrial pipe dining  table                                      0.110419
# midcentury tv unit                                                 0.102425
# floating bed                                                       0.101928
# Name: ndcg, dtype: float64

# %%
sig_harmed = len(deltas[deltas < -0.1])
print(f"Num Significatly Harmed: {sig_harmed}")
print(f"Prop improved/harmed: {sig_improved / (sig_harmed + sig_improved)} | {sig_harmed / (sig_harmed + sig_improved)}")
deltas[deltas < -0.1]
# Out:
# Num Significatly Harmed: 4
# Prop improved/harmed: 0.9215686274509803 | 0.0784313725490196
# query
# zodiac pillow              -0.113806
# papasan chair frame only   -0.123290
# outdoor lounge cushions    -0.223547
# sugar canister             -0.224721
# Name: ndcg, dtype: float64

# %% [markdown]
# ### Look at a query

# %%
QUERY = "sugar canister"
fully_classified(QUERY)
# Out:
# QueryClassification(keywords='sugar canister', classifications=['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Ceramic Kitchen Canisters & Jars', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars'])

# %%
ground_truth_cat[ground_truth_cat['query'] == QUERY]
# Out:
#               query category     count
# 183  sugar canister           0.847458

# %%
graded_categorized[graded_categorized['query'] == QUERY][['product_name', 'category hierarchy', 'grade']]
# Out:
#                                            product_name  \
# 1830  everyday coffee , sugar , flour kitchen canist...
# 1831                                   kitchen canister
# 1832                                   kitchen canister
# 1833                  wave 4 piece kitchen canister set
# 1834        enameled metal `` sugar '' kitchen canister
# 1835                         4.69 qt . kitchen canister
# 1836    tower salt and sugar container 2 jar spice rack
# 1837  metal 3 piece sugar , flour & coffee canister set
# 1838               pauline 3 piece kitchen canister set
# 1839            versailles 4 piece kitchen canister set
#
#                                      category hierarchy  grade
# 1830  Kitchen & Tabletop / Kitchen Organization / Fo...    2.0
# 1831  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1832  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1833  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1834                                                NaN    2.0
# 1835  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1836  Kitchen & Tabletop / Kitchen Organization / Sp...    1.0
# 1837                                                NaN    2.0
# 1838  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1839  Kitchen & Tabletop / Kitchen Organization / Fo...    2.0

# %%
graded_bm25[graded_bm25['query'] == QUERY][['product_name', 'category hierarchy', 'grade']]
# Out:
#                                            product_name  \
# 1830  everyday coffee , sugar , flour kitchen canist...
# 1831        enameled metal `` sugar '' kitchen canister
# 1832  metal 3 piece sugar , flour & coffee canister set
# 1833                                   kitchen canister
# 1834                                   4 qt . sugar jar
# 1835                                   kitchen canister
# 1836                     coffee & food storage canister
# 1837                       4 piece kitchen canister set
# 1838    tuscania : tuscania canister zucchero ( sugar )
# 1839                            3 qt . kitchen canister
#
#                                      category hierarchy  grade
# 1830  Kitchen & Tabletop / Kitchen Organization / Fo...    2.0
# 1831                                                NaN    2.0
# 1832                                                NaN    2.0
# 1833  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1834                                                NaN    2.0
# 1835  Kitchen & Tabletop / Kitchen Organization / Fo...    1.0
# 1836                                                NaN    2.0
# 1837                                                NaN    2.0
# 1838                                                NaN    2.0
# 1839                                                NaN    1.0

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np

from cheat_at_search.agent.enrich import CachedEnricher, OpenAIEnricher


class CategorySearch(SearchStrategy):
    def __init__(self, products, query_to_cat,
                 name_boost=9.3,
                 description_boost=4.1,
                 category_boost=10,
                 sub_category_boost=5):
        super().__init__(products)
        self.index = products
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'], snowball_tokenizer)
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)

        cat_split = products['category hierarchy'].fillna('').str.split("/")

        products['category'] = cat_split.apply(
            lambda x: x[0].strip() if len(x) > 0 else ""
        )
        products['subcategory'] = cat_split.apply(
            lambda x: x[1].strip() if len(x) > 1 else ""
        )
        self.index['category_snowball'] = SearchArray.index(
            products['category'], snowball_tokenizer
        )
        self.index['subcategory_snowball'] = SearchArray.index(
            products['subcategory'], snowball_tokenizer
        )

        self.query_to_cat = query_to_cat
        self.name_boost = name_boost
        self.description_boost = description_boost
        self.category_boost = category_boost
        self.sub_category_boost = sub_category_boost

    def search(self, query, k=10):
        """Dumb baseline lexical search, but add a constant boost when
           the desired category or subcategory"""
        bm25_scores = np.zeros(len(self.index))
        structured = self.query_to_cat(query)
        tokenized = snowball_tokenizer(query)

        # ****
        # Baseline BM25 search from before
        num_tokens_matched = np.zeros(len(self.index))
        for token in tokenized:

            name_score = self.index['product_name_snowball'].array.score(token) * self.name_boost
            desc_score = self.index['product_description_snowball'].array.score(
                token) * self.description_boost
            bm25_scores += name_score + desc_score
            num_tokens_matched[(name_score + desc_score) > 0] += 1

        # ****
        # If there's a subcategory, boost that by a constant amount
        for sub_category in structured.sub_categories:
            tokenized_subcategory = snowball_tokenizer(sub_category)
            subcategory_match = np.zeros(len(self.index))
            if tokenized_subcategory:
                subcategory_match = self.index['subcategory_snowball'].array.score(tokenized_subcategory) > 0
            bm25_scores[subcategory_match] += self.sub_category_boost

        # ****
        # If there's a category, boost that by a constant amount
        for category in structured.categories:
            tokenized_category = snowball_tokenizer(category)
            category_match = np.zeros(len(self.index))
            if tokenized_category:
                category_match = self.index['category_snowball'].array.score(tokenized_category) > 0
            bm25_scores[category_match] += self.category_boost

        # ***
        # Require all tokens to match
        min_token_match = max(len(tokenized) / 2, 1)
        bm25_scores[num_tokens_matched < min_token_match] *= 0.8

        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores

# %%
categorized_search = CategorySearch(products, fully_classified)
graded_categorized2 = run_strategy(categorized_search)
graded_categorized2

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_categorized2).mean()

# %%
categorized_search = CategorySearch(products, fully_classified, category_boost=100, sub_category_boost=50)
graded_categorized = run_strategy(categorized_search)
graded_categorized

# %%
def get_num_tokens(query):
    prompt = get_prompt_fully_qualified(query)
    return enricher.get_num_tokens(prompt)

get_num_tokens("loveseat sofa")

# %%
get_num_tokens("loveseat")
