# %% [markdown]
# # Synonyms generation with an LLM
#
# <small>
# (from <a href="http://maven.com/softwaredoug/cheat-at-search">Cheat at Search with LLMs</a> training course by Doug Turnbull.)
# </small>
#
# Let's get familiar with the code we'll use for this class by doing what a lot of search teams did when they heard about LLMs
#
# * Can I generate synonyms using LLMs?
#
# We'll try to expand queries -> their synonyms and see if it helps NDCG

# %%
# !pip install git+https://github.com/softwaredoug/cheat-at-search.git
# Out:
# Collecting git+https://github.com/softwaredoug/cheat-at-search.git
#   Cloning https://github.com/softwaredoug/cheat-at-search.git to /tmp/pip-req-build-m2gxl15f
#   Running command git clone --filter=blob:none --quiet https://github.com/softwaredoug/cheat-at-search.git /tmp/pip-req-build-m2gxl15f
#   Resolved https://github.com/softwaredoug/cheat-at-search.git to commit 38a087b480422fb5f29fea8b25fbfb25f3492da3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-genai<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.39.1)
# Requirement already satisfied: openai<2.0.0,>=1.84.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.109.1)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow<22.0.0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.11.9)
# Requirement already satisfied: pystemmer<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (3.0.0)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (6.0.3)
# Requirement already satisfied: searcharray<0.0.73,>=0.0.72 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (0.0.72)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (0.11.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from searcharray<0.0.73,>=0.0.72->cheat_at_search==0.1.0) (3.0.12)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.6.1)

# %% [markdown]
# ### Choose Gdrive or Instance Drive
#
# * **Save money / convenience** - set `use_grive` to True and mount your google drive. Data will be cached there. Beware of annoying permissions you need to give this notebook.
#
# * **Higher privacy / more cost** - set `use_gdrive` to False and the data will be stored as long as this notebook's runtime is running. Eventually it will be deallocated and you'll lose this cache and need to re-enter your OpenAI key when prompted.
#
# * **High privacy / save money / higher mainenance burden** - Download ipynb and run in your own Jupyter. Set the CHEAT_AT_SEARCH_DATA_PATH to some place on your system.

# %%
from cheat_at_search.data_dir import mount
mount(use_gdrive=True)    # colab, share data across notebook runs on gdrive
# mount(use_gdrive=False) # <- colab without gdrive
# mount(use_gdrive=False, manual_path="/path/to/directory")  # <- force data path to specific directory, ie you're running locally.
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Import helpers
#
# Import the following helpers:
#
# * `run_strategy` -- this runs a "strategy" and gives us the search results for each query back (more on this in a second)
# * `graded_bm25` -- a BM25 search baseline. A dump of the search results of every test query in the Wayfair dataset run using a BM25 baseline. Useful to compare our attempts against.
# * `ndcgs` -- Take one of the sets of search results (ie `graded_bm25`) and get the NDCG of each query
# * `ndcg_delta` -- Compare two sets of search results (ie `graded_bm25` vs `graded_my_cool_experiment`) and see which queries do better / worse
# * `vs_ideal` -- Take a set of search results (ie `graded_bm25`) and compare against the ideal according to the ground truth data.

# %%
from cheat_at_search.search import run_strategy, graded_bm25, ndcgs, ndcg_delta, vs_ideal

# %% [markdown]
# ## Import WANDS data
#
# Import [Wayfair Annotated Dataset](https://github.com/wayfair/WANDS) a labeled furniture e-commerce dataset. This is a helpful dataset that has 480 e-commerce queries, along with ~45K furniture / home goods products, and relevance labels for each. In WANDS relevance labels range from 0 (not at all relevant) to 2 (relevant)
#
# Below you see a sample of the corpus as a pandas dataframe.

# %%
from cheat_at_search.wands_data import products

products
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features             category  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...           Furniture
# 1      [capacityquarts:7, producttype : slow cooker, ...  Kitchen & Tabletop
# 2      [features : keep warm setting, capacityquarts:...  Kitchen & Tabletop
# 3      [overallwidth-sidetoside:3.5, warrantylength :...     Browse By Brand
# 4      [compatibledoorthickness:1.375 '' , countryofo...    Home Improvement
# ...                                                  ...                  ...
# 42989  [producttype : shower panel, spraypattern : ra...    Home Improvement
# 42990  [basematerialdetails : steel,  : gray wood, of...           Furniture
# 42991  [additionaltoolsrequirednotincluded : power dr...           Furniture
# 42992  [legmaterialdetails : rubberwood, backheight-s...           Furniture
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...           Furniture
#
#                                  sub_category  \
# 0                          Bedroom Furniture
# 1                   Small Kitchen Appliances
# 2                   Small Kitchen Appliances
# 3                                    All-Clad
# 4                      Doors & Door Hardware
# ...                                       ...
# 42989   Bathroom Remodel & Bathroom Fixtures
# 42990             Kitchen & Dining Furniture
# 42991             Kitchen & Dining Furniture
# 42992                  Living Room Furniture
# 42993             Kitchen & Dining Furniture
#
#                                               cat_subcat  \
# 0                       Furniture  /  Bedroom Furniture
# 1       Kitchen & Tabletop  /  Small Kitchen Appliances
# 2       Kitchen & Tabletop  /  Small Kitchen Appliances
# 3                           Browse By Brand  /  All-Clad
# 4            Home Improvement  /  Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement  /  Bathroom Remodel & Bathro...
# 42990          Furniture  /  Kitchen & Dining Furniture
# 42991          Furniture  /  Kitchen & Dining Furniture
# 42992               Furniture  /  Living Room Furniture
# 42993          Furniture  /  Kitchen & Dining Furniture
#
#                                    product_name_snowball  \
# 0            Terms({'solid', 'wood', 'bed', 'platform'})
# 1      Terms({'slow', 'clad', 'all', 'qt', 'cooker', ...
# 2      Terms({'slow', 'clad', 'all', 'cooker', 'qt', ...
# 3      Terms({'tool', 'clad', 'all', 'profession', 'p...
# 4      Terms({'alcott', 'rosett', 'with', 'prestig', ...
# ...                                                  ...
# 42989  Terms({'panel', 'head', 'fix', 'divert', 'bala...
# 42990  Terms({'set', 'breakfast', 'emmelin', 'dine', ...
# 42991  Terms({'set', 'pub', '3', 'piec', 'tabl', 'mal...
# 42992  Terms({'27', 'wide', 'fletcher', 'polyest', 'a...
# 42993           Terms({'griffin', 'stool', 'bar', '29'})
#
#                             product_description_snowball
# 0      Terms({'will', 'or', 'usag', 'express', 'probl...
# 1      Terms({'or', 'cook', 'in', 'place', 'walk', 'a...
# 2      Terms({'cook', 'featur', 'on', 'hour', 'prepar...
# 3      Terms({'to', 'pizza', 'cutter', 'featur', 'the...
# 4      Terms({'to', 'discrimin', 'which', 'from', 'in...
# ...                                                  ...
# 42989  Terms({'fixtur', 'overs', 'sleek', 'singl', 'i...
# 42990                                       Terms(set())
# 42991  Terms({'to', 'station', 'will', 'or', 'wheel',...
# 42992  Terms({'to', 'upholsteri', 'touch', 'craft', '...
# 42993  Terms({'or', 'togeth', 'minimalist', 'enjoy', ...
#
# [42994 rows x 15 columns]

# %% [markdown]
# ## Synonym generation
#
# We'll first setup the scaffolding of setting up query -> synonym mapping. Expecting a list back of phrases -> their synonyms.

# %% [markdown]
# ### Pydantic Models for Structured Output
#
# ["Pydantic"](https://docs.pydantic.dev/latest/) is a Python way of having a struct or simple data class. It can be a useful way to serialize data to/from underlying data formats (ie JSON, protobuf). And we'll largely work at this level of abstraction.
#
# We're using [OpenAI's structured output](https://platform.openai.com/docs/guides/structured-outputs). Which means:
#
# * Using pydantic to define the expected output (with a description that the model can use)
# * Creating a 'struct like' view of the data we want OpenAI to produce.
# * Forcing OpenAI to return a specific format, and not begging it to return parsable JSON
#
# This pattern of using structured outputs is common across other vendors such al Ollama, Gemini, etc. Though there may be mild differences in how the pydantic types are interpreted.

# %%
from pydantic import BaseModel, Field
from typing import List
from cheat_at_search.enrich import AutoEnricher


class Query(BaseModel):
    """
    Base model for search queries, containing common query attributes.
    """
    keywords: str = Field(
        ...,
        description="The original search query keywords sent in as input"
    )


class SynonymMapping(BaseModel):
    """
    Model for mapping phrases in the query to equivalent phrases or synonyms.
    """
    phrase: str = Field(
        ...,
        description="The original phrase from the query"
    )
    synonyms: List[str] = Field(
        ...,
        description="List of synonyms or equivalent phrases for the original phrase"
    )


class QueryWithSynonyms(Query):
    """
    Extended model for search queries that includes synonyms for keywords.
    Inherits from the base Query model.
    """
    synonyms: List[SynonymMapping] = Field(
        ...,
        description="Mapping of phrases in the query to equivalent phrases or synonyms"
    )

# %%
QueryWithSynonyms.model_json_schema()
# Out:
# {'$defs': {'SynonymMapping': {'description': 'Model for mapping phrases in the query to equivalent phrases or synonyms.',
#    'properties': {'phrase': {'description': 'The original phrase from the query',
#      'title': 'Phrase',
#      'type': 'string'},
#     'synonyms': {'description': 'List of synonyms or equivalent phrases for the original phrase',
#      'items': {'type': 'string'},
#      'title': 'Synonyms',
#      'type': 'array'}},
#    'required': ['phrase', 'synonyms'],
#    'title': 'SynonymMapping',
#    'type': 'object'}},
#  'description': 'Extended model for search queries that includes synonyms for keywords.\nInherits from the base Query model.',
#  'properties': {'keywords': {'description': 'The original search query keywords sent in as input',
#    'title': 'Keywords',
#    'type': 'string'},
#   'synonyms': {'description': 'Mapping of phrases in the query to equivalent phrases or synonyms',
#    'items': {'$ref': '#/$defs/SynonymMapping'},
#    'title': 'Synonyms',
#    'type': 'array'}},
#  'required': ['keywords', 'synonyms'],
#  'title': 'QueryWithSynonyms',
#  'type': 'object'}

# %% [markdown]
# ### Synonym generation code
#
# We use `AutoEnricher` in this class. This is something that wraps the calls to OpenAI in the `cheat_at_search` package.
#
# Notice when constructing it, we provide three values:
#
# * `model` -- the underlying LLM to use. If you load ChatGPT, you would notice the dropdown of models you can select. They each have pros/cons with cost and quality.
# * `system_prompt` -- the general behavior of the agent, priming it for the task its about to perform
# * `response_model` -- the Pydantic class to use to generate structured outputs
#
# We can then call `enricher.enrich(prompt)` and get back an instance of `QueryWithSynonyms`
#
# Notice too `get_prompt` generates a prompt given a search query.

# %%
syn_enricher = AutoEnricher(model="openai/gpt-4.1-nano",
                            system_prompt="You are a helpful AI assistant extracting synonyms from queries.",
                            response_model=QueryWithSynonyms)

def get_prompt(query: str):
    prompt = f"""
        Extract synonyms from the following query that will help us find relevant products for the query.

        {query}
    """

    return prompt

print(get_prompt("rack glass"))
# Out:
#         Extract synonyms from the following query that will help us find relevant products for the query.
#
#         rack glass

# %%
def query_to_syn(query: str):
    return syn_enricher.enrich(get_prompt(query))

query_to_syn("foldout blue ugly love seat")
# Out:
# QueryWithSynonyms(keywords='foldout blue ugly love seat', synonyms=[SynonymMapping(phrase='foldout', synonyms=['convertible', 'reclining', 'expandable']), SynonymMapping(phrase='blue', synonyms=['azure', 'navy', 'cobalt']), SynonymMapping(phrase='ugly', synonyms=['unattractive', 'unsightly', 'plain']), SynonymMapping(phrase='love seat', synonyms=['two-seater', 'sofa for two', 'loveseat'])])

# %% [markdown]
# ### Snowball tokenizer
#
# We'll use a [snowball stemmer](https://www.nltk.org/api/nltk.stem.SnowballStemmer.html) when we index the data. This is just a function that takes a string and returns a list of tokens, each snowball stemmed.

# %%
from cheat_at_search.tokenizers import snowball_tokenizer
snowball_tokenizer("fancy furniture")
# Out:
# ['fanci', 'furnitur']

# %% [markdown]
# ### Build a SearchStrategy -- Enrich, index, search
#
# A SearchStrategy emulates a typical search system, but in a mini form suitable for dorking around in this notebook.
#
# Notice in `__init__`, indexing:
#
# ```
#     self.index['product_name_snowball'] = SearchArray.index(
#             products['product_name'],
#             snowball_tokenizer
#         )
# ```
#
# Then later we `search`, summing up BM25 scores across different fields:
#
# ```
#         # ***
#         # For each token, get the BM25 score of that token in product name and
#         # product description. Sum them
#         for token in tokenized:
#             bm25_scores += self.name_boost * self.index['product_name_snowball'].array.score(token)
#             bm25_scores += self.description_boost * self.index['product_description_snowball'].array.score(
#                 token)
# ```
#
# Farther down, you see we boost also when we match a synonym phrase.
#
# #### SearchArray
#
# We use a lexical search library [SearchArray](http://github.com/softwaredoug/search-array) for simple lexical searches. (See the notebooks and information in the prework for the class)
#
# In the case of synonyms, a lot of teams trying this have a mature lexical search system like Elasticsearch. Instead of adding embedding retrieval to the search, they try this hack to see if they can cheat at search.

# %%
from searcharray import SearchArray
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np


class SynonymSearch(SearchStrategy):
    def __init__(self, products, synonym_generator,
                 name_boost=9.3,
                 description_boost=4.1):
        """ Build an index."""
        super().__init__(products)
        self.index = products
        self.name_boost = name_boost
        self.description_boost = description_boost

        #*****
        # Take an array of text (here `products['product_name']`)
        # Tokenize it with snowball (the passed function)
        # Produce a searchable index on "product_name_snowball"
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'],
            snowball_tokenizer
        )
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)
        self.query_to_syn = synonym_generator

    def search(self, query, k=10):
        """Dumb baseline lexical search with LLM generated synonyms"""
        # ***
        # Tokenize the query with snowball
        tokenized = snowball_tokenizer(query)
        bm25_scores = np.zeros(len(self.index))

        # ***
        # For each token, get the BM25 score of that token in product name and
        # product description. Sum them
        for token in tokenized:
            bm25_scores += self.name_boost * self.index['product_name_snowball'].array.score(token)
            bm25_scores += self.description_boost * self.index['product_description_snowball'].array.score(
                token)

        # ***
        # Generate synonyms
        synonyms = self.query_to_syn(query)

        # ***
        # Boost by each synonym phrase
        # (repeat the same above, except we add the BM25 scores of the generated synonyms)
        all_single_tokens = set()
        for mapping in synonyms.synonyms:
            for phrase in mapping.synonyms:
                tokenized = snowball_tokenizer(phrase)
                bm25_scores += self.index['product_name_snowball'].array.score(tokenized)
                bm25_scores += self.index['product_description_snowball'].array.score(tokenized)
                for token in tokenized:
                    all_single_tokens.add(token)

        # ***
        # Boost by each single token
        # for token in all_single_tokens:
        #     bm25_scores += self.index['product_name_snowball'].array.score(token)
        #     bm25_scores += self.index['product_description_snowball'].array.score(token)

        # ***
        # Sort by BM25 scores
        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores


syns = SynonymSearch(products, query_to_syn)
# Out:
# 2025-10-08 12:56:00,888 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-10-08 12:56:00,909 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-10-08 12:56:00,913 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-10-08 12:56:01,897 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-10-08 12:56:02,539 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-10-08 12:56:03,598 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-10-08 12:56:04,388 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-10-08 12:56:04,938 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-10-08 12:56:04,942 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-10-08 12:56:04,950 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-10-08 12:56:05,037 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-10-08 12:56:05,141 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-10-08 12:56:05,148 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-10-08 12:56:05,258 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-10-08 12:56:05,313 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-10-08 12:56:05,330 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-10-08 12:56:05,333 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-10-08 12:56:07,181 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-10-08 12:56:09,024 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-10-08 12:56:09,826 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-10-08 12:56:10,633 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-10-08 12:56:11,116 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-10-08 12:56:11,133 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-10-08 12:56:11,150 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-10-08 12:56:11,591 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-10-08 12:56:11,718 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-10-08 12:56:11,720 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-10-08 12:56:11,863 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete

# %% [markdown]
# ### Run strategy, get results back
#
# We call `run_strategy` which behind the scene passes every WANDS query to the `syns` strategy to get search results. Then appends them all to `graded_syns` which has 480 queries times 10 results per query (4800 rows)

# %%
# for each query
#   results = syns.search(query)
#   -- Give each result a 'grade'
#   --- Compute DCG
graded_syns = run_strategy(syns)
graded_syns
# Out:
# Searching: 100%|██████████| 480/480 [00:11<00:00, 40.61it/s]
#       product_id                                       product_name  \
# 0           7465                                   hair salon chair
# 1           7468  mercer41 hair salon chair hydraulic styling ch...
# 2          25431                      barberpub salon massage chair
# 3          39461         professional salon reclining massage chair
# 4           9234                            beauty salon task chair
# ...          ...                                                ...
# 4795       40244                       kena hanging wine glass rack
# 4796       40245                   podgorni hanging wine glass rack
# 4797       40247                       winn hanging wine glass rack
# 4798       39976                       wall mounted wine glass rack
# 4799        7151                     bataan hanging wine glass rack
#
#                  product_class  \
# 0     Massage Chairs|Recliners
# 1               Massage Chairs
# 2               Massage Chairs
# 3               Massage Chairs
# 4                          NaN
# ...                        ...
# 4795                Wine Racks
# 4796                Wine Racks
# 4797                Wine Racks
# 4798                Wine Racks
# 4799                Wine Racks
#
#                                      category hierarchy  \
# 0     Furniture / Living Room Furniture / Chairs & S...
# 1     Furniture / Living Room Furniture / Chairs & S...
# 2     Furniture / Living Room Furniture / Chairs & S...
# 3     Furniture / Living Room Furniture / Chairs & S...
# 4          Furniture / Office Furniture / Office Chairs
# ...                                                 ...
# 4795  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4796  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4797  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4798  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4799  Kitchen & Tabletop / Tableware & Drinkware / B...
#
#                                     product_description  \
# 0     offers a wide selection of professional salon ...
# 1     mercer41 beauty offers a wide selection profes...
# 2     salon chairs are a wonderful avenue for hairst...
# 3     new and in a good condition . first-rate metal...
# 4     applicable scene : office , home life , beauty...
# ...                                                 ...
# 4795  spruce up your farmhouse kitchen decor with th...
# 4796  display and protect your delicate wine or marg...
# 4797  are you looking for a safe and decorative solu...
# 4798  the latest addition to this collection , this ...
# 4799  hang your stemware in style with this charming...
#
#                                        product_features  rating_count  \
# 0     fauxleathertype : pu|legheight-toptobottom:18|...          69.0
# 1     seatfillmaterial : foam|waterrepellant : no re...           1.0
# 2     supplierintendedandapproveduse : non residenti...           4.0
# 3     overalldepth-fronttoback:39.4|warrantylength:1...           NaN
# 4     overallheight-toptobottom:37|backcolor : brown...           NaN
# ...                                                 ...           ...
# 4795  warrantylength:1 year|producttype : wine glass...          23.0
# 4796  overallheight-toptobottom:1.5|stemwarecapacity...           6.0
# 4797  overallheight-toptobottom:1.5|overallwidth-sid...         305.0
# 4798  overallheight-toptobottom:4|design : wall moun...          34.0
# 4799  stemwarecapacity:18|material : wood|design : h...         103.0
#
#       average_rating  review_count  \
# 0                4.5          53.0
# 1                5.0           1.0
# 2                5.0           4.0
# 3                NaN           NaN
# 4                NaN           NaN
# ...              ...           ...
# 4795             5.0          18.0
# 4796             4.0           6.0
# 4797             5.0         187.0
# 4798             4.5          18.0
# 4799             4.5          78.0
#
#                                                features  ... query_id rank  \
# 0     [fauxleathertype : pu, legheight-toptobottom:1...  ...        0    1
# 1     [seatfillmaterial : foam, waterrepellant : no ...  ...        0    2
# 2     [supplierintendedandapproveduse : non resident...  ...        0    3
# 3     [overalldepth-fronttoback:39.4, warrantylength...  ...        0    4
# 4     [overallheight-toptobottom:37, backcolor : bro...  ...        0    5
# ...                                                 ...  ...      ...  ...
# 4795  [warrantylength:1 year, producttype : wine gla...  ...      487    6
# 4796  [overallheight-toptobottom:1.5, stemwarecapaci...  ...      487    7
# 4797  [overallheight-toptobottom:1.5, overallwidth-s...  ...      487    8
# 4798  [overallheight-toptobottom:4, design : wall mo...  ...      487    9
# 4799  [stemwarecapacity:18, material : wood, design ...  ...      487   10
#
#          query_class     id    label  grade  discounted_gain      idcg  \
# 0     Massage Chairs   80.0    Exact    2.0             3.00  8.786905
# 1     Massage Chairs  104.0    Exact    2.0             1.50  8.786905
# 2     Massage Chairs   29.0    Exact    2.0             1.00  8.786905
# 3     Massage Chairs  114.0    Exact    2.0             0.75  8.786905
# 4     Massage Chairs   32.0  Partial    1.0             0.20  8.786905
# ...              ...    ...      ...    ...              ...       ...
# 4795             NaN    NaN      NaN    0.0             0.00  8.786905
# 4796             NaN    NaN      NaN    0.0             0.00  8.786905
# 4797             NaN    NaN      NaN    0.0             0.00  8.786905
# 4798             NaN    NaN      NaN    0.0             0.00  8.786905
# 4799             NaN    NaN      NaN    0.0             0.00  8.786905
#
#           dcg      ndcg
# 0     8.10119  0.921962
# 1     8.10119  0.921962
# 2     8.10119  0.921962
# 3     8.10119  0.921962
# 4     8.10119  0.921962
# ...       ...       ...
# 4795  0.00000  0.000000
# 4796  0.00000  0.000000
# 4797  0.00000  0.000000
# 4798  0.00000  0.000000
# 4799  0.00000  0.000000
#
# [4800 rows x 25 columns]

# %% [markdown]
# ### Look at one search result...

# %%
graded_syns[graded_syns['query'] == "wood bar stools"]
# Out:
#       product_id                               product_name product_class  \
# 4340        4888  gollapalli solid wood bar & counter stool    Bar Stools
# 4341       37300    axelle solid wood bar and counter stool    Bar Stools
# 4342       18420   stockdove solid wood bar & counter stool    Bar Stools
# 4343        4884  abramowitz solid wood bar & counter stool    Bar Stools
# 4344        4891      khanna solid wood bar & counter stool    Bar Stools
# 4345       34277   crystelle solid wood bar & counter stool    Bar Stools
# 4346        4902      wooden solid wood bar & counter stool    Bar Stools
# 4347       39984             solid wood bar & counter stool    Bar Stools
# 4348       17625       adona solid wood bar & counter stool    Bar Stools
# 4349       24132   bergstrom solid wood bar & counter stool    Bar Stools
#
#                                      category hierarchy  \
# 4340  Furniture / Kitchen & Dining Furniture / Bar F...
# 4341  Furniture / Kitchen & Dining Furniture / Bar F...
# 4342  Furniture / Kitchen & Dining Furniture / Bar F...
# 4343  Furniture / Kitchen & Dining Furniture / Bar F...
# 4344  Furniture / Kitchen & Dining Furniture / Bar F...
# 4345  Furniture / Kitchen & Dining Furniture / Bar F...
# 4346  Furniture / Kitchen & Dining Furniture / Bar F...
# 4347  Furniture / Kitchen & Dining Furniture / Bar F...
# 4348  Furniture / Kitchen & Dining Furniture / Bar F...
# 4349  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                     product_description  \
# 4340  enhance the beauty of your home with the inclu...
# 4341  this bar & counter stool is a sublime stool fu...
# 4342  introduce a graceful elegance to your home wit...
# 4343  give yourself a place to sit right next to you...
# 4344  compliment your home with the addition of this...
# 4345  this crystelle solid wood bar & counter stool ...
# 4346  personalize your home setting with the inclusi...
# 4347  outfit the home bar or accent your favorite se...
# 4348  this classic bar stool is solid wood for firm ...
# 4349  these solid wood bar stools add a contemporary...
#
#                                        product_features  rating_count  \
# 4340  upholsterymaterial : faux leather|seatbacktype...           NaN
# 4341  dswoodtone : medium wood|seatmaterialdetails :...         298.0
# 4342  overallheight-toptobottom:42.13|weightcapacity...           1.0
# 4343  overallproductweight:15.84|framematerial : sol...           NaN
# 4344  seatmaterial : solid wood|overallwidth-sidetos...           NaN
# 4345  dssecondaryproductstyle : contemporary industr...          21.0
# 4346  seatmaterial : solid wood|framematerialdetails...           1.0
# 4347  overalldepth-fronttoback:13.4|dsprimaryproduct...         330.0
# 4348  levelofassembly : partial assembly|overalldept...           3.0
# 4349  seatdepth-fronttoback:13|legbasetype:4 legs|se...         207.0
#
#       average_rating  review_count  \
# 4340             NaN           NaN
# 4341             4.5         203.0
# 4342             5.0           1.0
# 4343             NaN           NaN
# 4344             NaN           NaN
# 4345             4.5          17.0
# 4346             5.0           0.0
# 4347             4.5         253.0
# 4348             4.0           3.0
# 4349             5.0         154.0
#
#                                                features  ... query_id rank  \
# 4340  [upholsterymaterial : faux leather, seatbackty...  ...      440    1
# 4341  [dswoodtone : medium wood, seatmaterialdetails...  ...      440    2
# 4342  [overallheight-toptobottom:42.13, weightcapaci...  ...      440    3
# 4343  [overallproductweight:15.84, framematerial : s...  ...      440    4
# 4344  [seatmaterial : solid wood, overallwidth-sidet...  ...      440    5
# 4345  [dssecondaryproductstyle : contemporary indust...  ...      440    6
# 4346  [seatmaterial : solid wood, framematerialdetai...  ...      440    7
# 4347  [overalldepth-fronttoback:13.4, dsprimaryprodu...  ...      440    8
# 4348  [levelofassembly : partial assembly, overallde...  ...      440    9
# 4349  [seatdepth-fronttoback:13, legbasetype:4 legs,...  ...      440   10
#
#      query_class        id    label  grade  discounted_gain      idcg  \
# 4340  Bar Stools   47096.0  Partial    1.0         1.000000  8.786905
# 4341  Bar Stools   47044.0  Partial    1.0         0.500000  8.786905
# 4342  Bar Stools  188300.0    Exact    2.0         1.000000  8.786905
# 4343  Bar Stools   47027.0    Exact    2.0         0.750000  8.786905
# 4344  Bar Stools   47120.0  Partial    1.0         0.200000  8.786905
# 4345  Bar Stools  188485.0  Partial    1.0         0.166667  8.786905
# 4346  Bar Stools   47203.0  Partial    1.0         0.142857  8.786905
# 4347  Bar Stools   47186.0    Exact    2.0         0.375000  8.786905
# 4348  Bar Stools  188483.0    Exact    2.0         0.333333  8.786905
# 4349  Bar Stools   57259.0    Exact    2.0         0.300000  8.786905
#
#            dcg      ndcg
# 4340  4.767857  0.542609
# 4341  4.767857  0.542609
# 4342  4.767857  0.542609
# 4343  4.767857  0.542609
# 4344  4.767857  0.542609
# 4345  4.767857  0.542609
# 4346  4.767857  0.542609
# 4347  4.767857  0.542609
# 4348  4.767857  0.542609
# 4349  4.767857  0.542609
#
# [10 rows x 25 columns]

# %%
query_to_syn("wood bar stools")
# Out:
# QueryWithSynonyms(keywords='wood bar stools', synonyms=[SynonymMapping(phrase='wood', synonyms=['timber', 'lumber', 'wooden']), SynonymMapping(phrase='bar stools', synonyms=['counter stools', 'bar chairs', 'pub stools'])])

# %% [markdown]
# ## Analyze the results
#
# Let's look at the results to see how we did against a BM25 baseline
#
# Here we get ndcg of each query with `ndcgs`, then compute the mean for all queries. We do this comparing BM25 vs our synonym variant

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_syns).mean()
# Out:
# (np.float64(0.5411098691836396), np.float64(0.5435463050776015))

# %% [markdown]
# ### Win / loss against BM25 baseline
#
# `ndcg_delta` shows us the per-query NDCG difference
#
# * We note some massive wins
# * We unfortunately also note massive variance in outcomes (meaning a risky change)

# %%
ndcg_delta(graded_syns, graded_bm25)
# Out:
# query
# cover set for outdoor furniture    0.299959
# tye dye duvet cover                0.273811
# outdoor light fixtures             0.180192
# door jewelry organizer             0.170709
# bohemian                           0.136567
#                                      ...
# cloud modular sectional           -0.067019
# sheffield home bath set           -0.081290
# desk for kids                     -0.086709
# seat cushions desk                -0.113806
# wood bar stools                   -0.311340
# Name: ndcg, Length: 79, dtype: float64

# %% [markdown]
# ### Examine a single query (what went right/wrong?)
#
# First we see what BM25 produced...

# %%
QUERY = "seat cushions desk"

# %%
graded_bm25[graded_bm25['query'] == QUERY][['rank', 'product_name', 'product_description', 'grade']]
# Out:
#       rank                        product_name  \
# 2930     1  ergonomic memory foam seat cushion
# 2931     2               chiavari seat cushion
# 2932     3                 deluxe seat cushion
# 2933     4           deep outdoor seat cushion
# 2934     5                outdoor seat cushion
# 2935     6                 indoor seat cushion
# 2936     7         indoor/outdoor seat cushion
# 2937     8           outdoor seat/back cushion
# 2938     9      outdoor sunbrella seat cushion
# 2939    10                    gel seat cushion
#
#                                     product_description  grade
# 2930  work and drive in absolute comfort with the er...    2.0
# 2931  hard cushions are the most popular choice in t...    1.0
# 2932  the deluxe seat and back cushion by sacro-ease...    1.0
# 2933  this seat & back deep seating cushions feature...    1.0
# 2934  add personality and comfort to your outdoor pa...    1.0
# 2935  the classic buffalo check pattern comes to lif...    1.0
# 2936  become your own personal designer with their f...    1.0
# 2937  this seat and back cushion adds a boost of sof...    1.0
# 2938  this outdoor wicker seat cushion is made for c...    0.0
# 2939  sleekly designed with an ergonomic shape for r...    2.0

# %%
graded_syns[graded_syns['query'] ==  QUERY][['rank', 'product_name', 'product_description', 'grade']]
# Out:
#       rank                        product_name  \
# 2930     1                 indoor seat cushion
# 2931     2  ergonomic memory foam seat cushion
# 2932     3               chiavari seat cushion
# 2933     4                outdoor seat cushion
# 2934     5                 deluxe seat cushion
# 2935     6           deep outdoor seat cushion
# 2936     7         indoor/outdoor seat cushion
# 2937     8           outdoor seat/back cushion
# 2938     9      outdoor sunbrella seat cushion
# 2939    10                    gel seat cushion
#
#                                     product_description  grade
# 2930  the classic buffalo check pattern comes to lif...    1.0
# 2931  work and drive in absolute comfort with the er...    2.0
# 2932  hard cushions are the most popular choice in t...    1.0
# 2933  add personality and comfort to your outdoor pa...    1.0
# 2934  the deluxe seat and back cushion by sacro-ease...    1.0
# 2935  this seat & back deep seating cushions feature...    1.0
# 2936  become your own personal designer with their f...    1.0
# 2937  this seat and back cushion adds a boost of sof...    1.0
# 2938  this outdoor wicker seat cushion is made for c...    0.0
# 2939  sleekly designed with an ergonomic shape for r...    2.0

# %%
against_ideal = vs_ideal(graded_syns)
against_ideal[against_ideal['query'] == QUERY]
# Out:
#       query_id            query  ideal_product_id  ideal_id ideal_label  \
# 4300       440  wood bar stools               249    188394       Exact
# 4301       440  wood bar stools               558    188175       Exact
# 4302       440  wood bar stools               769    187948       Exact
# 4303       440  wood bar stools               797    188180       Exact
# 4304       440  wood bar stools               844    188451       Exact
# 4305       440  wood bar stools               849     47092       Exact
# 4306       440  wood bar stools               858    188433       Exact
# 4307       440  wood bar stools               873    188260       Exact
# 4308       440  wood bar stools               906    188370       Exact
# 4309       440  wood bar stools               956    188338       Exact
#
#       ideal_grade  ideal_rank  product_id  \
# 4300          2.0           1         249
# 4301          2.0           2         558
# 4302          2.0           3         769
# 4303          2.0           4         797
# 4304          2.0           5         844
# 4305          2.0           6         849
# 4306          2.0           7         858
# 4307          2.0           8         873
# 4308          2.0           9         906
# 4309          2.0          10         956
#
#                              ideal_product_name  rank  product_id_actual  \
# 4300       chip upholstered bar & counter stool     1               4888
# 4301                  whitworth 24 '' bar stool     2              37300
# 4302                  aspremont 25 '' bar stool     3              18420
# 4303                   caufield 25 '' bar stool     4               4884
# 4304                 harner bar & counter stool     5               4891
# 4305                 galliher 24.5 '' bar stool     6              34277
# 4306              aubrianna bar & counter stool     7               4902
# 4307                    mayfair 30 '' bar stool     8              39984
# 4308                mccowen bar & counter stool     9              17625
# 4309  altamirano solid wood 24 '' counter stool    10              24132
#
#                             product_name_actual  grade       dcg      ndcg
# 4300  gollapalli solid wood bar & counter stool    1.0  4.767857  0.542609
# 4301    axelle solid wood bar and counter stool    1.0  4.767857  0.542609
# 4302   stockdove solid wood bar & counter stool    2.0  4.767857  0.542609
# 4303  abramowitz solid wood bar & counter stool    2.0  4.767857  0.542609
# 4304      khanna solid wood bar & counter stool    1.0  4.767857  0.542609
# 4305   crystelle solid wood bar & counter stool    1.0  4.767857  0.542609
# 4306      wooden solid wood bar & counter stool    1.0  4.767857  0.542609
# 4307             solid wood bar & counter stool    2.0  4.767857  0.542609
# 4308       adona solid wood bar & counter stool    2.0  4.767857  0.542609
# 4309   bergstrom solid wood bar & counter stool    2.0  4.767857  0.542609

# %%
query_to_syn(QUERY)
# Out:
# QueryWithSynonyms(keywords='wood bar stools', synonyms=[SynonymMapping(phrase='wood', synonyms=['timber', 'lumber', 'wooden']), SynonymMapping(phrase='bar stools', synonyms=['counter stools', 'bar chairs', 'pub stools'])])
