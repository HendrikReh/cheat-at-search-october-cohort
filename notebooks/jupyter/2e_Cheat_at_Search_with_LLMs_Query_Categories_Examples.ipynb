# %% [markdown]
# # Query -> Category
#
# <small>
# (from <a href="http://maven.com/softwaredoug/cheat-at-search">Cheat at Search with LLMs</a> training course by Doug Turnbull.)
# </small>
#
# **Refinement** -- Give some hints we see from the furniture data
#
# We learned that we want to try to model aspects of the user's _information need_ not just make queries better.
#
# One such common dimension is query -> category classification

# %% [markdown]
# ## Boilerplate
#
# Install deps, mount GDrive, prompt for your OpenAI Key (placed in your GDrive)

# %%
# !pip install git+https://github.com/softwaredoug/cheat-at-search.git
# Out:
# Collecting git+https://github.com/softwaredoug/cheat-at-search.git
#   Cloning https://github.com/softwaredoug/cheat-at-search.git to /tmp/pip-req-build-kajfqg67
#   Running command git clone --filter=blob:none --quiet https://github.com/softwaredoug/cheat-at-search.git /tmp/pip-req-build-kajfqg67
#   Resolved https://github.com/softwaredoug/cheat-at-search.git to commit 7fbf2bf2845343912918f337a29127f9edc50bd2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-genai<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.31.0)
# Requirement already satisfied: openai<2.0.0,>=1.84.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.101.0)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.2.2)
# Collecting pyarrow<22.0.0,>=21.0.0 (from cheat_at_search==0.1.0)
#   Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.11.7)
# Collecting pystemmer<4.0.0,>=3.0.0 (from cheat_at_search==0.1.0)
#   Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Collecting searcharray<0.0.73,>=0.0.72 (from cheat_at_search==0.1.0)
#   Downloading searcharray-0.0.72-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (0.10.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.4.1)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from searcharray<0.0.73,>=0.0.72->cheat_at_search==0.1.0) (3.0.12)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.6.1)
# Downloading pyarrow-21.0.0-cp312-cp312-manylinux_2_28_x86_64.whl (42.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.8/42.8 MB 21.5 MB/s eta 0:00:00
# Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (745 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.3/745.3 kB 42.3 MB/s eta 0:00:00
# Downloading searcharray-0.0.72-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 63.1 MB/s eta 0:00:00
# Building wheels for collected packages: cheat_at_search
#   Building wheel for cheat_at_search (pyproject.toml) ... done
#   Created wheel for cheat_at_search: filename=cheat_at_search-0.1.0-py3-none-any.whl size=28125 sha256=d79ddefa4e5881651692ac6a334752165c4fd3a5b606f8abee953f566b5d58ce
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xpiv_wol/wheels/ea/96/d3/e69453e5f86e6f891864e5b5baf2b11ffda2d0981d9f8a138e
# Successfully built cheat_at_search
# Installing collected packages: pystemmer, pyarrow, searcharray, cheat_at_search
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 21.0.0 which is incompatible.
# Successfully installed cheat_at_search-0.1.0 pyarrow-21.0.0 pystemmer-3.0.0 searcharray-0.0.72

# %%
from google.colab import drive
import os

# To persist a cache of data between different versions of the training
drive.mount('/content/drive/')
# !mkdir -p /content/drive/MyDrive/cheat-at-search-data/
os.environ['CHEAT_AT_SEARCH_DATA_PATH'] = '/content/drive/MyDrive/cheat-at-search-data/'
# Out:
# Mounted at /content/drive/

# %%
from cheat_at_search.data_dir import ensure_data_subdir, DATA_PATH
print(f"Using {DATA_PATH} for data")
if not os.path.exists(os.path.join(DATA_PATH, 'openai_key.txt')):
    # Write key
    key = input("Enter your openai key: ")
    with open(os.path.join(DATA_PATH, 'openai_key.txt'), 'w') as f:
        f.write(key)
else:
    print("Found openai key on filesystem")
# Out:
# 2025-08-31 21:29:07,491 - data_dir - INFO - Using WANDS data path from environment variable: /content/drive/MyDrive/cheat-at-search-data/
# INFO:data_dir:Using WANDS data path from environment variable: /content/drive/MyDrive/cheat-at-search-data/
# Using /content/drive/MyDrive/cheat-at-search-data/ for data
# Found openai key on filesystem

# %% [markdown]
# ## Import helpers
#
# Helpers to compute ndcg of each query and other comparison functions

# %%
from cheat_at_search.search import run_strategy, graded_bm25, ndcgs, ndcg_delta, vs_ideal
# Out:
# 2025-08-31 21:29:08,151 - data_dir - INFO - Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# INFO:data_dir:Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# 2025-08-31 21:29:29,773 - data_dir - INFO - Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# INFO:data_dir:Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# 2025-08-31 21:29:31,642 - data_dir - INFO - Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# INFO:data_dir:Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# 2025-08-31 21:29:35,994 - data_dir - INFO - Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# INFO:data_dir:Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# 2025-08-31 21:29:36,005 - data_dir - INFO - Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# INFO:data_dir:Directory /content/drive/MyDrive/cheat-at-search-data/wands_enriched already exists. Checking for updates...
# 2025-08-31 21:29:38,159 - data_dir - INFO - Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched
# INFO:data_dir:Updated https://github.com/softwaredoug/WANDS.git dataset at /content/drive/MyDrive/cheat-at-search-data/wands_enriched

# %% [markdown]
# ## Import WANDS data
#
# Import [Wayfair Annotated Dataset](https://github.com/wayfair/WANDS) a labeled furniture e-commerce dataset

# %%
from cheat_at_search.wands_data import products

products
# Out:
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features             category  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...           Furniture
# 1      [capacityquarts:7, producttype : slow cooker, ...  Kitchen & Tabletop
# 2      [features : keep warm setting, capacityquarts:...  Kitchen & Tabletop
# 3      [overallwidth-sidetoside:3.5, warrantylength :...     Browse By Brand
# 4      [compatibledoorthickness:1.375 '' , countryofo...    Home Improvement
# ...                                                  ...                  ...
# 42989  [producttype : shower panel, spraypattern : ra...    Home Improvement
# 42990  [basematerialdetails : steel,  : gray wood, of...           Furniture
# 42991  [additionaltoolsrequirednotincluded : power dr...           Furniture
# 42992  [legmaterialdetails : rubberwood, backheight-s...           Furniture
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...           Furniture
#
#                                  sub_category  \
# 0                          Bedroom Furniture
# 1                   Small Kitchen Appliances
# 2                   Small Kitchen Appliances
# 3                                    All-Clad
# 4                      Doors & Door Hardware
# ...                                       ...
# 42989   Bathroom Remodel & Bathroom Fixtures
# 42990             Kitchen & Dining Furniture
# 42991             Kitchen & Dining Furniture
# 42992                  Living Room Furniture
# 42993             Kitchen & Dining Furniture
#
#                                               cat_subcat
# 0                       Furniture  /  Bedroom Furniture
# 1       Kitchen & Tabletop  /  Small Kitchen Appliances
# 2       Kitchen & Tabletop  /  Small Kitchen Appliances
# 3                           Browse By Brand  /  All-Clad
# 4            Home Improvement  /  Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement  /  Bathroom Remodel & Bathro...
# 42990          Furniture  /  Kitchen & Dining Furniture
# 42991          Furniture  /  Kitchen & Dining Furniture
# 42992               Furniture  /  Living Room Furniture
# 42993          Furniture  /  Kitchen & Dining Furniture
#
# [42994 rows x 13 columns]

# %% [markdown]
# ## Query -> Full classification
#
# We'll first setup the model of query -> category and subcategory. We've precurated categories / subcategories for you to help.

# %%
from pydantic import BaseModel, Field
from typing import List, Literal
from cheat_at_search.enrich import AutoEnricher

from typing import Literal, get_args
FullyQualifiedClassifications = Literal[
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs',
 'Rugs / Area Rugs',
 'Furniture / Office Furniture / Desks',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows',
 'Furniture / Bedroom Furniture / Dressers & Chests',
 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities',
 'Furniture / Living Room Furniture / Console Tables',
 'Décor & Pillows / Art / All Wall Art',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs',
 'Furniture / Office Furniture / Office Chairs',
 'Décor & Pillows / Mirrors / All Mirrors',
 'Bed & Bath / Bedding / All Bedding',
 'Décor & Pillows / Wall Décor / Wall Accents',
 'Furniture / Living Room Furniture / Chairs & Seating / Recliners',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen and Dining Sets',
 'Décor & Pillows / Window Treatments / Curtains & Drapes',
 'Furniture / Living Room Furniture / Sectionals',
 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / TV Stands & Entertainment Centers',
 'Lighting / Ceiling Lights / Chandeliers',
 'Furniture / Bedroom Furniture / Nightstands',
 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Desks',
 'Décor & Pillows / Home Accessories / Decorative Objects',
 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards',
 'Furniture / Living Room Furniture / Sofas',
 'Furniture / Living Room Furniture / Cabinets & Chests',
 'Décor & Pillows / Clocks / Wall Clocks',
 'Storage & Organization / Bathroom Storage & Organization / Bathroom Cabinets & Shelving',
 'Lighting / Table & Floor Lamps / Table Lamps',
 'Furniture / Living Room Furniture / Ottomans & Poufs',
 'Furniture / Kitchen & Dining Furniture / Kitchen Islands & Carts',
 'Furniture / Living Room Furniture / Bookcases',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals',
 'Furniture / Office Furniture / Office Storage Cabinets',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables',
 'Contractor / Entry & Hallway / Coat Racks & Umbrella Stands',
 'Bed & Bath / Bedding Essentials / Mattress Pads & Toppers',
 'Home Improvement / Hardware / Home Hardware / Switch Plates',
 'Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Patio Furniture Covers',
 'Rugs / Doormats',
 'Rugs / Kitchen Mats',
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds',
 'Furniture / Bedroom Furniture / Daybeds',
 'Furniture / Living Room Furniture / Living Room Sets',
 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets',
 'Outdoor / Outdoor Décor / Statues & Sculptures',
 'Décor & Pillows / Art / All Wall Art / Green Wall Art',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets',
 'Furniture / Living Room Furniture / Chairs & Seating / Chaise Lounge Chairs',
 'Storage & Organization / Wall Shelving & Organization / Wall and Display Shelves',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Rectangle Coffee Tables',
 'Décor & Pillows / Art / All Wall Art / Brown Wall Art',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools / Counter (24-27) Bar Stools & Counter Stools',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables',
 'Décor & Pillows / Window Treatments / Curtain Hardware & Accessories',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs / Side Kitchen & Dining Chairs',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs',
 'Furniture / Living Room Furniture / Chairs & Seating / Benches',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks',
 'Kitchen & Tabletop / Kitchen Organization / Food Pantries',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Deck Boxes & Patio Storage',
 'Outdoor / Garden / Planters',
 'Lighting / Wall Lights / Bathroom Vanity Lighting',
 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Bronze Cabinet & Drawer Pulls',
 'Storage & Organization / Storage Containers & Drawers / All Storage Containers',
 'Bed & Bath / Shower Curtains & Accessories / Shower Curtains & Shower Liners',
 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets',
 'Lighting / Light Bulbs & Hardware / Light Bulbs / All Light Bulbs / LED Light Bulbs',
 'Décor & Pillows / Art / All Wall Art / Blue Wall Art',
 'Bed & Bath / Mattresses & Foundations / Innerspring Mattresses',
 'Lighting / Outdoor Lighting / Outdoor Wall Lighting',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Natural Material Storage / Log Storage',
 'Bed & Bath / Bathroom Accessories & Organization / Countertop Bath Accessories',
 'Storage & Organization / Shoe Storage / All Shoe Storage',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Ceramic Floor Tiles & Wall Tiles',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls',
 'Bed & Bath / Mattresses & Foundations / Adjustable Beds',
 "Rugs / Area Rugs / 2' x 3' Area Rugs",
 'Commercial Business Furniture / Commercial Office Furniture / Office Storage & Filing / Office Carts & Stands / All Carts & Stands',
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets',
 "Rugs / Area Rugs / 4' x 6' Area Rugs",
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets',
 'Kitchen & Tabletop / Tableware & Drinkware / Table & Kitchen Linens / All Table Linens',
 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers',
 'Décor & Pillows / Flowers & Plants / Faux Flowers',
 'Bed & Bath / Bedding / All Bedding / Twin Bedding',
 'Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Porcelain Floor Tiles & Wall Tiles',
 'Home Improvement / Flooring, Walls & Ceiling / Flooring Installation & Accessories / Molding & Millwork / Wall Molding & Millwork',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Barn Door Hardware',
 'Bed & Bath / Bedding / Sheets & Pillowcases',
 'Furniture / Office Furniture / Chair Mats / Hard Floor Chair Mats',
 'Outdoor / Outdoor Fencing & Flooring / All Fencing',
 'Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks',
 'Kitchen & Tabletop / Kitchen Utensils & Tools / Colanders, Strainers, & Salad Spinners',
 'Outdoor / Hot Tubs & Saunas / Saunas',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Blue Throw Pillows',
 'Bed & Bath / Bedding Essentials / Bed Pillows',
 'Lighting / Wall Lights / Wall Sconces',
 'Outdoor / Front Door Décor & Curb Appeal / Mailboxes',
 'Outdoor / Garden / Greenhouses',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Faucets & Systems',
 'Bed & Bath / Mattresses & Foundations / Queen Mattresses',
 'Furniture / Bedroom Furniture / Jewelry Armoires',
 'Outdoor / Outdoor Shades / Awnings',
 'Baby & Kids / Nursery Bedding / Crib Bedding Sets',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Brass Cabinet & Drawer Knobs',
 'Décor & Pillows / Art / All Wall Art / Red Wall Art',
 'Lighting / Ceiling Lights / All Ceiling Lights',
 'Lighting / Light Bulbs & Hardware / Lighting Components',
 'Furniture / Game Tables & Game Room Furniture / Poker & Card Tables',
 'Appliances / Kitchen Appliances / Range Hoods / All Range Hoods',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools / Bar (28-33) Bar Stools & Counter Stools',
 'Outdoor / Outdoor Cooking & Tableware / Outdoor Serving & Tableware / Coolers, Baskets & Tubs / Picnic Baskets & Backpacks',
 'Décor & Pillows / Picture Frames & Albums / All Picture Frames',
 'Bed & Bath / Shower Curtains & Accessories / Shower Curtain Hooks',
 'Outdoor / Outdoor Shades / Outdoor Umbrellas / Patio Umbrella Stands & Bases',
 'Outdoor / Outdoor & Patio Furniture / Patio Bar Furniture / Patio Bar Stools',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Toilets & Bidets / Toilet Paper Holders / Free Standing Toilet Paper Holders',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Bike & Sport Racks',
 'Appliances / Kitchen Appliances / Refrigerators & Freezers / All Refrigerators / French Door Refrigerators',
 'Décor & Pillows / Home Accessories / Decorative Trays',
 'School Furniture and Supplies / School Spaces / Computer Lab Furniture / Podiums & Lecterns',
 'Lighting / Light Bulbs & Hardware / Lighting Shades',
 'Furniture / Kitchen & Dining Furniture / Bar Furniture / Home Bars & Bar Sets',
 'Lighting / Table & Floor Lamps / Floor Lamps',
 'Décor & Pillows / Wall Décor / Wall Accents / Brown Wall Accents',
 'Kitchen & Tabletop / Small Kitchen Appliances / Pressure & Slow Cookers / Slow Cookers / Slow Slow Cookers',
 'Décor & Pillows / Window Treatments / Curtains & Drapes / 90 Inch Curtains & Drapes',
 'Furniture / Bedroom Furniture / Armoires & Wardrobes',
 'Kitchen & Tabletop / Tableware & Drinkware / Flatware & Cutlery / Serving Utensils',
 'Baby & Kids / Baby & Kids Décor & Lighting / All Baby & Kids Wall Art',
 'Furniture / Office Furniture / Desks / Writing Desks',
 'Furniture / Office Furniture / Office Chairs / Task Office Chairs',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Shower & Bathtub Doors',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Rocking Chairs & Gliders',
 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Wall Paneling',
 'Outdoor / Garden / Plant Stands & Accessories',
 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables / 4 Seat Kitchen & Dining Tables',
 'Décor & Pillows / Home Accessories / Vases, Urns, Jars & Bottles',
 'Lighting / Wall Lights / Under Cabinet Lighting / Strip Under Cabinet Lighting',
 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities',
 'Pet / Dog / Dog Bowls & Feeding Supplies / Pet Bowls & Feeders',
 'Décor & Pillows / Candles & Holders / Candle Holders',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Shower & Bathtub Accessories',
 'Furniture / Office Furniture / Office Chair Accessories / Seat Cushion Office Chair Accessories',
 'Furniture / Office Furniture / Chair Mats',
 'Furniture / Living Room Furniture / Chairs & Seating / Massage Chairs',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities / Modern & Contemporary Bathroom Vanities',
 'Lighting / Ceiling Fans / All Ceiling Fans',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Black Kitchen Faucets',
 'Lighting / Light Bulbs & Hardware / Light Bulbs / All Light Bulbs / Incandescent Light Bulbs',
 'Home Improvement / Flooring, Walls & Ceiling / Flooring Installation & Accessories / Molding & Millwork',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Bathtubs',
 'Décor & Pillows / Art / All Wall Art / Yellow Wall Art',
 'Pet / Dog / Pet Gates, Fences & Doors / Pet Gates',
 'Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel Bars, Racks, and Stands / Metal Towel Bars, Racks, and Stands',
 'Décor & Pillows / Art / All Wall Art / Pink Wall Art',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Smoke Detectors / Wall & Ceiling Mounted Smoke Detectors',
 'Outdoor / Garden / Planters / Plastic Planters',
 'Décor & Pillows / Mirrors / All Mirrors / Accent Mirrors',
 'Appliances / Kitchen Appliances / Range Hoods / All Range Hoods / Wall Mount Range Hoods',
 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Round Coffee Tables',
 'Kitchen & Tabletop / Tableware & Drinkware / Dinnerware / Dining Bowls',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads / Dual Shower Heads',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Glass Floor Tiles & Wall Tiles',
 'School Furniture and Supplies / Facilities & Maintenance / Trash & Recycling',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Nickel Cabinet & Drawer Pulls',
 'Storage & Organization / Closet Storage & Organization / Closet Systems',
 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds',
 'Commercial Business Furniture / Commercial Office Furniture / Office Storage & Filing / Office Carts & Stands / All Carts & Stands / Printer Carts & Stands',
 'Storage & Organization / Closet Storage & Organization / Closet Accessories',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities / Traditional Bathroom Vanities',
 'Home Improvement / Plumbing / Core Plumbing / Parts & Components',
 'Holiday Décor / Christmas / Christmas Trees / All Christmas Trees',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Black Throw Pillows',
 'Furniture / Game Tables & Game Room Furniture / Sports Team Fan Shop & Memorabillia / Life Size Cutouts',
 'Lighting / Ceiling Lights / Pendant Lighting',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks',
 'Appliances / Washers & Dryers / Dryers / All Dryers / Gas Dryers',
 'Outdoor / Outdoor Recreation / Backyard Play / Kids Cars & Ride-On Toys',
 'Kitchen & Tabletop / Small Kitchen Appliances / Coffee, Espresso, & Tea / Coffee Makers',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals / Sectional Patio Sofas & Sectionals',
 'Lighting / Wall Lights / Under Cabinet Lighting',
 'Foodservice / Foodservice Tables / Table Parts',
 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting / Fence Post Cap Landscape Lighting',
 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables',
 'Commercial Business Furniture / Commercial Office Furniture / Office Storage & Filing / Office Carts & Stands / All Carts & Stands / Utility Carts & Stands',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs',
 'Furniture / Living Room Furniture / Chairs & Seating / Recliners / Brown Recliners',
 'Pet / Bird / Bird Perches & Play Gyms',
 'Décor & Pillows / Picture Frames & Albums / All Picture Frames / Single Picture Picture Frames',
 'Lighting / Outdoor Lighting / Outdoor Lanterns & Lamps',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls',
 'Bed Accessories',
 'Clips/Clamps',
 'Décor & Pillows / Wall Décor / Wall Decals',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles',
 'Bed & Bath / Bedding / Sheets & Pillowcases / Twin XL Sheets & Pillowcases',
 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters',
 'Holiday Décor / Holiday Lighting',
 'Décor & Pillows / Wall Décor / Memo Boards',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Toilets & Bidets / Toilet Paper Holders / Wall Mounted Toilet Paper Holders',
 'Décor & Pillows / Window Treatments / Curtains & Drapes / 63 Inch and Less Curtains & Drapes',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Knobs / Egg Door Knobs',
 'Décor & Pillows / Clocks / Wall Clocks / Analog Wall Clocks',
 'Home Improvement / Doors & Door Hardware / Interior Doors / Sliding Interior Doors',
 'Outdoor / Outdoor Recreation / Outdoor Games / All Outdoor Games',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Levers / Round Door Levers',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Sheds / Storage Sheds',
 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Levers',
 'School Furniture and Supplies / School Furniture / School Tables / Folding Tables / Wood Folding Tables',
 'Décor & Pillows / Wall Décor / Wall Accents / Green Wall Accents',
 'School Furniture and Supplies / Facilities & Maintenance / Commercial Signage',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Garage Storage Cabinets',
 'Furniture / Bedroom Furniture / Dressers & Chests / Beige Dressers & Chests',
 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves',
 'Furniture / Game Tables & Game Room Furniture / Dartboards & Cabinets',
 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Lounge Chair Patio Furniture Cushions',
 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets / Two Person Patio Dining Sets',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / Ivory & Cream Throw Pillows',
 'Appliances / Washers & Dryers / Washer & Dryer Sets / Black Washer & Dryer Sets',
 'School Furniture and Supplies / School Furniture / School Chairs & Seating / Stackable Chairs',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Brass Cabinet & Drawer Pulls',
 'School Furniture and Supplies / School Boards & Technology / AV, Mounts & Tech Accessories / Electronic Mounts & Stands / Computer Mounts',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Papasan Accent Chairs',
 'Storage & Organization / Shoe Storage / All Shoe Storage / Rack Shoe Storage',
 'Storage & Organization / Shoe Storage / All Shoe Storage / Cabinet Shoe Storage',
 'Storage & Organization / Storage Containers & Drawers / Storage Drawers',
 'Appliances / Kitchen Appliances / Wine & Beverage Coolers / Water Coolers',
 'Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs',
 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Bowls & Baskets / Serving Bowls / NA Serving Bowls',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Inflatable Projection Screens',
 'Appliances / Kitchen Appliances / Large Appliance Parts & Accessories',
 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets / Laundry Hampers & Laundry Baskets',
 'Furniture / Office Furniture / Office Stools',
 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs / Metal Outdoor Club Chairs',
 'School Furniture and Supplies / School Furniture / School Tables / Folding Tables',
 'Lighting / Wall Lights / Bathroom Vanity Lighting / Traditional Bathroom Vanity Lighting',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Centerset Bathroom Sink Faucets',
 'Décor & Pillows / Flowers & Plants / Faux Flowers / Orchid Faux Flowers',
 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Metal Floor Tiles & Wall Tiles',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks',
 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Grill Covers / Charcoal Grill Grill Covers',
 'Outdoor / Outdoor Décor / Outdoor Wall Décor',
 'Storage & Organization / Cleaning & Laundry Organization / Laundry Room Organizers',
 'Reception Area / Reception Seating / Reception Sofas & Loveseats',
 'Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans / Steel Bread & Loaf Pans',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Wingback Accent Chairs',
 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads / Fixed Shower Heads',
 'Kitchen & Tabletop / Kitchen Utensils & Tools / Kitchen Gadgets / Pasta Makers & Accessories',
 'School Furniture and Supplies / School Furniture / School Chairs & Seating / Classroom Chairs / High School & College Classroom Chairs',
 'Furniture / Living Room Furniture / Sectionals / Stationary Sectionals',
 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets / Drawer Equipped Sideboards & Buffets',
 'Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans',
 'Kitchen & Tabletop / Kitchen Utensils & Tools / Cooking Utensils / All Cooking Utensils / Kitchen Cooking Utensils',
 'Décor & Pillows / Flowers & Plants / Live Plants',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / Projection Screens / Folding Frame Projection Screens',
 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars',
 'Outdoor / Outdoor Décor / Outdoor Fountains',
 'Outdoor / Outdoor Shades / Pergolas / Wood Pergolas',
 'Décor & Pillows / Candles & Holders / Candle Holders / Sconce Candle Holders',
 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Cake & Tiered Stands',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Chrome Kitchen Faucets',
 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows / White Throw Pillows',
 'Outdoor / Outdoor Fencing & Flooring / Turf',
 'Décor & Pillows / Window Treatments / Valances & Kitchen Curtains',
 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs',
 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Bronze Kitchen Faucets',
 'Appliances / Washers & Dryers / Washer & Dryer Sets',
 'Décor & Pillows / Clocks / Mantel & Tabletop Clocks',
 'Home Improvement / Doors & Door Hardware / Interior Doors',
 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves / Floating Wall & Display Shelves',
 'Outdoor / Outdoor Recreation / Backyard Play / Climbing Toys & Slides',
 'Home Improvement / Building Equipment / Dollies / Hand Truck Dollies',
 'Baby & Kids / Toddler & Kids Bedroom Furniture / Baby & Kids Dressers',
 'Décor & Pillows / Mirrors / All Mirrors / Leaning & Floor Mirrors',
 'Kitchen & Tabletop / Tableware & Drinkware / Drinkware / Mugs & Teacups',
 'Décor & Pillows / Flowers & Plants / Wreaths',
 'Outdoor / Outdoor Shades / Pergolas / Metal Pergolas',
 'Bed & Bath / Bedding / Sheets & Pillowcases / Twin Sheets & Pillowcases',
 'Outdoor / Outdoor Shades / Pergolas',
 'Reception Area / Reception Seating / Office Sofas & Loveseats',
 'Décor & Pillows / Home Accessories / Indoor Fountains',
 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Ceramic Kitchen Canisters & Jars',
 'Décor & Pillows / Window Treatments / Curtain Hardware & Accessories / Bracket Curtain Hardware & Accessories',
 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Accent Tiles / Ceramic Accent Tiles',
 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Accent Tiles',
 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Arm Accent Chairs',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Free Form Coffee Tables',
 'Décor & Pillows / Flowers & Plants / Faux Flowers / Rose Faux Flowers',
 'Bed & Bath / Mattresses & Foundations / Innerspring Mattresses / Twin Innerspring Mattresses',
 'Outdoor / Outdoor Décor / Outdoor Pillows & Cushions / Patio Furniture Cushions / Dining Chair Patio Furniture Cushions',
 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / TV Stands & Entertainment Centers / Traditional TV Stands & Entertainment Centers',
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables / Square Plant Stands & Tables',
 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves / Corner Wall & Display Shelves',
 "Rugs / Area Rugs / 3' x 5' Area Rugs",
 'Kitchen & Tabletop / Tableware & Drinkware / Drinkware / Mugs & Teacups / Coffee Mugs & Teacups',
 'Contractor / Entry & Hallway / Coat Racks & Umbrella Stands / Wall Mounted Coat Racks & Umbrella Stands',
 "Baby & Kids / Toddler & Kids Playroom / Indoor Play / Kids' Playhouses",
 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables / Square Coffee Tables',
 'Baby & Kids / Toddler & Kids Playroom / Indoor Play / Dollhouses & Accessories',
 'Bed & Bath / Bedding / All Bedding / Queen Bedding',
 'No Classification Fits'
]

classifications_list = sorted(get_args(FullyQualifiedClassifications))

known_categories = set([c.split(" / ")[0].strip() for c in classifications_list])
known_sub_categories = set([c.split(" / ")[1].strip() for c in classifications_list if len(c.split(" / ")) > 1])

known_sub_categories


class Query(BaseModel):
    """
    Base model for search queries, containing common query attributes.
    """
    keywords: str = Field(
        ...,
        description="The original search query keywords sent in as input"
    )


class QueryClassification(Query):
    """
    Structured representation of a search query for furniture e-commerce.
    Inherits keywords from the base Query model and adds category and sub-category.
    """
    classifications: list[FullyQualifiedClassifications] = Field(
        description="A possible classification for the product."
    )

    @property
    def categories(self):
        return set([c.split(" / ")[0] for c in self.classifications])

    @property
    def sub_categories(self):
        return set([c.split(" / ")[1] for c in self.classifications if len(c.split(" / ")) > 1])

# %% [markdown]
# ### Query classification code

# %%
enricher = AutoEnricher(
     model="openai/gpt-4.1-nano",
     system_prompt="You are a helpful furniture shopping agent that helps users construct search queries.",
     response_model=QueryClassification
)

def get_prompt_fully_qualified(query):
        prompt = f"""
        As a helpful agent, you'll recieve requests from users looking for furniture products.

        Your task is to search with a structured query against a furniture product catalog.

        Here is the users request:

        {query}

        Return the best classifications for this user's query.

        Try to pick as diverse a set of possible to ensure the customer finds what they need.
        (IE different top level categories are better than very similar classifications that share most of their tree / subtree)

        Keep in mind some notes about the furniture domain
        * bistro tables are for outdoors
        *

        Return an empty list if no classification fits, or its too ambiguous.

        """

        return prompt

def fully_classified(query):
    prompt = get_prompt_fully_qualified(query)
    classification = enricher.enrich(prompt).model_copy()
    if "No Classification Fits" in classification.classifications:
        classification.classifications = []
    return classification

fully_classified("dinosaur"), fully_classified("sofa loveseat")
# Out:
# 2025-08-31 21:29:43,727 - data_dir - INFO - Looking for openai in environment variables or globals...
# INFO:data_dir:Looking for openai in environment variables or globals...
# 2025-08-31 21:29:43,729 - data_dir - INFO - Reading openai_api_key API key from /content/drive/MyDrive/cheat-at-search-data//keys.json
# INFO:data_dir:Reading openai_api_key API key from /content/drive/MyDrive/cheat-at-search-data//keys.json
# 2025-08-31 21:29:43,938 - data_dir - INFO - openai_api_key key loaded successfully.
# INFO:data_dir:openai_api_key key loaded successfully.
# 2025-08-31 21:29:44,416 - query_parser - INFO - Loading enrich cache from /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3e979c5575201e6082871b9e34bd5889_cache.pkl
# INFO:query_parser:Loading enrich cache from /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3e979c5575201e6082871b9e34bd5889_cache.pkl
# 2025-08-31 21:29:45,495 - query_parser - ERROR - Error loading cache file /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3e979c5575201e6082871b9e34bd5889_cache.pkl: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# ERROR:query_parser:Error loading cache file /content/drive/MyDrive/cheat-at-search-data/enrich_cache/openaienricher_3e979c5575201e6082871b9e34bd5889_cache.pkl: 'utf-8' codec can't decode byte 0x80 in position 0: invalid start byte
# 2025-08-31 21:29:45,499 - query_parser - ERROR - Starting with empty cache due to error.
# ERROR:query_parser:Starting with empty cache due to error.
# (QueryClassification(keywords='dinosaur', classifications=['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']),
#  QueryClassification(keywords='sofa loveseat', classifications=['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']))

# %% [markdown]
# ### Redefine ground truth

# %%
CUTOFF = 0.8

from cheat_at_search.wands_data import labeled_query_products, queries

# Get relevant products per query
top_products = labeled_query_products[labeled_query_products['grade'] == 2]

# Aggregate top categories
categories_per_query_ideal = top_products.groupby('query')['category'].value_counts().reset_index()

# Get as percentage of all categories for this query
top_cat_proportion = categories_per_query_ideal.groupby(['query', 'category']).sum() / categories_per_query_ideal.groupby('query').sum()
top_cat_proportion = top_cat_proportion.drop(columns='category').reset_index()

# Only look at cases where the category is > 0.8
top_cat_proportion = top_cat_proportion[top_cat_proportion['count'] > CUTOFF]
top_cat_proportion['category'].fillna('No Category Fits', inplace=True)
ground_truth_cat = top_cat_proportion
# Give No Category Fits to all others without dominant category
ground_truth_cat = ground_truth_cat.merge(queries, how='right', on='query')[['query', 'category', 'count']]
ground_truth_cat['category'].fillna('No Category Fits', inplace=True)
ground_truth_cat
# Out:
# /tmp/ipython-input-422174659.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_cat_proportion['category'].fillna('No Category Fits', inplace=True)
# /tmp/ipython-input-422174659.py:21: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ground_truth_cat['category'].fillna('No Category Fits', inplace=True)
#                                                  query          category  \
# 0                                          salon chair  No Category Fits
# 1                                   smart coffee table        Furniture
# 2                                             dinosaur  No Category Fits
# 3                                    turquoise pillows  Décor & Pillows
# 4                            chair and a half recliner        Furniture
# ..                                                 ...               ...
# 475                                        rustic twig  Décor & Pillows
# 476  nespresso vertuo next premium by breville with...  No Category Fits
# 477                                     pedistole sink  No Category Fits
# 478                                54 in bench cushion  No Category Fits
# 479                                         rack glass  No Category Fits
#
#         count
# 0         NaN
# 1    1.000000
# 2         NaN
# 3    0.963636
# 4    0.956522
# ..        ...
# 475  1.000000
# 476       NaN
# 477       NaN
# 478       NaN
# 479       NaN
#
# [480 rows x 3 columns]

# %%
def prec_cat(categorized):
    hits = []
    misses = []
    idx = 0
    for _, row in ground_truth_cat.sample(frac=1).iterrows():
        query = row['query']
        expected_category = row['category']

        cat = categorized(query)
        if len(cat.classifications) == 0:
            print(f"{idx} Skipping {query}")
            continue
        if expected_category != "No Category Fits":
            if expected_category.strip() in cat.categories:
                print(f"{idx} q:{query} -- pred:{cat.categories} == expected:{expected_category.strip()}")
                hits.append((expected_category, cat))
            else:
                print("***")
                print(f"{query} -- pred:{cat.categories} != expected:{expected_category.strip()}")
                print(cat.classifications)
                misses.append((expected_category, cat))
                num_so_far = len(hits) + len(misses)
                print(f"{idx} recall (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
        idx += 1

    return len(hits) / (len(hits) + len(misses)), hits, misses

prec, hits, misses = prec_cat(fully_classified)
prec
# Out:
# 0 q:rose gold lounge -- pred:{'Furniture'} == expected:Furniture
# ***
# foutains with brick look -- pred:{'Décor & Pillows', 'Outdoor'} != expected:
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Outdoor / Outdoor Décor / Outdoor Fountains']
# 1 recall (N=2) -- 0.5
# 2 q:glow in the dark silent wall clock -- pred:{'Lighting', 'Décor & Pillows', 'Home Improvement'} == expected:Décor & Pillows
# 3 q:rolande heavy duty power lift assist recliner -- pred:{'Furniture'} == expected:Furniture
# 4 q:small curtain rods -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 5 q:wine bar -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 6 q:wood rack wide -- pred:{'Furniture', 'Storage & Organization'} == expected:Storage & Organization
# 9 q:cloud modular sectional -- pred:{'Furniture'} == expected:Furniture
# 10 q:tye dye duvet cover -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 11 q:bistro sets patio -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 12 q:itchington butterfly -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 13 q:kohen 5 drawer dresser -- pred:{'Furniture'} == expected:Furniture
# 15 q:kitchen storage shelves -- pred:{'Furniture', 'Storage & Organization'} == expected:Storage & Organization
# 16 q:accent chairs living room -- pred:{'Furniture'} == expected:Furniture
# 17 Skipping kisner
# 18 q:floating bed -- pred:{'Furniture'} == expected:Furniture
# 19 q:block coffee table -- pred:{'Furniture'} == expected:Furniture
# 20 q:refrigerator with ice an water in door -- pred:{'Appliances', 'Home Improvement'} == expected:Appliances
# 22 q:cake cutlery -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# ***
# coat rack for bedroom -- pred:{'Furniture', 'Storage & Organization'} != expected:Contractor
# ['Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks', 'Furniture / Bedroom Furniture / Nightstands', 'Furniture / Bedroom Furniture / Armoires & Wardrobes']
# 24 recall (N=19) -- 0.8947368421052632
# 25 q:writing desk -- pred:{'Furniture'} == expected:Furniture
# 28 q:overstreet rustic pub stools -- pred:{'Furniture'} == expected:Furniture
# 29 q:leather dining chairs -- pred:{'Furniture'} == expected:Furniture
# 30 Skipping wainscoting ideas
# 30 q:mexican art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 32 q:worn leather office chair -- pred:{'Furniture'} == expected:Furniture
# 33 q:marlon tufted queen bed -- pred:{'Furniture'} == expected:Furniture
# 36 q:eiffel tower wall art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 37 q:benjiamino faux leather power lift chair -- pred:{'Furniture'} == expected:Furniture
# 39 Skipping monthly calendar
# 39 q:black 5 drawer dresser by guilford -- pred:{'Furniture'} == expected:Furniture
# ***
# dining table vinyl cloth -- pred:{'Furniture'} != expected:Kitchen & Tabletop
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables']
# 41 recall (N=29) -- 0.896551724137931
# 43 q:king poster bed -- pred:{'Furniture'} == expected:Furniture
# 44 q:wrought tv stand -- pred:{'Furniture'} == expected:Furniture
# ***
# twin over full bunk beds cool desins -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds']
# 45 recall (N=32) -- 0.875
# ***
# kitchen anti fatigue mats -- pred:{'Kitchen & Tabletop', 'Home Improvement'} != expected:Rugs
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles']
# 47 recall (N=33) -- 0.8484848484848485
# 49 q:liberty hardware francisco -- pred:{'Home Improvement'} == expected:Home Improvement
# 51 q:hinged square ottoman -- pred:{'Furniture'} == expected:Furniture
# 52 q:industrial pipe dining  table -- pred:{'Furniture'} == expected:Furniture
# 53 q:huge bookcase -- pred:{'Furniture'} == expected:Furniture
# 54 q:rug for teen room -- pred:{'Furniture', 'Décor & Pillows', 'Rugs'} == expected:Rugs
# 56 q:attleboro drum coffee table -- pred:{'Furniture'} == expected:Furniture
# 57 q:broadway lever -- pred:{'Home Improvement'} == expected:Home Improvement
# 58 q:annex dresser -- pred:{'Furniture'} == expected:Furniture
# ***
# girl reading statue -- pred:{'Décor & Pillows'} != expected:Outdoor
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 59 recall (N=42) -- 0.8571428571428571
# 61 q:real touch roses floral arrangements in glass vase -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 64 q:bowersville ladder writing desk -- pred:{'Furniture'} == expected:Furniture
# 68 q:infant girl crib bedding -- pred:{'Baby & Kids', 'Décor & Pillows', 'Bed & Bath'} == expected:Baby & Kids
# ***
# wood floor protector mat -- pred:{'Décor & Pillows', 'Storage & Organization', 'Home Improvement'} != expected:Furniture
# ['Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Patio Furniture Covers', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 69 recall (N=46) -- 0.8478260869565217
# 71 q:medium size chandelier -- pred:{'Lighting'} == expected:Lighting
# 73 q:brush nickel faucet bathroom -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# deer coat hooks -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:Contractor
# ['Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Nickel Cabinet & Drawer Pulls', 'Décor & Pillows / Wall Décor / Wall Accents / Green Wall Accents']
# 76 recall (N=49) -- 0.8367346938775511
# 78 q:dark gray dresser -- pred:{'Furniture'} == expected:Furniture
# 80 q:ergonomic chair -- pred:{'Furniture'} == expected:Furniture
# 82 q:sheets for twinxl -- pred:{'Bed & Bath'} == expected:Bed & Bath
# 83 q:clear shower curtain -- pred:{'Home Improvement', 'Bed & Bath'} == expected:Bed & Bath
# 84 q:light and navy blue decorative pillow -- pred:{'Furniture', 'Décor & Pillows'} == expected:Décor & Pillows
# 85 q:turquoise pillows -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 87 q:sofa with ottoman -- pred:{'Furniture'} == expected:Furniture
# 94 q:ligth bulb -- pred:{'Lighting'} == expected:Lighting
# 95 Skipping rattan truck
# ***
# luau string lights -- pred:{'Décor & Pillows', 'Outdoor', 'Lighting'} != expected:Holiday Décor
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting / Fence Post Cap Landscape Lighting']
# 95 recall (N=58) -- 0.8448275862068966
# 98 q:burruss patio sectional with cushions -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} == expected:Outdoor
# 99 q:outdoor welcome rug -- pred:{'Rugs', 'Outdoor'} == expected:Rugs
# ***
# shower hooks -- pred:{'Home Improvement'} != expected:Bed & Bath
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks']
# 100 recall (N=61) -- 0.8360655737704918
# 103 q:betty resin free standing umbrella -- pred:{'Outdoor'} == expected:Outdoor
# 104 q:outdoor lounge chair -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 105 q:chinese flower stand -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} == expected:Furniture
# 106 q:queen wingback chair -- pred:{'Furniture'} == expected:Furniture
# 107 q:coma inducer comforter king set -- pred:{'Furniture', 'Décor & Pillows', 'Bed & Bath'} == expected:Bed & Bath
# 108 q:ayesha curry kitchen -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 109 q:hawaii vintage art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 110 q:living curtains pearl -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Décor & Pillows
# 111 q:tufted upholstered bed diamond -- pred:{'Furniture'} == expected:Furniture
# 112 q:front porch furniture sets -- pred:{'Outdoor'} == expected:Outdoor
# 113 q:toilet paper stand -- pred:{'Home Improvement'} == expected:Home Improvement
# 114 q:accent leather chair -- pred:{'Furniture'} == expected:Furniture
# 116 q:driftwood mirror -- pred:{'Furniture', 'Décor & Pillows', 'Home Improvement'} == expected:Décor & Pillows
# ***
# outdoor lounge cushions -- pred:{'Décor & Pillows', 'Outdoor'} != expected:
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 117 recall (N=75) -- 0.8533333333333334
# 119 q:led light strip -- pred:{'Lighting'} == expected:Lighting
# 120 q:waterfall faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# outdoor waterproof chest -- pred:{'Outdoor'} != expected:Storage & Organization
# ['Outdoor / Garden / Garden Décor / Lawn & Garden Accents', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 121 recall (N=78) -- 0.8461538461538461
# 122 q:bed side table -- pred:{'Furniture'} == expected:Furniture
# 124 q:chaise lounge couch -- pred:{'Furniture'} == expected:Furniture
# 125 q:farmhouse cabinet -- pred:{'Furniture'} == expected:Furniture
# 127 q:window wall accent -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 128 q:upholstered girls bed -- pred:{'Furniture'} == expected:Furniture
# 130 q:ines shag rug w003096809 -- pred:{'Rugs'} == expected:Rugs
# 132 q:kari 2 piece -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 133 q:zachary 72.5 -- pred:{'Furniture', 'Outdoor'} == expected:Furniture
# 134 q:3 1/2 inch drawer pull -- pred:{'Home Improvement'} == expected:Home Improvement
# 135 q:king size bed -- pred:{'Furniture'} == expected:Furniture
# 137 q:barstool patio sets -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 139 q:chase utility laundry cart -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 141 q:48 in entry table with side by side drawer -- pred:{'Furniture'} == expected:Furniture
# 142 q:tile backsplash -- pred:{'Home Improvement'} == expected:Home Improvement
# 144 q:gravity feeder -- pred:{'Pet', 'Outdoor'} == expected:Pet
# 145 q:wall shelves -- pred:{'Storage & Organization', 'Home Improvement'} == expected:Storage & Organization
# 146 q:bar stool 24 inches height -- pred:{'Furniture'} == expected:Furniture
# 147 q:mahone porch rocking chair -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# ***
# landis wall mounted bathroom shelves -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:Storage & Organization
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Décor & Pillows / Wall Décor / Wall Accents']
# 149 recall (N=97) -- 0.865979381443299
# 150 q:midcentury tv unit -- pred:{'Furniture'} == expected:Furniture
# 151 q:outdoor sectional dining -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 153 q:chair and a half recliner -- pred:{'Furniture'} == expected:Furniture
# ***
# 48 inch kitchen hood -- pred:{'Home Improvement'} != expected:Appliances
# ['Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks']
# 156 recall (N=101) -- 0.8613861386138614
# 158 q:calvin patio chair -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 159 q:multi color rug -- pred:{'Rugs'} == expected:Rugs
# 160 q:front door cabinet with doors -- pred:{'Furniture', 'Storage & Organization', 'Home Improvement'} == expected:Furniture
# 161 q:smart coffee table -- pred:{'Furniture'} == expected:Furniture
# 163 q:3 piece rug set with runners -- pred:{'Rugs'} == expected:Rugs
# ***
# zakariyah twin platform -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 164 recall (N=107) -- 0.8598130841121495
# 165 q:hillsby oriental rug -- pred:{'Décor & Pillows', 'Rugs'} == expected:Rugs
# 166 q:closet storage with zipper -- pred:{'Storage & Organization'} == expected:Storage & Organization
# ***
# coffee table fire pit -- pred:{'Furniture', 'Outdoor'} != expected:
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets']
# 167 recall (N=110) -- 0.8545454545454545
# 168 q:regner power loom red -- pred:{'Furniture', 'Rugs', 'Home Improvement'} == expected:Rugs
# 169 q:tollette teal outdoor rug -- pred:{'Décor & Pillows', 'Rugs', 'Outdoor'} == expected:Rugs
# 171 q:drum picture -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 172 q:glass lsmp shades -- pred:{'Lighting'} == expected:Lighting
# 180 q:led 60 -- pred:{'Lighting'} == expected:Lighting
# 181 q:fortunat coffee table -- pred:{'Furniture'} == expected:Furniture
# 182 q:small loving roomtables -- pred:{'Furniture'} == expected:Furniture
# ***
# medium clips -- pred:{'Furniture', 'Décor & Pillows', 'Lighting'} != expected:Clips
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Lighting / Wall Lights / Wall Sconces', 'Furniture / Office Furniture / Office Chairs']
# 184 recall (N=118) -- 0.8559322033898306
# 185 q:full mattress padded liner -- pred:{'Furniture', 'Home Improvement', 'Bed & Bath'} == expected:Bed & Bath
# 187 q:farmhouse bread box -- pred:{'Décor & Pillows', 'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# ***
# sugar canister -- pred:{'Kitchen & Tabletop'} != expected:
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars']
# 188 recall (N=121) -- 0.8512396694214877
# 189 q:kids chair -- pred:{'Furniture', 'Baby & Kids'} == expected:Baby & Kids
# 190 q:golub dining table -- pred:{'Furniture'} == expected:Furniture
# 193 q:animal print handmade tufted wool beige/black area rug by allmodern -- pred:{'Décor & Pillows', 'Rugs'} == expected:Rugs
# 196 q:breakfast bar table -- pred:{'Furniture'} == expected:Furniture
# ***
# nettie 5 pc bar set -- pred:{'Furniture'} != expected:Outdoor
# ['Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools']
# 197 recall (N=126) -- 0.8492063492063492
# 198 q:outdoor storage -- pred:{'Storage & Organization', 'Outdoor'} == expected:Storage & Organization
# 199 q:small woven pouf -- pred:{'Furniture'} == expected:Furniture
# 201 q:wayfair comforters -- pred:{'Bed & Bath'} == expected:Bed & Bath
# ***
# high weight capacity bunk beds -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds']
# 202 recall (N=130) -- 0.8461538461538461
# 205 q:non slip shower floor tile -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# emma headboard -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 207 recall (N=132) -- 0.8409090909090909
# 208 q:grantola wall mirror -- pred:{'Furniture', 'Décor & Pillows'} == expected:Décor & Pillows
# 209 q:side table with storage -- pred:{'Furniture'} == expected:Furniture
# 210 q:bistro table and chairs -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 211 Skipping dumbbells
# 211 q:tall buffet cabinet -- pred:{'Furniture'} == expected:Furniture
# ***
# ruckus chair -- pred:{'Furniture'} != expected:School Furniture and Supplies
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Office Chairs']
# 213 recall (N=137) -- 0.8394160583941606
# 215 q:artificial orchid arrangement -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 219 q:gnome fairy garden -- pred:{'Décor & Pillows', 'Outdoor'} == expected:Outdoor
# 221 q:laundry basket with wheels -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 222 q:accent chair recliner -- pred:{'Furniture'} == expected:Furniture
# ***
# pennfield playhouse -- pred:{'Baby & Kids', 'Outdoor'} != expected:
# ['Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating', 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs']
# 223 recall (N=142) -- 0.8380281690140845
# 224 q:power lift chair -- pred:{'Furniture'} == expected:Furniture
# 225 q:argenteuil -- pred:{'Furniture', 'Décor & Pillows', 'Rugs'} == expected:Décor & Pillows
# 227 q:bar room wall decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# ***
# outdoor seat/back cushion -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals']
# 229 recall (N=146) -- 0.8356164383561644
# 230 q:board game storage cabinet -- pred:{'Furniture'} == expected:Furniture
# 231 q:alyse 8 light -- pred:{'Lighting'} == expected:Lighting
# 232 q:wire basket with dividers -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 235 q:small space dining table and chairs sets -- pred:{'Furniture'} == expected:Furniture
# 236 q:bedroom wall decor floral, multicolored with some teal (prints) -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 237 q:hussain handmade tufted magenta rug -- pred:{'Rugs'} == expected:Rugs
# 238 q:decorative wall clocks -- pred:{'Furniture', 'Décor & Pillows'} == expected:Décor & Pillows
# 240 q:ombre rug -- pred:{'Rugs'} == expected:Rugs
# 241 q:tufted chair with gold legs -- pred:{'Furniture'} == expected:Furniture
# 244 q:bathroom lighting -- pred:{'Lighting'} == expected:Lighting
# 246 q:music plug wall plate -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Home Improvement
# 247 q:wooden chair outdoor -- pred:{'Furniture', 'Outdoor'} == expected:Outdoor
# 248 q:gas detector -- pred:{'Home Improvement'} == expected:Home Improvement
# ***
# full metal bed rose gold -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 249 recall (N=160) -- 0.84375
# ***
# kohler whitehaven farmhouse kitchen sink -- pred:{'Kitchen & Tabletop'} != expected:Home Improvement
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Kitchen & Tabletop / Kitchen Utensils & Tools / Kitchen Gadgets / Pasta Makers & Accessories', 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters']
# 250 recall (N=161) -- 0.8385093167701864
# 251 q:love seat wide faux leather tuxedo arm sofa -- pred:{'Furniture'} == expected:Furniture
# 252 Skipping drudge report
# 252 q:entrance table -- pred:{'Furniture'} == expected:Furniture
# ***
# delta trinsic -- pred:{'Furniture', 'Décor & Pillows'} != expected:Home Improvement
# ['Furniture / Office Furniture / Desks', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Wall Décor / Wall Accents']
# 253 recall (N=164) -- 0.8353658536585366
# 254 q:kraus kitchen sink faucet oletto kpf 2820 sfs -- pred:{'Home Improvement'} == expected:Home Improvement
# 257 q:orren ellis l shaped desk -- pred:{'Furniture'} == expected:Furniture
# 265 q:gowdy height adjustable standing desk -- pred:{'Furniture'} == expected:Furniture
# 266 q:46 inch closet door -- pred:{'Home Improvement'} == expected:Home Improvement
# 267 q:iittala bowl -- pred:{'Décor & Pillows', 'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 268 q:gaia driftwood table -- pred:{'Furniture', 'Outdoor'} == expected:Furniture
# 270 q:ceramic tile sea shell -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Home Improvement
# ***
# bedroom accessories -- pred:{'Furniture', 'Bed & Bath'} != expected:Décor & Pillows
# ['Furniture / Bedroom Furniture / Bedroom and Makeup Vanities', 'Bed & Bath / Bedding / All Bedding', 'Bed & Bath / Bedding / Sheets & Pillowcases', 'Bed & Bath / Bedding / All Bedding / Twin Bedding', 'Bed & Bath / Bedding / All Bedding / Queen Bedding']
# 273 recall (N=172) -- 0.8372093023255814
# 274 q:beds that have leds -- pred:{'Furniture'} == expected:Furniture
# 275 q:bathroom single faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 276 q:home sweet home sign -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 277 q:velvet chaise -- pred:{'Furniture'} == expected:Furniture
# 278 q:rug plum -- pred:{'Rugs'} == expected:Rugs
# 280 q:end table between recliners -- pred:{'Furniture'} == expected:Furniture
# 281 q:wall design shelf -- pred:{'Décor & Pillows', 'Storage & Organization'} == expected:Storage & Organization
# 282 q:big basket for dirty cloths -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 284 q:large spoon and fork wall decor -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Décor & Pillows
# 285 q:trundle daybed -- pred:{'Furniture'} == expected:Furniture
# 286 q:turquoise chair -- pred:{'Furniture'} == expected:Furniture
# 287 q:wishbone chair -- pred:{'Furniture'} == expected:Furniture
# ***
# burnt orange curtains -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:Rugs
# ['Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs', 'Décor & Pillows / Window Treatments / Curtains & Drapes']
# 288 recall (N=185) -- 0.8432432432432433
# 289 q:sunjoy lantern -- pred:{'Décor & Pillows', 'Outdoor', 'Lighting'} == expected:Lighting
# 290 Skipping propane gas dryer
# 290 q:coffee bar buffet -- pred:{'Furniture'} == expected:Furniture
# 291 q:retractable side awning -- pred:{'Outdoor'} == expected:Outdoor
# 292 q:storage dresser -- pred:{'Furniture'} == expected:Furniture
# 295 q:seat cushions desk -- pred:{'Furniture'} == expected:Furniture
# ***
# wisdom stone river 3-3/4 -- pred:{'Furniture', 'Décor & Pillows'} != expected:Home Improvement
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Bedroom Furniture / Nightstands', 'Décor & Pillows / Wall Décor / Wall Accents']
# 296 recall (N=191) -- 0.8429319371727748
# ***
# grill cover 73 -- pred:{'Outdoor'} != expected:Storage & Organization
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables']
# 299 recall (N=192) -- 0.8385416666666666
# 302 q:malachi sled -- pred:{'Furniture', 'Baby & Kids', 'Outdoor'} == expected:Furniture
# 305 q:penny round tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 306 q:dining room tables -- pred:{'Furniture'} == expected:Furniture
# 307 q:bathroom vanity knobs -- pred:{'Home Improvement'} == expected:Home Improvement
# 308 q:modern outdoor furniture -- pred:{'Outdoor'} == expected:Outdoor
# 309 q:rustic storage cabinet -- pred:{'Furniture'} == expected:Furniture
# 312 q:bathroom freestanding cabinet -- pred:{'Storage & Organization', 'Home Improvement'} == expected:Storage & Organization
# 314 q:shoe closet -- pred:{'Furniture', 'Storage & Organization'} == expected:Storage & Organization
# 315 q:arwen table lamp -- pred:{'Décor & Pillows', 'Lighting'} == expected:Lighting
# 316 q:black freestanding tub  with faucet -- pred:{'Bed & Bath', 'Home Improvement'} == expected:Home Improvement
# 317 q:desk for kids -- pred:{'Furniture', 'Baby & Kids'} == expected:Baby & Kids
# 321 q:closet pull out valet rod -- pred:{'Storage & Organization', 'Home Improvement'} == expected:Storage & Organization
# 322 q:antique brass faucet -- pred:{'Home Improvement'} == expected:Home Improvement
# 323 q:modern farmhouse lighting semi flush mount -- pred:{'Lighting'} == expected:Lighting
# ***
# dorel vanity -- pred:{'Furniture'} != expected:Home Improvement
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities']
# 324 recall (N=207) -- 0.8454106280193237
# 326 q:capricorn chest -- pred:{'Furniture'} == expected:Furniture
# 327 q:canvas map art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 330 q:orren ellis l shape desk -- pred:{'Furniture'} == expected:Furniture
# 331 q:solid teak end table -- pred:{'Furniture'} == expected:Furniture
# 332 q:living room coffee table sets -- pred:{'Furniture'} == expected:Furniture
# 333 q:papasan chair frame only -- pred:{'Furniture'} == expected:Furniture
# 334 q:elegant executive chair -- pred:{'Furniture'} == expected:Furniture
# 336 q:rooster decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 337 q:teal chair -- pred:{'Furniture'} == expected:Furniture
# 341 q:zodiac pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 343 q:anchor decor -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 345 q:fleur de lis living candle wall sconce bronze -- pred:{'Décor & Pillows', 'Lighting'} == expected:Décor & Pillows
# 347 q:sheffield home bath set -- pred:{'Bed & Bath', 'Home Improvement'} == expected:Home Improvement
# 349 q:card table -- pred:{'Furniture', 'Outdoor'} == expected:Furniture
# 350 q:chrome bathroom 4 light vanity light -- pred:{'Lighting', 'Home Improvement'} == expected:Lighting
# 351 q:kelly clarkson light fixtures -- pred:{'Lighting'} == expected:Lighting
# 353 q:decorative white pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 354 q:pasta tools -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 355 q:beach blue headboard -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# 356 q:wood coffee table set by storage -- pred:{'Furniture'} == expected:Furniture
# 358 q:champagne velvet desk chair -- pred:{'Furniture'} == expected:Furniture
# 362 q:outdoor light fixtures -- pred:{'Outdoor', 'Lighting'} == expected:Lighting
# 364 q:outdoor privacy wall -- pred:{'Outdoor'} == expected:Outdoor
# 365 q:berenice 4 storage cabinet -- pred:{'Furniture', 'Storage & Organization'} == expected:Furniture
# 366 q:chrome shower head and valve -- pred:{'Home Improvement'} == expected:Home Improvement
# 367 q:ge top loading washer 4.5 -- pred:{'Appliances', 'Home Improvement'} == expected:Appliances
# 368 q:butcher block island -- pred:{'Furniture'} == expected:Furniture
# ***
# serta kleinmon -- pred:{'Furniture'} != expected:Bed & Bath
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Sofas', 'Furniture / Office Furniture / Desks', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 369 recall (N=235) -- 0.8595744680851064
# 371 q:body pillow and case -- pred:{'Décor & Pillows', 'Bed & Bath'} == expected:Bed & Bath
# 372 q:wayfair tension rod -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Décor & Pillows
# ***
# above toilet cabinet -- pred:{'Bed & Bath', 'Home Improvement'} != expected:Storage & Organization
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Bed & Bath / Bathroom Accessories & Organization / Countertop Bath Accessories']
# 373 recall (N=238) -- 0.8571428571428571
# 374 q:30 inch bathroom vanity -- pred:{'Furniture', 'Home Improvement'} == expected:Home Improvement
# 375 q:rustic twig -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} == expected:Décor & Pillows
# 378 q:led nightstand -- pred:{'Furniture'} == expected:Furniture
# 379 q:hub leaning full length mirror -- pred:{'Furniture', 'Décor & Pillows'} == expected:Décor & Pillows
# 380 q:kitchen islands with seating -- pred:{'Furniture'} == expected:Furniture
# ***
# rock climbing wall kids -- pred:{'School Furniture and Supplies', 'Outdoor'} != expected:Holiday Décor
# ['Outdoor / Garden / Garden Décor / Lawn & Garden Accents', 'School Furniture and Supplies / School Spaces / Computer Lab Furniture / Podiums & Lecterns']
# 382 recall (N=244) -- 0.8565573770491803
# 383 q:parsons chairs -- pred:{'Furniture'} == expected:Furniture
# 384 q:picasso -- pred:{'Furniture', 'Décor & Pillows'} == expected:Décor & Pillows
# 385 q:upholstered bed -- pred:{'Furniture'} == expected:Furniture
# 386 q:70s inspired furniture -- pred:{'Furniture'} == expected:Furniture
# 387 q:small wardrobe grey -- pred:{'Furniture'} == expected:Furniture
# ***
# lunch bag -- pred:{'Kitchen & Tabletop', 'Storage & Organization'} != expected:Outdoor
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks']
# 388 recall (N=250) -- 0.856
# 390 q:48" sliding single track , barn door for laundry -- pred:{'Home Improvement'} == expected:Home Improvement
# 391 q:jennie tufted upholstered low profile platform bed -- pred:{'Furniture'} == expected:Furniture
# 392 q:sancroft armchair -- pred:{'Furniture'} == expected:Furniture
# 393 q:toddler couch fold out -- pred:{'Furniture', 'Baby & Kids'} == expected:Baby & Kids
# 394 q:novara pergola -- pred:{'Outdoor'} == expected:Outdoor
# 396 q:stainless steel colander set -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 398 q:beaded curtains -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Décor & Pillows
# 399 q:milk cow chair -- pred:{'Furniture'} == expected:Furniture
# 403 q:white abstract -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 404 q:island estate coffee table -- pred:{'Furniture'} == expected:Furniture
# ***
# mobley zero gravity adjustable bed with wireless remote -- pred:{'Furniture'} != expected:Bed & Bath
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 405 recall (N=261) -- 0.8582375478927203
# 406 q:leather chair -- pred:{'Furniture'} == expected:Furniture
# 407 q:feather wall art -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 408 q:kohler purist brushed bronze -- pred:{'Home Improvement'} == expected:Home Improvement
# 409 q:mattress foam topper queen -- pred:{'Home Improvement', 'Bed & Bath'} == expected:Bed & Bath
# 410 q:unique coffee tables -- pred:{'Furniture'} == expected:Furniture
# 412 q:stainless steel free standing shower caddy -- pred:{'Home Improvement'} == expected:Home Improvement
# 414 q:desk for kids tjat ate 10 year old -- pred:{'Furniture', 'Baby & Kids'} == expected:Baby & Kids
# 415 q:cortez pillow -- pred:{'Décor & Pillows'} == expected:Décor & Pillows
# 416 q:wood bar stools -- pred:{'Furniture'} == expected:Furniture
# 419 q:body pillow case -- pred:{'Décor & Pillows', 'Bed & Bath'} == expected:Bed & Bath
# 420 q:boho bed frame -- pred:{'Furniture'} == expected:Furniture
# 421 q:mystic swivel -- pred:{'Furniture'} == expected:Furniture
# 422 q:geralyn upholstered storage platform bed -- pred:{'Furniture'} == expected:Furniture
# ***
# door jewelry organizer -- pred:{'Décor & Pillows', 'Storage & Organization', 'Home Improvement'} != expected:Furniture
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves', 'Décor & Pillows / Wall Décor / Wall Accents']
# 423 recall (N=275) -- 0.8618181818181818
# 424 q:basket planter -- pred:{'Décor & Pillows', 'Outdoor'} == expected:Outdoor
# 426 q:edge chair mat -- pred:{'Furniture', 'Décor & Pillows', 'Storage & Organization'} == expected:Furniture
# 428 q:low profile loveseat recliner -- pred:{'Furniture'} == expected:Furniture
# 429 q:entertainment console -- pred:{'Furniture'} == expected:Furniture
# ***
# anti fatigue mat -- pred:{'Storage & Organization', 'Home Improvement'} != expected:Rugs
# ['Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Patio Furniture Covers']
# 430 recall (N=280) -- 0.8607142857142858
# ***
# cover set for outdoor furniture -- pred:{'Outdoor'} != expected:Storage & Organization
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 431 recall (N=281) -- 0.8576512455516014
# 433 q:dolomite subway tile -- pred:{'Home Improvement'} == expected:Home Improvement
# 434 q:almost heaven sauna -- pred:{'Outdoor', 'Home Improvement'} == expected:Outdoor
# 436 q:circle cabinet pulls -- pred:{'Home Improvement'} == expected:Home Improvement
# 438 q:glass doors for bath -- pred:{'Home Improvement'} == expected:Home Improvement
# 440 q:comfortable accent chair -- pred:{'Furniture'} == expected:Furniture
# 441 q:adjustable height artist stool -- pred:{'Furniture'} == expected:Furniture
# 442 q:garage sports storage rack -- pred:{'Storage & Organization'} == expected:Storage & Organization
# 443 q:brunk ship wheel -- pred:{'Décor & Pillows', 'Outdoor'} == expected:Décor & Pillows
# 444 q:brendon counter stool -- pred:{'Furniture'} == expected:Furniture
# 445 q:bathroom vanity with counter space -- pred:{'Furniture', 'Home Improvement'} == expected:Home Improvement
# 446 q:entertainment stand end table -- pred:{'Furniture'} == expected:Furniture
# 450 q:whimsical solar lights -- pred:{'Décor & Pillows', 'Outdoor', 'Lighting'} == expected:Lighting
# 452 q:enclosed shoe rack -- pred:{'Furniture', 'Storage & Organization'} == expected:Storage & Organization
# 453 q:leather chairs -- pred:{'Furniture'} == expected:Furniture
# 455 q:bar stool with backrest -- pred:{'Furniture'} == expected:Furniture
# 456 q:hulmeville writing desk with hutch -- pred:{'Furniture'} == expected:Furniture
# 457 q:blaylock bookcase headboard -- pred:{'Furniture'} == expected:Furniture
# 460 q:tall free standing pet gate -- pred:{'Pet'} == expected:Pet
# 463 q:e12/candelabra -- pred:{'Décor & Pillows', 'Lighting'} == expected:Lighting
# ***
# jordanna solid wood rocking -- pred:{'Furniture'} != expected:Outdoor
# ['Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 464 recall (N=301) -- 0.8637873754152824
# 465 q:7qt slow cooker -- pred:{'Kitchen & Tabletop'} == expected:Kitchen & Tabletop
# 466 q:odum velvet -- pred:{'Furniture', 'Décor & Pillows'} == expected:Furniture
# ***
# verden callan -- pred:{'Furniture', 'Outdoor'} != expected:Bed & Bath
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 468 recall (N=304) -- 0.8618421052631579
# 469 q:french molding -- pred:{'Décor & Pillows', 'Home Improvement'} == expected:Home Improvement
# ***
# fold in half table -- pred:{'Furniture'} != expected:School Furniture and Supplies
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables', 'Furniture / Office Furniture / Desks / Writing Desks', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 470 recall (N=306) -- 0.8594771241830066
# 471 q:podium with locking cabinet -- pred:{'Furniture', 'Storage & Organization', 'School Furniture and Supplies'} == expected:School Furniture and Supplies
# 0.8599348534201955

# %%
def recall_all(categorized):
    """When we retrieve a category, is it correct?"""
    hits = []
    misses = []
    idx = 0
    for _, row in ground_truth_cat.sample(frac=1).iterrows():
        query = row['query']
        expected_category = row['category']

        cat = categorized(query)
        if len(cat.classifications) == 0:
            print(f"{idx} Skipping {query}")
            continue
        # ***
        # Now also consider this a miss, we should not have predicted any caterogies
        if expected_category == "No Category Fits" and len(cat.categories) > 0:
            print("!**")
            print(f"{query} -- pred:{cat.categories} != expected:{expected_category.strip()}")
            print(cat.classifications)
            misses.append((expected_category, cat))
            num_so_far = len(hits) + len(misses)
            print(f"{idx} recall (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
        elif expected_category.strip() in cat.categories:
            # print(f"{idx} q:{query} -- pred:{cat.categories} == expected:{expected_category.strip()}")
            hits.append((expected_category, cat))
        else:
            print("***")
            print(f"{query} -- pred:{cat.categories} != expected:{expected_category.strip()}")
            print(cat.classifications)
            misses.append((expected_category, cat))
            num_so_far = len(hits) + len(misses)
            print(f"{idx} recall (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
        idx += 1

    return len(hits) / (len(hits) + len(misses)), hits, misses

recall, hits, misses = recall_all(fully_classified)
recall
# Out:
# !**
# hitchcock mid-century wall shelf -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Furniture / Living Room Furniture / Bookcases', 'Furniture / Bedroom Furniture / Nightstands']
# 1 recall (N=2) -- 0.5
# !**
# surge protector -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Hardware / Home Hardware / Switch Plates', 'Home Improvement / Building Equipment / Dollies / Hand Truck Dollies']
# 3 recall (N=4) -- 0.5
# !**
# auburn throw pillows -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Art / All Wall Art']
# 7 recall (N=8) -- 0.625
# 8 Skipping kisner
# 8 Skipping rattan truck
# !**
# alter furniture -- pred:{'Furniture', 'Outdoor'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Desks', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Sectionals', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Furniture / Bedroom Furniture / Nightstands']
# 8 recall (N=9) -- 0.5555555555555556
# !**
# wand bunk beds -- pred:{'Furniture', 'Baby & Kids'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds']
# 10 recall (N=11) -- 0.5454545454545454
# !**
# cushion replacement insert -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs / Wingback Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 11 recall (N=12) -- 0.5
# !**
# moen 5995 arbor one -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets', 'Home Improvement / Plumbing / Core Plumbing / Parts & Components']
# 18 recall (N=19) -- 0.631578947368421
# !**
# kitchen wooden stand -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Kitchen Islands & Carts', 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets / Drawer Equipped Sideboards & Buffets', 'Furniture / Kitchen & Dining Furniture / Kitchen Islands & Carts']
# 26 recall (N=27) -- 0.7037037037037037
# !**
# rack glass -- pred:{'Furniture', 'Décor & Pillows', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Storage Containers & Drawers / Storage Drawers', 'Décor & Pillows / Wall Décor / Wall Accents', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables']
# 27 recall (N=28) -- 0.6785714285714286
# !**
# brockham solid blackout thermal grommet curtain panels -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:No Category Fits
# ['Décor & Pillows / Window Treatments / Curtains & Drapes', 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Levers']
# 28 recall (N=29) -- 0.6551724137931034
# !**
# nespresso vertuo next premium by breville with aeroccino -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Small Kitchen Appliances / Coffee, Espresso, & Tea / Coffee Makers', 'Kitchen & Tabletop / Small Kitchen Appliances / Coffee, Espresso, & Tea / Coffee Makers']
# 29 recall (N=30) -- 0.6333333333333333
# !**
# shoe bench entryway -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Storage & Organization / Shoe Storage / All Shoe Storage / Rack Shoe Storage', 'Furniture / Bedroom Furniture / Nightstands', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 30 recall (N=31) -- 0.6129032258064516
# ***
# medium clips -- pred:{'Furniture', 'Décor & Pillows', 'Lighting'} != expected:Clips
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Lighting / Wall Lights / Wall Sconces', 'Furniture / Office Furniture / Office Chairs']
# 31 recall (N=32) -- 0.59375
# !**
# indoor water fountain -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Indoor Fountains', 'Home Improvement / Building Equipment / Dollies / Hand Truck Dollies']
# 34 recall (N=35) -- 0.6
# !**
# antique silver entry table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Sideboards & Buffets / Drawer Equipped Sideboards & Buffets', 'Furniture / Living Room Furniture / Console Tables', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 35 recall (N=36) -- 0.5833333333333334
# !**
# china clock -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:No Category Fits
# ['Décor & Pillows / Clocks / Wall Clocks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Brass Cabinet & Drawer Knobs']
# 45 recall (N=46) -- 0.6521739130434783
# !**
# urban outfitters duvet -- pred:{'Furniture', 'Décor & Pillows', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 48 recall (N=49) -- 0.6530612244897959
# !**
# porcelain loaf pan -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Cookware & Bakeware / Baking Sheets & Pans / Bread & Loaf Pans / Steel Bread & Loaf Pans', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers']
# 51 recall (N=52) -- 0.6538461538461539
# !**
# bubble guppies chair -- pred:{'Baby & Kids'} != expected:No Category Fits
# ['Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds', 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Desks', 'Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating']
# 54 recall (N=55) -- 0.6545454545454545
# !**
# carolyn console table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Console Tables', 'Furniture / Office Furniture / Desks', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 57 recall (N=58) -- 0.6551724137931034
# !**
# tressler rug -- pred:{'Rugs'} != expected:No Category Fits
# ['Rugs / Area Rugs', 'Rugs / Doormats', 'Rugs / Kitchen Mats']
# 58 recall (N=59) -- 0.6440677966101694
# !**
# ottoman bed queen -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 60 recall (N=61) -- 0.639344262295082
# !**
# merlyn 6 -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 61 recall (N=62) -- 0.6290322580645161
# ***
# bedroom accessories -- pred:{'Furniture', 'Bed & Bath'} != expected:Décor & Pillows
# ['Furniture / Bedroom Furniture / Bedroom and Makeup Vanities', 'Bed & Bath / Bedding / All Bedding', 'Bed & Bath / Bedding / Sheets & Pillowcases', 'Bed & Bath / Bedding / All Bedding / Twin Bedding', 'Bed & Bath / Bedding / All Bedding / Queen Bedding']
# 62 recall (N=63) -- 0.6190476190476191
# !**
# semi flush foyer light -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / Chandeliers', 'Lighting / Ceiling Lights / Pendant Lighting', 'Lighting / Wall Lights / Wall Sconces']
# 63 recall (N=64) -- 0.609375
# !**
# fawkes 36" blue vanity -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 64 recall (N=65) -- 0.6
# !**
# maryford queen tufted bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 65 recall (N=66) -- 0.5909090909090909
# !**
# sinks bed frame -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 67 recall (N=68) -- 0.5882352941176471
# !**
# bed risers -- pred:{'Furniture', 'Storage & Organization', 'Home Improvement'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Bed Frames / Twin Bed Frames', 'Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs']
# 70 recall (N=71) -- 0.5915492957746479
# !**
# bohemian -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Décor & Pillows / Art / All Wall Art']
# 71 recall (N=72) -- 0.5833333333333334
# !**
# lowes tile -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Ceramic Floor Tiles & Wall Tiles', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Glass Floor Tiles & Wall Tiles']
# 72 recall (N=73) -- 0.5753424657534246
# !**
# oliver parsons -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Décor & Pillows / Art / All Wall Art']
# 75 recall (N=76) -- 0.5789473684210527
# !**
# 5 gang light switch -- pred:{'Lighting', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls', 'Lighting / Wall Lights / Wall Sconces', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets']
# 76 recall (N=77) -- 0.5714285714285714
# !**
# croscill ashton -- pred:{'Décor & Pillows', 'Bed & Bath'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Bed & Bath / Bedding / All Bedding']
# 77 recall (N=78) -- 0.5641025641025641
# ***
# emma headboard -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Headboards', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 80 recall (N=81) -- 0.5679012345679012
# !**
# mom urn -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Flowers & Plants / Wreaths']
# 83 recall (N=84) -- 0.5714285714285714
# 84 Skipping propane gas dryer
# !**
# filaret outdoor sofa -- pred:{'Furniture', 'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Furniture / Living Room Furniture / Sofas', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs']
# 84 recall (N=85) -- 0.5647058823529412
# ***
# lunch bag -- pred:{'Kitchen & Tabletop', 'Storage & Organization'} != expected:Outdoor
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks']
# 87 recall (N=88) -- 0.5681818181818182
# !**
# day bed indian -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Daybeds']
# 88 recall (N=89) -- 0.5617977528089888
# !**
# nesting tray set -- pred:{'Décor & Pillows', 'Kitchen & Tabletop', 'Storage & Organization'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets']
# 89 recall (N=90) -- 0.5555555555555556
# !**
# brushed gold wall decor -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Décor & Pillows / Art / All Wall Art']
# 92 recall (N=93) -- 0.5591397849462365
# !**
# mission double vanity -- pred:{'Furniture', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 98 recall (N=99) -- 0.5757575757575758
# ***
# cover set for outdoor furniture -- pred:{'Outdoor'} != expected:Storage & Organization
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 99 recall (N=100) -- 0.57
# !**
# pedistole sink -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Single Hole Bathroom Sink Faucets']
# 102 recall (N=103) -- 0.5728155339805825
# ***
# coat rack for bedroom -- pred:{'Furniture', 'Storage & Organization'} != expected:Contractor
# ['Storage & Organization / Closet Storage & Organization / Clothes Racks & Garment Racks', 'Furniture / Bedroom Furniture / Nightstands', 'Furniture / Bedroom Furniture / Armoires & Wardrobes']
# 107 recall (N=108) -- 0.5833333333333334
# !**
# door pulls bronze matte 4 inch -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Bronze Cabinet & Drawer Pulls', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 110 recall (N=111) -- 0.5855855855855856
# !**
# nectar queen mattress -- pred:{'Furniture', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Queen Size Beds']
# 112 recall (N=113) -- 0.584070796460177
# !**
# johan desk by laurel foundry -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 113 recall (N=114) -- 0.5789473684210527
# !**
# blue faux throw with pillows -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 118 recall (N=119) -- 0.5882352941176471
# ***
# twin over full bunk beds cool desins -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Full & Double Beds']
# 124 recall (N=125) -- 0.6
# !**
# gray leather cocktail table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 129 recall (N=130) -- 0.6076923076923076
# !**
# cake plates with tops -- pred:{'Décor & Pillows', 'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 131 recall (N=132) -- 0.6060606060606061
# !**
# gray dresser -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 133 recall (N=134) -- 0.6044776119402985
# !**
# flamingo -- pred:{'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Art / All Wall Art', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 134 recall (N=135) -- 0.6
# !**
# owl -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 135 recall (N=136) -- 0.5955882352941176
# !**
# biycicle plant stands -- pred:{'Furniture', 'Outdoor'} != expected:No Category Fits
# ['Outdoor / Garden / Plant Stands & Accessories', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables']
# 136 recall (N=137) -- 0.5912408759124088
# !**
# patio design -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 137 recall (N=138) -- 0.5869565217391305
# ***
# shower hooks -- pred:{'Home Improvement'} != expected:Bed & Bath
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks']
# 144 recall (N=145) -- 0.6
# !**
# nautical platters -- pred:{'Décor & Pillows', 'Kitchen & Tabletop'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters']
# 145 recall (N=146) -- 0.5958904109589042
# !**
# cream queen duvet cover -- pred:{'Décor & Pillows', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding / Queen Bedding', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 147 recall (N=148) -- 0.5945945945945946
# !**
# farmhouse hood vent -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Faucets / Black Kitchen Faucets']
# 148 recall (N=149) -- 0.5906040268456376
# ***
# outdoor seat/back cushion -- pred:{'Outdoor'} != expected:
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals']
# 154 recall (N=155) -- 0.6
# !**
# moen matte black hooks -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 156 recall (N=157) -- 0.5987261146496815
# !**
# twin bed frame -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 157 recall (N=158) -- 0.5949367088607594
# !**
# sliding closet mirror -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Décor & Pillows / Mirrors / All Mirrors']
# 160 recall (N=161) -- 0.5962732919254659
# !**
# black hanging bookshelf -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Bookcases', 'Furniture / Office Furniture / Office Storage Cabinets', 'Décor & Pillows / Wall Décor / Wall Accents']
# 161 recall (N=162) -- 0.5925925925925926
# !**
# round outdoor patio cover -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor Shades / Pergolas / Metal Pergolas', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 166 recall (N=167) -- 0.5988023952095808
# ***
# dining table vinyl cloth -- pred:{'Furniture'} != expected:Kitchen & Tabletop
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables']
# 168 recall (N=169) -- 0.5976331360946746
# !**
# large bases -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Office Furniture / Desks', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 170 recall (N=171) -- 0.5964912280701754
# !**
# aiden black velvet bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 172 recall (N=173) -- 0.5953757225433526
# ***
# jordanna solid wood rocking -- pred:{'Furniture'} != expected:Outdoor
# ['Furniture / Living Room Furniture / Chairs & Seating / Rocking Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 175 recall (N=176) -- 0.5965909090909091
# !**
# amarillo -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Décor & Pillows / Wall Décor / Wall Accents']
# 176 recall (N=177) -- 0.5932203389830508
# !**
# tall storage cabinet -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Sideboards & Buffets / Drawer Equipped Sideboards & Buffets', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Storage & Organization / Closet Storage & Organization / Closet Systems', 'Furniture / Office Furniture / Office Storage Cabinets']
# 177 recall (N=178) -- 0.5898876404494382
# !**
# small ladies rocker swivel recliner -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 178 recall (N=179) -- 0.5865921787709497
# !**
# acrylic clear chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Office Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners']
# 179 recall (N=180) -- 0.5833333333333334
# ***
# zakariyah twin platform -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 189 recall (N=190) -- 0.6
# !**
# industrial -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Office Furniture / Desks', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Décor & Pillows / Wall Décor / Wall Accents']
# 190 recall (N=191) -- 0.5968586387434555
# ***
# deer coat hooks -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:Contractor
# ['Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Nickel Cabinet & Drawer Pulls', 'Décor & Pillows / Wall Décor / Wall Accents / Green Wall Accents']
# 193 recall (N=194) -- 0.5979381443298969
# ***
# full metal bed rose gold -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 194 recall (N=195) -- 0.5948717948717949
# ***
# kitchen anti fatigue mats -- pred:{'Kitchen & Tabletop', 'Home Improvement'} != expected:Rugs
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles']
# 196 recall (N=197) -- 0.5939086294416244
# !**
# bathroom wastebasket -- pred:{'Storage & Organization', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bathroom Accessories & Organization / Countertop Bath Accessories', 'Storage & Organization / Bathroom Storage & Organization / Hampers & Laundry Baskets']
# 197 recall (N=198) -- 0.5909090909090909
# ***
# burnt orange curtains -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:Rugs
# ['Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Knobs / Black Cabinet & Drawer Knobs', 'Décor & Pillows / Window Treatments / Curtains & Drapes']
# 198 recall (N=199) -- 0.5879396984924623
# ***
# foutains with brick look -- pred:{'Décor & Pillows', 'Outdoor'} != expected:
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Outdoor / Outdoor Décor / Outdoor Fountains']
# 199 recall (N=200) -- 0.585
# !**
# living room ideas -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Sectionals', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners']
# 202 recall (N=203) -- 0.5862068965517241
# !**
# royal blue counter height chairs -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools']
# 203 recall (N=204) -- 0.5833333333333334
# !**
# canadian -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor', 'Home Improvement'} != expected:No Category Fits
# ['Outdoor / Garden / Garden Décor / Lawn & Garden Accents', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Décor & Pillows / Wall Décor / Wall Accents', 'Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles']
# 208 recall (N=209) -- 0.5885167464114832
# !**
# minnestrista -- pred:{'Furniture', 'Outdoor'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 210 recall (N=211) -- 0.5876777251184834
# !**
# wall sconce with usb port -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Wall Lights / Wall Sconces', 'Lighting / Wall Lights / Wall Sconces']
# 213 recall (N=214) -- 0.5887850467289719
# !**
# living room designs -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / TV Stands & Media Storage Furniture / TV Stands & Entertainment Centers', 'Furniture / Living Room Furniture / Sectionals']
# 214 recall (N=215) -- 0.586046511627907
# !**
# writing desk 48" -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Bedroom Furniture / Dressers & Chests']
# 215 recall (N=216) -- 0.5833333333333334
# !**
# pantry grey -- pred:{'Storage & Organization', 'Home Improvement'} != expected:No Category Fits
# ['Storage & Organization / Closet Storage & Organization / Closet Accessories', 'Storage & Organization / Garage & Outdoor Storage & Organization / Storage Racks & Shelving Units', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks']
# 216 recall (N=217) -- 0.5806451612903226
# 217 Skipping wainscoting ideas
# !**
# star wars rug -- pred:{'Décor & Pillows', 'Rugs'} != expected:No Category Fits
# ['Rugs / Area Rugs', 'Décor & Pillows / Art / All Wall Art']
# 220 recall (N=221) -- 0.583710407239819
# !**
# light wood nightstand with silver accents -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Nightstands', 'Furniture / Living Room Furniture / Cabinets & Chests', 'Décor & Pillows / Mirrors / All Mirrors']
# 221 recall (N=222) -- 0.581081081081081
# !**
# dual monitor stand -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves']
# 222 recall (N=223) -- 0.57847533632287
# !**
# arched christmas tree -- pred:{'Holiday Décor', 'Décor & Pillows'} != expected:No Category Fits
# ['Holiday Décor / Christmas / Christmas Trees / All Christmas Trees', 'Décor & Pillows / Wall Décor / Wall Accents']
# 223 recall (N=224) -- 0.5758928571428571
# !**
# desk and chair set -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Furniture / Office Furniture / Office Storage Cabinets', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 224 recall (N=225) -- 0.5733333333333334
# ***
# rock climbing wall kids -- pred:{'School Furniture and Supplies', 'Outdoor'} != expected:Holiday Décor
# ['Outdoor / Garden / Garden Décor / Lawn & Garden Accents', 'School Furniture and Supplies / School Spaces / Computer Lab Furniture / Podiums & Lecterns']
# 226 recall (N=227) -- 0.5726872246696035
# !**
# vlad modular sectional -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sectionals', 'Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners']
# 228 recall (N=229) -- 0.5720524017467249
# !**
# kitchen storage cabinet -- pred:{'Furniture', 'Storage & Organization'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Sideboards & Buffets / Drawer Equipped Sideboards & Buffets', 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves']
# 229 recall (N=230) -- 0.5695652173913044
# !**
# outdoor sectional doning -- pred:{'Furniture', 'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets', 'Furniture / Living Room Furniture / Sectionals / Stationary Sectionals']
# 232 recall (N=233) -- 0.5708154506437768
# !**
# town & country living curtains -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:No Category Fits
# ['Décor & Pillows / Window Treatments / Curtains & Drapes', 'Home Improvement / Doors & Door Hardware / Interior Doors / Sliding Interior Doors']
# 233 recall (N=234) -- 0.5683760683760684
# ***
# anti fatigue mat -- pred:{'Storage & Organization', 'Home Improvement'} != expected:Rugs
# ['Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Patio Furniture Covers']
# 235 recall (N=236) -- 0.5677966101694916
# !**
# black fluffy stool -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities']
# 237 recall (N=238) -- 0.5672268907563025
# ***
# fold in half table -- pred:{'Furniture'} != expected:School Furniture and Supplies
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables', 'Furniture / Office Furniture / Desks / Writing Desks', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 239 recall (N=240) -- 0.5666666666666667
# !**
# printers -- pred:{'School Furniture and Supplies', 'Home Improvement'} != expected:No Category Fits
# ['School Furniture and Supplies / School Boards & Technology / AV, Mounts & Tech Accessories / Electronic Mounts & Stands / Computer Mounts', 'Home Improvement / Building Equipment / Dollies / Hand Truck Dollies']
# 240 recall (N=241) -- 0.5643153526970954
# !**
# full bed with trundle -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 241 recall (N=242) -- 0.5619834710743802
# ***
# grill cover 73 -- pred:{'Outdoor'} != expected:Storage & Organization
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables']
# 242 recall (N=243) -- 0.5596707818930041
# ***
# kohler whitehaven farmhouse kitchen sink -- pred:{'Kitchen & Tabletop'} != expected:Home Improvement
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Kitchen & Tabletop / Kitchen Utensils & Tools / Kitchen Gadgets / Pasta Makers & Accessories', 'Kitchen & Tabletop / Tableware & Drinkware / Serveware / Serving Trays & Boards / Serving Trays & Platters / Serving Serving Trays & Platters']
# 243 recall (N=244) -- 0.5573770491803278
# ***
# door jewelry organizer -- pred:{'Décor & Pillows', 'Storage & Organization', 'Home Improvement'} != expected:Furniture
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Storage & Organization / Wall Shelving & Organization / Wall & Display Shelves', 'Décor & Pillows / Wall Décor / Wall Accents']
# 244 recall (N=245) -- 0.5551020408163265
# !**
# queen ann style living room chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Massage Chairs']
# 250 recall (N=251) -- 0.5617529880478087
# !**
# olive green console table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Console Tables', 'Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 251 recall (N=252) -- 0.5595238095238095
# !**
# sunflower -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Flowers & Plants / Faux Flowers', 'Décor & Pillows / Flowers & Plants / Live Plants', 'Décor & Pillows / Wall Décor / Wall Accents']
# 253 recall (N=254) -- 0.5590551181102362
# !**
# wayfair sleep zippered -- pred:{'Furniture', 'Décor & Pillows', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 255 recall (N=256) -- 0.55859375
# !**
# delta trinsic double towel hook in champagne bronze -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks']
# 257 recall (N=258) -- 0.5581395348837209
# !**
# dinosaur -- pred:{'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 258 recall (N=259) -- 0.555984555984556
# !**
# trinaic towel rod -- pred:{'Home Improvement', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bathroom Accessories & Organization / Countertop Bath Accessories', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Towel Storage / Towel & Robe Hooks / Black Towel & Robe Hooks']
# 259 recall (N=260) -- 0.5538461538461539
# ***
# ruckus chair -- pred:{'Furniture'} != expected:School Furniture and Supplies
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Office Furniture / Office Chairs']
# 262 recall (N=263) -- 0.5551330798479087
# !**
# glinda upholstered bench -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Benches', 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities']
# 263 recall (N=264) -- 0.553030303030303
# 265 Skipping dumbbells
# !**
# pull out sleeper loveseat -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Sectionals']
# 265 recall (N=266) -- 0.5526315789473685
# !**
# outdoor movie screen -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Outdoor / Outdoor & Patio Furniture / Outdoor Tables / All Patio Tables']
# 271 recall (N=272) -- 0.5588235294117647
# !**
# blk 18x18 seat cushions -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets']
# 272 recall (N=273) -- 0.5567765567765568
# !**
# king adjustable bed including mattress -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 275 recall (N=276) -- 0.5579710144927537
# !**
# pictures to hang over fireplace -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Wall Décor / Wall Accents']
# 277 recall (N=278) -- 0.5575539568345323
# ***
# coffee table fire pit -- pred:{'Furniture', 'Outdoor'} != expected:
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets']
# 278 recall (N=279) -- 0.5555555555555556
# !**
# super bright lights -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / Chandeliers', 'Lighting / Table & Floor Lamps / Floor Lamps', 'Lighting / Wall Lights / Wall Sconces', 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting']
# 279 recall (N=280) -- 0.5535714285714286
# !**
# coffee container -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars']
# 280 recall (N=281) -- 0.5516014234875445
# !**
# chabely 5 draw chest -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Dressers & Chests / White Dressers & Chests']
# 282 recall (N=283) -- 0.5512367491166078
# !**
# wall art fiji -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Art / All Wall Art / Green Wall Art', 'Décor & Pillows / Art / All Wall Art / Blue Wall Art', 'Décor & Pillows / Art / All Wall Art / Red Wall Art', 'Décor & Pillows / Wall Décor / Wall Accents / Green Wall Accents']
# 285 recall (N=286) -- 0.5524475524475524
# ***
# high weight capacity bunk beds -- pred:{'Furniture'} != expected:Baby & Kids
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds']
# 286 recall (N=287) -- 0.5505226480836237
# !**
# 12v dirt bike -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor Recreation / Backyard Play / Kids Cars & Ride-On Toys']
# 288 recall (N=289) -- 0.5501730103806228
# !**
# black frame 22 x 36 -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Office Furniture / Desks / Writing Desks', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 290 recall (N=291) -- 0.5498281786941581
# !**
# meade mirror -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Mirrors / All Mirrors', 'Furniture / Bedroom Furniture / Nightstands', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 295 recall (N=296) -- 0.5540540540540541
# !**
# platform bed side table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Nightstands', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables']
# 301 recall (N=302) -- 0.5596026490066225
# ***
# mobley zero gravity adjustable bed with wireless remote -- pred:{'Furniture'} != expected:Bed & Bath
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 302 recall (N=303) -- 0.5577557755775577
# !**
# promo codes or discounts -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Hardware / Home Hardware / Switch Plates', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Conversation Sets']
# 304 recall (N=305) -- 0.5573770491803278
# ***
# luau string lights -- pred:{'Décor & Pillows', 'Outdoor', 'Lighting'} != expected:Holiday Décor
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Lighting / Outdoor Lighting / Landscape Lighting / All Landscape Lighting / Fence Post Cap Landscape Lighting']
# 305 recall (N=306) -- 0.5555555555555556
# !**
# parakeet toy -- pred:{'Décor & Pillows', 'Pet'} != expected:No Category Fits
# ['Décor & Pillows / Home Accessories / Decorative Objects', 'Pet / Bird / Bird Perches & Play Gyms']
# 307 recall (N=308) -- 0.5551948051948052
# !**
# belchertown table lamp -- pred:{'Décor & Pillows', 'Lighting'} != expected:No Category Fits
# ['Lighting / Table & Floor Lamps / Table Lamps', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 309 recall (N=310) -- 0.5548387096774193
# !**
# pastel pink desk chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 310 recall (N=311) -- 0.5530546623794212
# !**
# osgood mirror -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Mirrors / All Mirrors', 'Décor & Pillows / Wall Décor / Wall Accents']
# 315 recall (N=316) -- 0.5569620253164557
# !**
# huntsville sectional sofa -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sectionals', 'Furniture / Living Room Furniture / Sofas']
# 318 recall (N=319) -- 0.5579937304075235
# !**
# aloe vera plant pot -- pred:{'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Flowers & Plants / Faux Flowers', 'Outdoor / Garden / Planters']
# 319 recall (N=320) -- 0.55625
# !**
# self enclosed planters -- pred:{'Outdoor'} != expected:No Category Fits
# ['Outdoor / Garden / Planters / Plastic Planters', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 320 recall (N=321) -- 0.5545171339563862
# ***
# wood floor protector mat -- pred:{'Décor & Pillows', 'Storage & Organization', 'Home Improvement'} != expected:Furniture
# ['Home Improvement / Flooring, Walls & Ceiling / Floor Tiles & Wall Tiles / Natural Stone Floor Tiles & Wall Tiles', 'Storage & Organization / Garage & Outdoor Storage & Organization / Outdoor Covers / Patio Furniture Covers', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 322 recall (N=323) -- 0.5541795665634675
# !**
# stoneford end tables white and wood -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / End & Side Tables', 'Furniture / Bedroom Furniture / Nightstands']
# 323 recall (N=324) -- 0.5524691358024691
# !**
# oriental vanity -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Armoires & Wardrobes']
# 330 recall (N=331) -- 0.5589123867069486
# ***
# landis wall mounted bathroom shelves -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:Storage & Organization
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Décor & Pillows / Wall Décor / Wall Accents']
# 332 recall (N=333) -- 0.5585585585585585
# !**
# peacock -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Wall Décor / Wall Accents']
# 335 recall (N=336) -- 0.5595238095238095
# !**
# carpet 5x6 -- pred:{'Rugs'} != expected:No Category Fits
# ["Rugs / Area Rugs / 4' x 6' Area Rugs", "Rugs / Area Rugs / 2' x 3' Area Rugs"]
# 336 recall (N=337) -- 0.5578635014836796
# !**
# mila task chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 337 recall (N=338) -- 0.5562130177514792
# !**
# family lamp -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Table & Floor Lamps / Table Lamps', 'Lighting / Wall Lights / Wall Sconces', 'Lighting / Outdoor Lighting / Outdoor Lanterns & Lamps']
# 339 recall (N=340) -- 0.5558823529411765
# ***
# nettie 5 pc bar set -- pred:{'Furniture'} != expected:Outdoor
# ['Furniture / Kitchen & Dining Furniture / Bar Furniture / Bar Stools & Counter Stools / All Bar Stools & Counter Stools']
# 340 recall (N=341) -- 0.5542521994134897
# !**
# gracie oaks 62 oller 14 ceiling fan -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Fans / All Ceiling Fans']
# 343 recall (N=344) -- 0.5552325581395349
# !**
# zen -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor', 'Lighting'} != expected:No Category Fits
# ...
# 354 recall (N=355) -- 0.5521126760563381
# !**
# camper -- pred:{'Furniture', 'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs']
# 355 recall (N=356) -- 0.550561797752809
# ***
# serta kleinmon -- pred:{'Furniture'} != expected:Bed & Bath
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Sofas', 'Furniture / Office Furniture / Desks', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 356 recall (N=357) -- 0.5490196078431373
# !**
# white bathroom vanity black hardware -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities / Modern & Contemporary Bathroom Vanities', 'Home Improvement / Hardware / Cabinet Hardware / Cabinet & Drawer Pulls / Black Cabinet & Drawer Pulls']
# 357 recall (N=358) -- 0.547486033519553
# ***
# delta trinsic -- pred:{'Furniture', 'Décor & Pillows'} != expected:Home Improvement
# ['Furniture / Office Furniture / Desks', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Wall Décor / Wall Accents']
# 361 recall (N=362) -- 0.5497237569060773
# ***
# outdoor waterproof chest -- pred:{'Outdoor'} != expected:Storage & Organization
# ['Outdoor / Garden / Garden Décor / Lawn & Garden Accents', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 363 recall (N=364) -- 0.5494505494505495
# !**
# togo chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Recliners', 'Furniture / Living Room Furniture / Chairs & Seating / Massage Chairs']
# 365 recall (N=366) -- 0.5491803278688525
# !**
# one alium way -- pred:{'Furniture', 'Outdoor', 'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Doors & Door Hardware / Interior Doors', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds']
# 366 recall (N=367) -- 0.547683923705722
# !**
# wayfair coffee table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 370 recall (N=371) -- 0.5498652291105122
# !**
# counter top one cup hot water dispenser -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Kitchen Utensils & Tools / Kitchen Gadgets / Pasta Makers & Accessories', 'Kitchen & Tabletop / Small Kitchen Appliances / Coffee, Espresso, & Tea / Coffee Makers']
# 371 recall (N=372) -- 0.5483870967741935
# !**
# white splashproof shiplap wallpaper -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Home Improvement / Flooring, Walls & Ceiling / Walls & Ceilings / Wall Paneling']
# 373 recall (N=374) -- 0.5481283422459893
# !**
# mud room sign -- pred:{'Décor & Pillows', 'Home Improvement'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Knobs / Egg Door Knobs']
# 378 recall (N=379) -- 0.5514511873350924
# !**
# 48 inch bathroom vanity with trough sink -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Sinks & Faucet Components / Bathroom Sink Faucets / Widespread Bathroom Sink Faucets']
# 379 recall (N=380) -- 0.55
# !**
# chaves l-shape floating desk with hutch -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Desks', 'Furniture / Office Furniture / Office Storage Cabinets']
# 380 recall (N=381) -- 0.5485564304461942
# !**
# bee -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 381 recall (N=382) -- 0.5471204188481675
# 385 Skipping drudge report
# !**
# 7 draw white dresser -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Living Room Furniture / Cabinets & Chests']
# 386 recall (N=387) -- 0.5503875968992248
# !**
# outdoor clock -- pred:{'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Clocks / Wall Clocks', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs']
# 387 recall (N=388) -- 0.5489690721649485
# ***
# 48 inch kitchen hood -- pred:{'Home Improvement'} != expected:Appliances
# ['Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks', 'Home Improvement / Kitchen Remodel & Kitchen Fixtures / Kitchen Sinks & Faucet Components / Kitchen Sinks / Farmhouse & Apron Kitchen Sinks']
# 390 recall (N=391) -- 0.5498721227621484
# ***
# wisdom stone river 3-3/4 -- pred:{'Furniture', 'Décor & Pillows'} != expected:Home Improvement
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Bedroom Furniture / Nightstands', 'Décor & Pillows / Wall Décor / Wall Accents']
# 391 recall (N=392) -- 0.548469387755102
# !**
# westling coffee table -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Table Sets', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 395 recall (N=396) -- 0.5505050505050505
# 397 Skipping monthly calendar
# !**
# certified international melamine -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs', 'Furniture / Kitchen & Dining Furniture / Sideboards & Buffets', 'Furniture / Kitchen & Dining Furniture / Kitchen Islands & Carts']
# 397 recall (N=398) -- 0.550251256281407
# !**
# candace wingback upholstered bed -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 401 recall (N=402) -- 0.5522388059701493
# !**
# chair pillow cushion -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 404 recall (N=405) -- 0.5530864197530864
# !**
# large cushion outdoor chair -- pred:{'Furniture', 'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Outdoor Chaise & Lounge Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 406 recall (N=407) -- 0.5528255528255528
# !**
# 3/4 size mattress -- pred:{'Furniture', 'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding / Twin Bedding', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds / Twin Beds']
# 409 recall (N=410) -- 0.5536585365853659
# !**
# pineapple -- pred:{'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Art / All Wall Art', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 410 recall (N=411) -- 0.5523114355231143
# ***
# girl reading statue -- pred:{'Décor & Pillows'} != expected:Outdoor
# ['Décor & Pillows / Art / All Wall Art', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows']
# 412 recall (N=413) -- 0.5520581113801453
# !**
# salon chair -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Office Furniture / Office Chairs', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs']
# 415 recall (N=416) -- 0.5528846153846154
# !**
# gold -- pred:{'Furniture', 'Décor & Pillows', 'Lighting'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Décor & Pillows / Art / All Wall Art', 'Furniture / Bedroom Furniture / Dressers & Chests', 'Lighting / Ceiling Lights / Chandeliers']
# 416 recall (N=417) -- 0.5515587529976019
# ***
# verden callan -- pred:{'Furniture', 'Outdoor'} != expected:Bed & Bath
# ['Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Outdoor / Outdoor & Patio Furniture / Patio Furniture Sets / Patio Dining Sets']
# 421 recall (N=422) -- 0.5545023696682464
# !**
# dull bed with shirt head board -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 422 recall (N=423) -- 0.5531914893617021
# !**
# elephant framed -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Décor & Pillows / Art / All Wall Art']
# 423 recall (N=424) -- 0.5518867924528302
# !**
# navy and peach bedding -- pred:{'Bed & Bath'} != expected:No Category Fits
# ['Bed & Bath / Bedding / All Bedding', 'Bed & Bath / Bedding / Sheets & Pillowcases']
# 424 recall (N=425) -- 0.5505882352941176
# !**
# marble -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Art / All Wall Art', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Tables', 'Furniture / Living Room Furniture / Coffee Tables & End Tables / Coffee Tables']
# 425 recall (N=426) -- 0.5492957746478874
# !**
# welcome sign -- pred:{'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Wall Décor / Wall Accents', 'Décor & Pillows / Art / All Wall Art']
# 427 recall (N=428) -- 0.5490654205607477
# !**
# moen multi function dual shower head -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads / Dual Shower Heads', 'Home Improvement / Bathroom Remodel & Bathroom Fixtures / Showers & Bathtubs / Showers & Bathtubs Plumbing / Shower Heads / Fixed Shower Heads']
# 431 recall (N=432) -- 0.5509259259259259
# ***
# above toilet cabinet -- pred:{'Bed & Bath', 'Home Improvement'} != expected:Storage & Organization
# ['Home Improvement / Bathroom Remodel & Bathroom Fixtures / Bathroom Vanities / All Bathroom Vanities', 'Bed & Bath / Bathroom Accessories & Organization / Countertop Bath Accessories']
# 433 recall (N=434) -- 0.5506912442396313
# !**
# donaldson teak couch -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Living Room Furniture / Sectionals']
# 437 recall (N=438) -- 0.5525114155251142
# !**
# garage door mail slot -- pred:{'Home Improvement'} != expected:No Category Fits
# ['Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Levers', 'Home Improvement / Doors & Door Hardware / Door Hardware & Accessories / Door Knobs / Egg Door Knobs']
# 442 recall (N=443) -- 0.5553047404063205
# !**
# cliffside 5 light candle style drum chandelier -- pred:{'Lighting'} != expected:No Category Fits
# ['Lighting / Ceiling Lights / Chandeliers', 'Lighting / Ceiling Lights / Pendant Lighting', 'Lighting / Wall Lights / Wall Sconces']
# 443 recall (N=444) -- 0.5540540540540541
# ***
# dorel vanity -- pred:{'Furniture'} != expected:Home Improvement
# ['Furniture / Bedroom Furniture / Dressers & Chests', 'Furniture / Bedroom Furniture / Bedroom and Makeup Vanities']
# 445 recall (N=446) -- 0.5538116591928252
# !**
# hardwood beds -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Bedroom Furniture / Beds & Headboards / Headboards']
# 448 recall (N=449) -- 0.5545657015590201
# ***
# pennfield playhouse -- pred:{'Baby & Kids', 'Outdoor'} != expected:
# ['Baby & Kids / Toddler & Kids Playroom / Playroom Furniture / Toddler & Kids Chairs & Seating', 'Baby & Kids / Toddler & Kids Bedroom Furniture / Kids Beds', 'Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Outdoor Club Chairs']
# 450 recall (N=451) -- 0.5543237250554324
# !**
# memory foam rug galveston -- pred:{'Rugs'} != expected:No Category Fits
# ['Rugs / Area Rugs', 'Rugs / Doormats']
# 451 recall (N=452) -- 0.5530973451327433
# !**
# pool floats -- pred:{'Décor & Pillows', 'Outdoor'} != expected:No Category Fits
# ['Outdoor / Outdoor & Patio Furniture / Outdoor Seating & Patio Chairs / Patio Seating / Patio Sofas & Sectionals', 'Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Outdoor / Garden / Garden Décor / Lawn & Garden Accents']
# 452 recall (N=453) -- 0.5518763796909493
# !**
# mid century modern -- pred:{'Furniture'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Sofas', 'Furniture / Bedroom Furniture / Beds & Headboards / Beds', 'Furniture / Office Furniture / Desks', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Furniture / Kitchen & Dining Furniture / Dining Tables & Seating / Kitchen & Dining Chairs']
# 455 recall (N=456) -- 0.5526315789473685
# !**
# 54 in bench cushion -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Décor & Pillows / Decorative Pillows & Blankets / Throw Pillows', 'Furniture / Living Room Furniture / Chairs & Seating / Benches']
# 463 recall (N=464) -- 0.5581896551724138
# !**
# flour and sugar containers -- pred:{'Kitchen & Tabletop'} != expected:No Category Fits
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Ceramic Kitchen Canisters & Jars']
# 467 recall (N=468) -- 0.5598290598290598
# !**
# indoor multi tiered plant stand -- pred:{'Furniture', 'Décor & Pillows'} != expected:No Category Fits
# ['Furniture / Living Room Furniture / Coffee Tables & End Tables / Plant Stands & Tables', 'Furniture / Living Room Furniture / Chairs & Seating / Accent Chairs', 'Décor & Pillows / Home Accessories / Decorative Objects']
# 469 recall (N=470) -- 0.5595744680851064
# ***
# sugar canister -- pred:{'Kitchen & Tabletop'} != expected:
# ['Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Food Storage Containers', 'Kitchen & Tabletop / Kitchen Organization / Food Storage & Canisters / Kitchen Canisters & Jars / Metal Kitchen Canisters & Jars']
# 471 recall (N=472) -- 0.559322033898305
# !**
# palram harmony greenhouses -- pred:{'Outdoor', 'Home Improvement'} != expected:No Category Fits
# ['Outdoor / Garden / Greenhouses', 'Home Improvement / Building Equipment / Dollies / Hand Truck Dollies']
# 472 recall (N=473) -- 0.5581395348837209
# 0.5581395348837209

# %% [markdown]
# ## Run Category search strategy with classifier

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np

from cheat_at_search.agent.enrich import CachedEnricher, OpenAIEnricher


class CategorySearch(SearchStrategy):
    def __init__(self, products, query_to_cat,
                 name_boost=9.3,
                 description_boost=4.1,
                 category_boost=10,
                 sub_category_boost=5):
        super().__init__(products)
        self.index = products
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'], snowball_tokenizer)
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)

        cat_split = products['category hierarchy'].fillna('').str.split("/")

        products['category'] = cat_split.apply(
            lambda x: x[0].strip() if len(x) > 0 else ""
        )
        products['subcategory'] = cat_split.apply(
            lambda x: x[1].strip() if len(x) > 1 else ""
        )
        self.index['category_snowball'] = SearchArray.index(
            products['category'], snowball_tokenizer
        )
        self.index['subcategory_snowball'] = SearchArray.index(
            products['subcategory'], snowball_tokenizer
        )

        self.query_to_cat = query_to_cat
        self.name_boost = name_boost
        self.description_boost = description_boost
        self.category_boost = category_boost
        self.sub_category_boost = sub_category_boost

    def search(self, query, k=10):
        """Dumb baseline lexical search, but add a constant boost when
           the desired category or subcategory"""
        bm25_scores = np.zeros(len(self.index))
        structured = self.query_to_cat(query)
        tokenized = snowball_tokenizer(query)

        # ****
        # Baseline BM25 search from before
        for token in tokenized:
            bm25_scores += self.index['product_name_snowball'].array.score(token) * self.name_boost
            bm25_scores += self.index['product_description_snowball'].array.score(
                token) * self.description_boost

        # ****
        # If there's a subcategory, boost that by a constant amount
        for sub_category in structured.sub_categories:
            tokenized_subcategory = snowball_tokenizer(sub_category)
            subcategory_match = np.ones(len(self.index))
            if tokenized_subcategory:
                subcategory_match = self.index['subcategory_snowball'].array.score(tokenized_subcategory) > 0
            bm25_scores[subcategory_match] += self.sub_category_boost

        # ****
        # If there's a category, boost that by a constant amount
        for category in structured.categories:
            tokenized_category = snowball_tokenizer(category)
            category_match = np.ones(len(self.index))
            if tokenized_category:
                category_match = self.index['category_snowball'].array.score(tokenized_category) > 0
            bm25_scores[category_match] += self.category_boost

        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-365599876.py in <cell line: 0>()
#       4 import numpy as np
#       5
# ----> 6 from cheat_at_search.agent.enrich import CachedEnricher, OpenAIEnricher
#       7
#       8
#
# ModuleNotFoundError: No module named 'cheat_at_search.agent'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
categorized_search = CategorySearch(products, fully_classified)
graded_categorized = run_strategy(categorized_search)
graded_categorized

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_categorized).mean()

# %%
deltas = ndcg_delta(graded_categorized, graded_bm25)

# %%
sig_improved = len(deltas[deltas > 0.1])
print(f"Num Significatly Improved: {sig_improved}")
deltas[deltas > 0.1]

# %%
sig_harmed = len(deltas[deltas < -0.1])
print(f"Num Significatly Harmed: {sig_harmed}")
print(f"Prop improved/harmed: {sig_improved / (sig_harmed + sig_improved)} | {sig_harmed / (sig_harmed + sig_improved)}")
deltas[deltas < -0.1]

# %% [markdown]
# ### Look at a query

# %%
QUERY = "sugar canister"
fully_classified(QUERY)

# %%
ground_truth_cat[ground_truth_cat['query'] == QUERY]

# %%
graded_categorized[graded_categorized['query'] == QUERY][['product_name', 'category hierarchy', 'grade']]

# %%
graded_bm25[graded_bm25['query'] == QUERY][['product_name', 'category hierarchy', 'grade']]

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np

from cheat_at_search.agent.enrich import CachedEnricher, OpenAIEnricher


class CategorySearch(SearchStrategy):
    def __init__(self, products, query_to_cat,
                 name_boost=9.3,
                 description_boost=4.1,
                 category_boost=10,
                 sub_category_boost=5):
        super().__init__(products)
        self.index = products
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'], snowball_tokenizer)
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)

        cat_split = products['category hierarchy'].fillna('').str.split("/")

        products['category'] = cat_split.apply(
            lambda x: x[0].strip() if len(x) > 0 else ""
        )
        products['subcategory'] = cat_split.apply(
            lambda x: x[1].strip() if len(x) > 1 else ""
        )
        self.index['category_snowball'] = SearchArray.index(
            products['category'], snowball_tokenizer
        )
        self.index['subcategory_snowball'] = SearchArray.index(
            products['subcategory'], snowball_tokenizer
        )

        self.query_to_cat = query_to_cat
        self.name_boost = name_boost
        self.description_boost = description_boost
        self.category_boost = category_boost
        self.sub_category_boost = sub_category_boost

    def search(self, query, k=10):
        """Dumb baseline lexical search, but add a constant boost when
           the desired category or subcategory"""
        bm25_scores = np.zeros(len(self.index))
        structured = self.query_to_cat(query)
        tokenized = snowball_tokenizer(query)

        # ****
        # Baseline BM25 search from before
        num_tokens_matched = np.zeros(len(self.index))
        for token in tokenized:

            name_score = self.index['product_name_snowball'].array.score(token) * self.name_boost
            desc_score = self.index['product_description_snowball'].array.score(
                token) * self.description_boost
            bm25_scores += name_score + desc_score
            num_tokens_matched[(name_score + desc_score) > 0] += 1

        # ****
        # If there's a subcategory, boost that by a constant amount
        for sub_category in structured.sub_categories:
            tokenized_subcategory = snowball_tokenizer(sub_category)
            subcategory_match = np.ones(len(self.index))
            if tokenized_subcategory:
                subcategory_match = self.index['subcategory_snowball'].array.score(tokenized_subcategory) > 0
            bm25_scores[subcategory_match] += self.sub_category_boost

        # ****
        # If there's a category, boost that by a constant amount
        for category in structured.categories:
            tokenized_category = snowball_tokenizer(category)
            category_match = np.ones(len(self.index))
            if tokenized_category:
                category_match = self.index['category_snowball'].array.score(tokenized_category) > 0
            bm25_scores[category_match] += self.category_boost

        # ***
        # Require all tokens to match
        min_token_match = max(len(tokenized) / 2, 1)
        bm25_scores[num_tokens_matched < min_token_match] *= 0.8

        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores

# %%
categorized_search = CategorySearch(products, fully_classified)
graded_categorized2 = run_strategy(categorized_search)
graded_categorized2

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_categorized2).mean()
