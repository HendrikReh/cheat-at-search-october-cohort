# %% [markdown]
# # Query -> Category w/ No Category Found
#
# <small>
# (from <a href="http://maven.com/softwaredoug/cheat-at-search">Cheat at Search with LLMs</a> training course by Doug Turnbull.)
# </small>
#
# Previously we [categorized queries](https://colab.research.google.com/drive/1cPG0l-lCOPKDpCAJkhyNCwTjgTmCtzRz). In this notebook, we add a refinement to improve precision, but sacrificing recall. We let the LLM say it doesn't know by returning "No Category Found".
#
# This might let us get some of the benefit with less of the downside.

# %% [markdown]
# ## Boilerplate
#
# Install deps, mount GDrive, prompt for your OpenAI Key (placed in your GDrive), and import needed cheat at search helpers.
#
# We cover this extensively in the [synonyms notebook](https://colab.research.google.com/drive/1aUCvcBa1YdmsbIgYc74jlknl9_iRotp1) walkthrough

# %%
# !pip install git+https://github.com/softwaredoug/cheat-at-search.git
from cheat_at_search.data_dir import mount
mount(use_gdrive=True)
from cheat_at_search.search import run_strategy, graded_bm25, ndcgs, ndcg_delta, vs_ideal
from cheat_at_search.wands_data import products

products
# Out:
# Collecting git+https://github.com/softwaredoug/cheat-at-search.git
#   Cloning https://github.com/softwaredoug/cheat-at-search.git to /tmp/pip-req-build-o8a1aody
#   Running command git clone --filter=blob:none --quiet https://github.com/softwaredoug/cheat-at-search.git /tmp/pip-req-build-o8a1aody
#   Resolved https://github.com/softwaredoug/cheat-at-search.git to commit 38a087b480422fb5f29fea8b25fbfb25f3492da3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: google-genai<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.41.0)
# Requirement already satisfied: openai<2.0.0,>=1.84.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (1.109.1)
# Requirement already satisfied: pandas<3.0.0,>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.2.2)
# Requirement already satisfied: pyarrow<22.0.0,>=14.0.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (18.1.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (2.11.10)
# Collecting pystemmer<4.0.0,>=3.0.0 (from cheat_at_search==0.1.0)
#   Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from cheat_at_search==0.1.0) (6.0.3)
# Collecting searcharray<0.0.73,>=0.0.72 (from cheat_at_search==0.1.0)
#   Downloading searcharray-0.0.72-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.11.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.38.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (0.11.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.84.0->cheat_at_search==0.1.0) (4.67.1)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.11.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: Cython in /usr/local/lib/python3.12/dist-packages (from searcharray<0.0.73,>=0.0.72->cheat_at_search==0.1.0) (3.0.12)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.10)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.2.0->cheat_at_search==0.1.0) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.2.0->cheat_at_search==0.1.0) (0.6.1)
# Downloading PyStemmer-3.0.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (745 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 745.3/745.3 kB 8.1 MB/s eta 0:00:00
# Downloading searcharray-0.0.72-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 4.4 MB/s eta 0:00:00
# Building wheels for collected packages: cheat_at_search
#   Building wheel for cheat_at_search (pyproject.toml) ... done
#   Created wheel for cheat_at_search: filename=cheat_at_search-0.1.0-py3-none-any.whl size=40951 sha256=8418acb416c9862f0b3fa4692cd9d08d55a5bb825fbf6e9026c2c056005c31cc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-t7jmhz8o/wheels/ea/96/d3/e69453e5f86e6f891864e5b5baf2b11ffda2d0981d9f8a138e
# Successfully built cheat_at_search
# Installing collected packages: pystemmer, searcharray, cheat_at_search
# Successfully installed cheat_at_search-0.1.0 pystemmer-3.0.0 searcharray-0.0.72
# Mounted at /content/drive
#        product_id                                       product_name  \
# 0               0                            solid wood platform bed
# 1               1                        all-clad 7 qt . slow cooker
# 2               2            all-clad electrics 6.5 qt . slow cooker
# 3               3       all-clad all professional tools pizza cutter
# 4               4  baldwin prestige alcott passage knob with roun...
# ...           ...                                                ...
# 42989       42989  malibu pressure balanced diverter fixed shower...
# 42990       42990              emmeline 5 piece breakfast dining set
# 42991       42991                      maloney 3 piece pub table set
# 42992       42992           fletcher 27.5 '' wide polyester armchair
# 42993       42993                            griffin 29 '' bar stool
#
#                              product_class  \
# 0                                     Beds
# 1                             Slow Cookers
# 2                             Slow Cookers
# 3             Slicers, Peelers And Graters
# 4                               Door Knobs
# ...                                    ...
# 42989                        Shower Panels
# 42990                    Dining Table Sets
# 42991                    Dining Table Sets
# 42992  Teen Lounge Furniture|Accent Chairs
# 42993                           Bar Stools
#
#                                       category hierarchy  \
# 0      Furniture / Bedroom Furniture / Beds & Headboa...
# 1      Kitchen & Tabletop / Small Kitchen Appliances ...
# 2      Kitchen & Tabletop / Small Kitchen Appliances ...
# 3                             Browse By Brand / All-Clad
# 4      Home Improvement / Doors & Door Hardware / Doo...
# ...                                                  ...
# 42989  Home Improvement / Bathroom Remodel & Bathroom...
# 42990  Furniture / Kitchen & Dining Furniture / Dinin...
# 42991  Furniture / Kitchen & Dining Furniture / Dinin...
# 42992  Furniture / Living Room Furniture / Chairs & S...
# 42993  Furniture / Kitchen & Dining Furniture / Bar F...
#
#                                      product_description  \
# 0      good , deep sleep can be quite difficult to ha...
# 1      create delicious slow-cooked meals , from tend...
# 2      prepare home-cooked meals on any schedule with...
# 3      this original stainless tool was designed to c...
# 4      the hardware has a rich heritage of delivering...
# ...                                                  ...
# 42989  the malibu pressure balanced diverter fixed sh...
# 42990
# 42991  this pub table set includes 1 counter height t...
# 42992  bring iconic , modern style to your space in a...
# 42993  this set of two barstools features a minimalis...
#
#                                         product_features  rating_count  \
# 0      overallwidth-sidetoside:64.7|dsprimaryproducts...          15.0
# 1      capacityquarts:7|producttype : slow cooker|pro...         100.0
# 2      features : keep warm setting|capacityquarts:6....         208.0
# 3      overallwidth-sidetoside:3.5|warrantylength : l...          69.0
# 4      compatibledoorthickness:1.375 '' |countryofori...          70.0
# ...                                                  ...           ...
# 42989  producttype : shower panel|spraypattern : rain...           3.0
# 42990  basematerialdetails : steel| : gray wood|ofhar...        1314.0
# 42991  additionaltoolsrequirednotincluded : power dri...          49.0
# 42992  legmaterialdetails : rubberwood|backheight-sea...        1746.0
# 42993  distancebetweenfloorandfootrest:7.5|dssecondar...          20.0
#
#        average_rating  review_count  \
# 0                 4.5          15.0
# 1                 2.0          98.0
# 2                 3.0         181.0
# 3                 4.5          42.0
# 4                 5.0          42.0
# ...               ...           ...
# 42989             4.5           2.0
# 42990             4.5         864.0
# 42991             4.0          41.0
# 42992             4.5        1226.0
# 42993             4.5          20.0
#
#                                                 features             category  \
# 0      [overallwidth-sidetoside:64.7, dsprimaryproduc...           Furniture
# 1      [capacityquarts:7, producttype : slow cooker, ...  Kitchen & Tabletop
# 2      [features : keep warm setting, capacityquarts:...  Kitchen & Tabletop
# 3      [overallwidth-sidetoside:3.5, warrantylength :...     Browse By Brand
# 4      [compatibledoorthickness:1.375 '' , countryofo...    Home Improvement
# ...                                                  ...                  ...
# 42989  [producttype : shower panel, spraypattern : ra...    Home Improvement
# 42990  [basematerialdetails : steel,  : gray wood, of...           Furniture
# 42991  [additionaltoolsrequirednotincluded : power dr...           Furniture
# 42992  [legmaterialdetails : rubberwood, backheight-s...           Furniture
# 42993  [distancebetweenfloorandfootrest:7.5, dssecond...           Furniture
#
#                                  sub_category  \
# 0                          Bedroom Furniture
# 1                   Small Kitchen Appliances
# 2                   Small Kitchen Appliances
# 3                                    All-Clad
# 4                      Doors & Door Hardware
# ...                                       ...
# 42989   Bathroom Remodel & Bathroom Fixtures
# 42990             Kitchen & Dining Furniture
# 42991             Kitchen & Dining Furniture
# 42992                  Living Room Furniture
# 42993             Kitchen & Dining Furniture
#
#                                               cat_subcat
# 0                       Furniture  /  Bedroom Furniture
# 1       Kitchen & Tabletop  /  Small Kitchen Appliances
# 2       Kitchen & Tabletop  /  Small Kitchen Appliances
# 3                           Browse By Brand  /  All-Clad
# 4            Home Improvement  /  Doors & Door Hardware
# ...                                                  ...
# 42989  Home Improvement  /  Bathroom Remodel & Bathro...
# 42990          Furniture  /  Kitchen & Dining Furniture
# 42991          Furniture  /  Kitchen & Dining Furniture
# 42992               Furniture  /  Living Room Furniture
# 42993          Furniture  /  Kitchen & Dining Furniture
#
# [42994 rows x 13 columns]

# %% [markdown]
# ## Query -> Category classification (allow no category found)
#
# Iterating on the previous notebook, this code is identical. However we have added No Category Found / No SubCategory Found. Note the comments of what's ADDED/CHANGED from before.
#
# **What's the goal?** -- search is a constant precision / recall tradeoff. Here, we know there is big downside to misclassification. What if we mitigate that downside by giving the LLM the ability to NOT classify to a category.

# %%
from pydantic import BaseModel, Field
from typing import List, Literal
from cheat_at_search.enrich import AutoEnricher


CategoriesWithUnknown = Literal['Furniture',
                     'Home Improvement',
                     'Décor & Pillows',
                     'Outdoor',
                     'Storage & Organization',
                     'Lighting',
                     'Rugs',
                     'Bed & Bath',
                     'Kitchen & Tabletop',
                     'Baby & Kids',
                     'School Furniture and Supplies',
                     'Appliances',
                     'Holiday Décor',
                     'Commercial Business Furniture',
                     'Pet',
                     'Contractor',
                     'Sale',
                     'Foodservice ',
                     'Reception Area',
                     'Clips',
                     'No Category Fits']   #< ADDDED!

SubCategoriesWithUnknown = Literal['Bedroom Furniture',
 'Small Kitchen Appliances',
 'All-Clad',
 'Doors & Door Hardware',
 'Bathroom Remodel & Bathroom Fixtures',
 'Home Accessories',
 'Living Room Furniture',
 'Outdoor Décor',
 'Flooring, Walls & Ceiling',
 'Garage & Outdoor Storage & Organization',
 'Cookware & Bakeware',
 'Bedding',
 'Kitchen Utensils & Tools',
 'Shower Curtains & Accessories',
 'Wall Shelving & Organization',
 'Clocks',
 'Bedding Essentials',
 'Kitchen & Dining Furniture',
 'Office Furniture',
 'Tableware & Drinkware',
 'Nursery Bedding',
 'Cat',
 'Outdoor Shades',
 'Outdoor & Patio Furniture',
 'Ceiling Lights',
 'Area Rugs',
 'Outdoor Lighting',
 'Window Treatments',
 'Garden',
 'Closet Storage & Organization',
 'Wall Décor',
 'Mirrors',
 'Shoe Storage',
 'Toddler & Kids Playroom',
 'Game Tables & Game Room Furniture',
 'Decorative Pillows & Blankets',
 'School Furniture',
 'Wall Lights',
 'Bathroom Storage & Organization',
 'Commercial Office Furniture',
 'Flowers & Plants',
 'Mattresses & Foundations',
 'Area Rugs',
 'Cleaning & Laundry Organization',
 'Kitchen Organization',
 'Candles & Holders',
 'Christmas',
 'Toddler & Kids Bedroom Furniture',
 'Front Door Décor & Curb Appeal',
 'Storage Furniture',
 'School Spaces',
 'Hardware',
 'Light Bulbs & Hardware',
 'Ceiling Fans',
 'Doormats',
 'Entry & Hallway',
 'Storage Containers & Drawers',
 'Holiday Lighting',
 'Kitchen Mats',
 'Facilities & Maintenance',
 'Table & Floor Lamps',
 'Bird',
 'Kitchen Appliances',
 'Building Equipment',
 'Art',
 'Picture Frames & Albums',
 'Outdoor Heating',
 'Outdoor Recreation',
 'Bathroom Accessories & Organization',
 'School Boards & Technology',
 'Closeout',
 'Reception Seating',
 'Foodservice Tables',
 'Kitchen Remodel & Kitchen Fixtures',
 'Hot Tubs & Saunas',
 'Teen Bedroom Furniture',
 'Outdoor Fencing & Flooring',
 'Chairs',
 'Bath Rugs & Towels',
 'Fish',
 'Dog',
 'Chicken',
 'Boards & Tech Accessories',
 'Commercial Contractor',
 'Clamps',
 'Jewelry Organization',
 'Entry & Mudroom Furniture',
 'Outdoor Cooking & Tableware',
 'Seasonal Décor',
 'Nursery Furniture',
 'Storage & Organization Sale',
 'Washers & Dryers',
 'Baby & Kids Décor & Lighting',
 'Outdoor Remodel',
 'Plumbing',
 'Birch Lane™',
 'Office Organization',
 'Kitchen & Dining Sale',
 'Holiday Lighting',
 'Baby & Kids Storage',
 'Shop All Characters',
 'Commercial Kitchen',
 'Guest Room Amenities',
 'Charlton Home',
 'Wade Logan®',
 'Heating, Cooling & Air Quality',
 'Thanksgiving',
 'Fourth of July',
 'Vacuums & Deep Cleaners',
 'Stair Tread Rugs',
 'Small Spaces',
 'Toddler & Kids Bedding & Bath',
 'Classroom Décor',
 'Early Education Play Area',
 'Zoomie Kids',
 'Fryers',
 'August Grove',
 'Dorm Décor & Back to School Essentials',
 'Symple Stuff',
 'Wayfair Basics®',
 'The Holiday Aisle',
 'Chair Pads & Cushions',
 'The Monogram Shop',
 'Wedding',
 'Wedding',
 'Reception Desks & Tables',
 'Rug Pads',
 'Latitude Run',
 'Accommodations Furniture',
 'Easter',
 'Furniture Sale',
 'Shop All Characters',
 'Novelty Lights',
 "Valentine's Day",
 'Outdoor Sale',
 'Classroom & Training Furniture',
 'Rebrilliant',
 'Rug Pads',
 'Commercial Kitchen Storage',
 'Teen Bedding',
 'Tommy Bahama Home',
 'Appliances Sale',
 'Massage Products',
 'No SubCategory Fits']   #< ADDDED!


class Query(BaseModel):
    """
    Base model for search queries, containing common query attributes.
    """
    keywords: str = Field(
        ...,
        description="The original search query keywords sent in as input"
    )


class QueryCategoryWithUnknown(Query):
    """
    Structured representation of a search query for furniture e-commerce.
    Inherits keywords from the base Query model and adds category and sub-category.
    """
    category: CategoriesWithUnknown = Field(
        description="Category of the product, if identified. Use 'No Category Fits' if ambiguous or no category in list fits"
    ) # CHANGED - description allows classification to unknown
    sub_category: SubCategoriesWithUnknown = Field(
        description="Sub-category of the product, if identified. Use 'No SubCategory Fits' if ambiguous or no sub-category in list fits"
    ) # CHANGED - description allows classification to unknown

    @property
    def classification(self) -> str:
        return f"{self.category} / {self.sub_category}"

# %% [markdown]
# ### Query classification code
#
# Our code here is identical to

# %%
enricher = AutoEnricher(
     model="openai/gpt-4o",
     system_prompt="You are a helpful furniture shopping agent that helps users construct search queries.",
     response_model=QueryCategoryWithUnknown
)

def get_prompt_with_unknown(query):
    prompt = f"""
        As a helpful agent, you'll recieve requests from users looking for furniture products.

        Your task is to search with a structured query against a furniture product catalog.

        Here is the users request:

        {query}

        Return Category / Subcategory:

        * Category - the category (as listed in schema) for the query.
        * SubCategory - the subcategory (as listed in the schema) for the query

        Use "No Category Fits" / "No SubCategory Fits" if ambiguous, unclear, or many might fit.
    """
    return prompt


def categorized_with_unknown(query):
    prompt = get_prompt_with_unknown(query)
    return enricher.enrich(prompt)

categorized_with_unknown("banana popsicle")
# Out:
# QueryCategoryWithUnknown(keywords='banana popsicle', category='No Category Fits', sub_category='No SubCategory Fits')

# %% [markdown]
# ### Define ground truth
#
# As in the previous notebook, we re-define our ground truth for query classification. We define `prec_cat` to measure precision.

# %%
from cheat_at_search.wands_data import labeled_query_products, queries

def get_top_category(column, no_fit_label, cutoff=0.8):
    # Get relevant products per query
    top_products = labeled_query_products[labeled_query_products['grade'] == 2]

    # Aggregate top categories
    categories_per_query_ideal = top_products.groupby('query')[column].value_counts().reset_index()

    # Get as percentage of all categories for this query
    top_cat_proportion = categories_per_query_ideal.groupby(['query', column]).sum() / categories_per_query_ideal.groupby('query').sum()
    top_cat_proportion = top_cat_proportion.drop(columns=column).reset_index()

    # Only look at cases where the category is > 0.8
    top_cat_proportion = top_cat_proportion[top_cat_proportion['count'] > cutoff]
    top_cat_proportion[column].fillna(no_fit_label, inplace=True)
    ground_truth_cat = top_cat_proportion
    # Give No Category Fits to all others without dominant category
    ground_truth_cat = ground_truth_cat.merge(queries, how='right', on='query')[['query', column, 'count']]
    ground_truth_cat[column].fillna(no_fit_label, inplace=True)
    return ground_truth_cat

ground_truth_cat = get_top_category('category', 'No Category Fits')
ground_truth_cat
# Out:
# /tmp/ipython-input-3280341426.py:16: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   top_cat_proportion[column].fillna(no_fit_label, inplace=True)
# /tmp/ipython-input-3280341426.py:20: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   ground_truth_cat[column].fillna(no_fit_label, inplace=True)
#                                                  query          category  \
# 0                                          salon chair  No Category Fits
# 1                                   smart coffee table        Furniture
# 2                                             dinosaur  No Category Fits
# 3                                    turquoise pillows  Décor & Pillows
# 4                            chair and a half recliner        Furniture
# ..                                                 ...               ...
# 475                                        rustic twig  Décor & Pillows
# 476  nespresso vertuo next premium by breville with...  No Category Fits
# 477                                     pedistole sink  No Category Fits
# 478                                54 in bench cushion  No Category Fits
# 479                                         rack glass  No Category Fits
#
#         count
# 0         NaN
# 1    1.000000
# 2         NaN
# 3    0.963636
# 4    0.956522
# ..        ...
# 475  1.000000
# 476       NaN
# 477       NaN
# 478       NaN
# 479       NaN
#
# [480 rows x 3 columns]

# %% [markdown]
# ### Modified precision -- measure coverage / recall
#
# We'll measure both precision -- accuracy when prediction made -- and coverage -- how many items are given predictions.

# %%
def get_pred(cat, column):
    if column == 'category':
        return cat.category
    elif column == 'sub_category':
        return cat.sub_category
    else:
        raise ValueError(f"Unknown column {column}")


def prec_cat(ground_truth, column, no_fit_label, categorized, N=500):
    hits = []
    misses = []
    for _, row in ground_truth.sample(frac=1).iterrows():
        query = row['query']
        expected_category = row[column]

        cat = categorized(query)
        pred = get_pred(cat, column)
        if pred == no_fit_label:
            print(f"Skipping {query}")
            continue
        if pred == expected_category.strip():
            hits.append((expected_category, cat))
        else:
            print("***")
            print(f"{query} -- predicted:{cat.category} != expected:{expected_category.strip()}")
            misses.append((expected_category, cat))
            num_so_far = len(hits) + len(misses)
            print(f"prec (N={num_so_far}) -- {len(hits) / (len(hits) + len(misses))}")
            print(f"coverage {num_so_far / len(ground_truth)}")

        if len(hits) + len(misses) > N:
            break
    return len(hits) / (len(hits) + len(misses)), num_so_far / len(ground_truth)

prec, coverage = prec_cat(ground_truth_cat, 'category', 'No Category Fits', categorized_with_unknown, N=500)
prec, coverage
# Out:
# Skipping kisner
# ***
# cake plates with tops -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=1) -- 0.0
# coverage 0.0020833333333333333
# ***
# desk and chair set -- predicted:Furniture != expected:No Category Fits
# prec (N=2) -- 0.0
# coverage 0.004166666666666667
# ***
# tall storage cabinet -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=3) -- 0.0
# coverage 0.00625
# Skipping merlyn 6
# Skipping industrial
# ***
# board game storage cabinet -- predicted:Storage & Organization != expected:Furniture
# prec (N=7) -- 0.42857142857142855
# coverage 0.014583333333333334
# ***
# gray leather cocktail table -- predicted:Furniture != expected:No Category Fits
# prec (N=8) -- 0.375
# coverage 0.016666666666666666
# Skipping promo codes or discounts
# ***
# 54 in bench cushion -- predicted:Furniture != expected:No Category Fits
# prec (N=10) -- 0.4
# coverage 0.020833333333333332
# ***
# acrylic clear chair -- predicted:Furniture != expected:No Category Fits
# prec (N=11) -- 0.36363636363636365
# coverage 0.022916666666666665
# ***
# nespresso vertuo next premium by breville with aeroccino -- predicted:Appliances != expected:No Category Fits
# prec (N=16) -- 0.5
# coverage 0.03333333333333333
# ***
# podium with locking cabinet -- predicted:Commercial Business Furniture != expected:School Furniture and Supplies
# prec (N=17) -- 0.47058823529411764
# coverage 0.035416666666666666
# Skipping argenteuil
# ***
# star wars rug -- predicted:Rugs != expected:No Category Fits
# prec (N=21) -- 0.5238095238095238
# coverage 0.04375
# ***
# palram harmony greenhouses -- predicted:Outdoor != expected:No Category Fits
# prec (N=22) -- 0.5
# coverage 0.04583333333333333
# Skipping gas detector
# ***
# queen ann style living room chair -- predicted:Furniture != expected:No Category Fits
# prec (N=25) -- 0.52
# coverage 0.052083333333333336
# Skipping peacock
# ***
# white bathroom vanity black hardware -- predicted:Home Improvement != expected:No Category Fits
# prec (N=27) -- 0.5185185185185185
# coverage 0.05625
# Skipping outdoor movie screen
# ***
# wall sconce with usb port -- predicted:Lighting != expected:No Category Fits
# prec (N=30) -- 0.5333333333333333
# coverage 0.0625
# ***
# coffee table fire pit -- predicted:Outdoor != expected:
# prec (N=32) -- 0.53125
# coverage 0.06666666666666667
# ***
# urban outfitters duvet -- predicted:Bed & Bath != expected:No Category Fits
# prec (N=33) -- 0.5151515151515151
# coverage 0.06875
# ***
# black hanging bookshelf -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=34) -- 0.5
# coverage 0.07083333333333333
# ***
# semi flush foyer light -- predicted:Lighting != expected:No Category Fits
# prec (N=35) -- 0.4857142857142857
# coverage 0.07291666666666667
# Skipping wisdom stone river 3-3/4
# Skipping pineapple
# ***
# arched christmas tree -- predicted:Holiday Décor != expected:No Category Fits
# prec (N=37) -- 0.4864864864864865
# coverage 0.07708333333333334
# ***
# berenice 4 storage cabinet -- predicted:Storage & Organization != expected:Furniture
# prec (N=38) -- 0.47368421052631576
# coverage 0.07916666666666666
# Skipping marble
# ***
# memory foam rug galveston -- predicted:Rugs != expected:No Category Fits
# prec (N=42) -- 0.5
# coverage 0.0875
# ***
# counter top one cup hot water dispenser -- predicted:Appliances != expected:No Category Fits
# prec (N=43) -- 0.4883720930232558
# coverage 0.08958333333333333
# ***
# indoor multi tiered plant stand -- predicted:Furniture != expected:No Category Fits
# prec (N=45) -- 0.4888888888888889
# coverage 0.09375
# Skipping kari 2 piece
# Skipping ruckus chair
# Skipping canadian
# Skipping zachary 72.5
# ***
# anti fatigue mat -- predicted:Kitchen & Tabletop != expected:Rugs
# prec (N=52) -- 0.5384615384615384
# coverage 0.10833333333333334
# ***
# donaldson teak couch -- predicted:Furniture != expected:No Category Fits
# prec (N=56) -- 0.5535714285714286
# coverage 0.11666666666666667
# ***
# stoneford end tables white and wood -- predicted:Furniture != expected:No Category Fits
# prec (N=58) -- 0.5517241379310345
# coverage 0.12083333333333333
# ***
# trinaic towel rod -- predicted:Home Improvement != expected:No Category Fits
# prec (N=60) -- 0.55
# coverage 0.125
# Skipping milk cow chair
# ***
# bed risers -- predicted:Furniture != expected:No Category Fits
# prec (N=61) -- 0.5409836065573771
# coverage 0.12708333333333333
# ***
# deer coat hooks -- predicted:Décor & Pillows != expected:Contractor
# prec (N=65) -- 0.5538461538461539
# coverage 0.13541666666666666
# ***
# twin bed frame -- predicted:Furniture != expected:No Category Fits
# prec (N=68) -- 0.5588235294117647
# coverage 0.14166666666666666
# ***
# basket planter -- predicted:Décor & Pillows != expected:Outdoor
# prec (N=70) -- 0.5571428571428572
# coverage 0.14583333333333334
# ***
# bathroom wastebasket -- predicted:Bed & Bath != expected:No Category Fits
# prec (N=71) -- 0.5492957746478874
# coverage 0.14791666666666667
# ***
# writing desk 48" -- predicted:Furniture != expected:No Category Fits
# prec (N=78) -- 0.5769230769230769
# coverage 0.1625
# Skipping zen
# ***
# dull bed with shirt head board -- predicted:Furniture != expected:No Category Fits
# prec (N=84) -- 0.5952380952380952
# coverage 0.175
# ***
# hitchcock mid-century wall shelf -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=86) -- 0.5930232558139535
# coverage 0.17916666666666667
# ***
# brushed gold wall decor -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=87) -- 0.5862068965517241
# coverage 0.18125
# ***
# 48 inch bathroom vanity with trough sink -- predicted:Home Improvement != expected:No Category Fits
# prec (N=90) -- 0.5888888888888889
# coverage 0.1875
# ***
# aiden black velvet bed -- predicted:Furniture != expected:No Category Fits
# prec (N=91) -- 0.5824175824175825
# coverage 0.18958333333333333
# ***
# outdoor welcome rug -- predicted:Outdoor != expected:Rugs
# prec (N=92) -- 0.5760869565217391
# coverage 0.19166666666666668
# ***
# tressler rug -- predicted:Rugs != expected:No Category Fits
# prec (N=93) -- 0.5698924731182796
# coverage 0.19375
# ***
# outdoor clock -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=94) -- 0.5638297872340425
# coverage 0.19583333333333333
# ***
# carpet 5x6 -- predicted:Rugs != expected:No Category Fits
# prec (N=96) -- 0.5625
# coverage 0.2
# ***
# full bed with trundle -- predicted:Furniture != expected:No Category Fits
# prec (N=100) -- 0.57
# coverage 0.20833333333333334
# Skipping french molding
# Skipping mom urn
# ***
# sliding closet mirror -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=102) -- 0.5686274509803921
# coverage 0.2125
# ***
# certified international melamine -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=104) -- 0.5673076923076923
# coverage 0.21666666666666667
# Skipping rock climbing wall kids
# ***
# family lamp -- predicted:Lighting != expected:No Category Fits
# prec (N=106) -- 0.5660377358490566
# coverage 0.22083333333333333
# ***
# vlad modular sectional -- predicted:Furniture != expected:No Category Fits
# prec (N=108) -- 0.5648148148148148
# coverage 0.225
# ***
# girl reading statue -- predicted:Décor & Pillows != expected:Outdoor
# prec (N=109) -- 0.5596330275229358
# coverage 0.22708333333333333
# ***
# rustic storage cabinet -- predicted:Storage & Organization != expected:Furniture
# prec (N=110) -- 0.5545454545454546
# coverage 0.22916666666666666
# Skipping wainscoting ideas
# ***
# pool floats -- predicted:Outdoor != expected:No Category Fits
# prec (N=114) -- 0.5614035087719298
# coverage 0.2375
# Skipping surge protector
# Skipping rustic twig
# ***
# mid century modern -- predicted:Furniture != expected:No Category Fits
# prec (N=122) -- 0.5819672131147541
# coverage 0.25416666666666665
# Skipping white splashproof shiplap wallpaper
# ***
# grill cover 73 -- predicted:Outdoor != expected:Storage & Organization
# prec (N=124) -- 0.5806451612903226
# coverage 0.25833333333333336
# ***
# black fluffy stool -- predicted:Furniture != expected:No Category Fits
# prec (N=127) -- 0.5826771653543307
# coverage 0.26458333333333334
# ***
# kitchen wooden stand -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=128) -- 0.578125
# coverage 0.26666666666666666
# ***
# living room ideas -- predicted:Furniture != expected:No Category Fits
# prec (N=132) -- 0.5833333333333334
# coverage 0.275
# ***
# body pillow and case -- predicted:Décor & Pillows != expected:Bed & Bath
# prec (N=133) -- 0.5789473684210527
# coverage 0.27708333333333335
# ***
# 7qt slow cooker -- predicted:Appliances != expected:Kitchen & Tabletop
# prec (N=134) -- 0.5746268656716418
# coverage 0.2791666666666667
# ***
# burnt orange curtains -- predicted:Décor & Pillows != expected:Rugs
# prec (N=135) -- 0.5703703703703704
# coverage 0.28125
# Skipping liberty hardware francisco
# ***
# whimsical solar lights -- predicted:Outdoor != expected:Lighting
# prec (N=136) -- 0.5661764705882353
# coverage 0.2833333333333333
# Skipping one alium way
# ***
# chabely 5 draw chest -- predicted:Furniture != expected:No Category Fits
# prec (N=139) -- 0.5683453237410072
# coverage 0.28958333333333336
# ***
# self enclosed planters -- predicted:Outdoor != expected:No Category Fits
# prec (N=141) -- 0.5673758865248227
# coverage 0.29375
# ***
# luau string lights -- predicted:Lighting != expected:Holiday Décor
# prec (N=142) -- 0.5633802816901409
# coverage 0.29583333333333334
# ***
# moen multi function dual shower head -- predicted:Home Improvement != expected:No Category Fits
# prec (N=144) -- 0.5625
# coverage 0.3
# Skipping beaded curtains
# ***
# cover set for outdoor furniture -- predicted:Outdoor != expected:Storage & Organization
# prec (N=147) -- 0.564625850340136
# coverage 0.30625
# ***
# nettie 5 pc bar set -- predicted:Furniture != expected:Outdoor
# prec (N=148) -- 0.5608108108108109
# coverage 0.30833333333333335
# ***
# pedistole sink -- predicted:Home Improvement != expected:No Category Fits
# prec (N=149) -- 0.5570469798657718
# coverage 0.3104166666666667
# ***
# gray dresser -- predicted:Furniture != expected:No Category Fits
# prec (N=150) -- 0.5533333333333333
# coverage 0.3125
# ***
# emma headboard -- predicted:Furniture != expected:Baby & Kids
# prec (N=152) -- 0.5526315789473685
# coverage 0.31666666666666665
# ***
# glinda upholstered bench -- predicted:Furniture != expected:No Category Fits
# prec (N=153) -- 0.5490196078431373
# coverage 0.31875
# ***
# living room designs -- predicted:Furniture != expected:No Category Fits
# prec (N=155) -- 0.5483870967741935
# coverage 0.3229166666666667
# ***
# 3/4 size mattress -- predicted:Furniture != expected:No Category Fits
# prec (N=159) -- 0.5534591194968553
# coverage 0.33125
# ***
# chair pillow cushion -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=161) -- 0.5527950310559007
# coverage 0.33541666666666664
# ***
# garage door mail slot -- predicted:Home Improvement != expected:No Category Fits
# prec (N=162) -- 0.5493827160493827
# coverage 0.3375
# ***
# nectar queen mattress -- predicted:Furniture != expected:No Category Fits
# prec (N=165) -- 0.5515151515151515
# coverage 0.34375
# ***
# door jewelry organizer -- predicted:Storage & Organization != expected:Furniture
# prec (N=168) -- 0.5535714285714286
# coverage 0.35
# ***
# foutains with brick look -- predicted:Outdoor != expected:
# prec (N=169) -- 0.5502958579881657
# coverage 0.35208333333333336
# ***
# kitchen storage cabinet -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=172) -- 0.5523255813953488
# coverage 0.35833333333333334
# Skipping printers
# Skipping wayfair tension rod
# ***
# oriental vanity -- predicted:Furniture != expected:No Category Fits
# prec (N=176) -- 0.5568181818181818
# coverage 0.36666666666666664
# ***
# huntsville sectional sofa -- predicted:Furniture != expected:No Category Fits
# prec (N=179) -- 0.5586592178770949
# coverage 0.3729166666666667
# Skipping oliver parsons
# ***
# day bed indian -- predicted:Furniture != expected:No Category Fits
# prec (N=184) -- 0.5652173913043478
# coverage 0.38333333333333336
# ***
# farmhouse hood vent -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=185) -- 0.5621621621621622
# coverage 0.3854166666666667
# Skipping wayfair sleep zippered
# ***
# coat rack for bedroom -- predicted:Furniture != expected:Contractor
# prec (N=188) -- 0.5638297872340425
# coverage 0.39166666666666666
# ***
# welcome sign -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=190) -- 0.5631578947368421
# coverage 0.3958333333333333
# Skipping gold
# ***
# parakeet toy -- predicted:Pet != expected:No Category Fits
# prec (N=193) -- 0.5647668393782384
# coverage 0.40208333333333335
# ***
# chaves l-shape floating desk with hutch -- predicted:Furniture != expected:No Category Fits
# prec (N=196) -- 0.5663265306122449
# coverage 0.4083333333333333
# Skipping small curtain rods
# ***
# chinese flower stand -- predicted:Décor & Pillows != expected:Furniture
# prec (N=198) -- 0.5656565656565656
# coverage 0.4125
# ***
# zakariyah twin platform -- predicted:Furniture != expected:Baby & Kids
# prec (N=199) -- 0.5628140703517588
# coverage 0.41458333333333336
# ***
# antique silver entry table -- predicted:Furniture != expected:No Category Fits
# prec (N=200) -- 0.56
# coverage 0.4166666666666667
# ***
# fawkes 36" blue vanity -- predicted:Furniture != expected:No Category Fits
# prec (N=201) -- 0.5572139303482587
# coverage 0.41875
# ***
# fold in half table -- predicted:Furniture != expected:School Furniture and Supplies
# prec (N=204) -- 0.5588235294117647
# coverage 0.425
# Skipping malachi sled
# ***
# gnome fairy garden -- predicted:Décor & Pillows != expected:Outdoor
# prec (N=207) -- 0.5603864734299517
# coverage 0.43125
# Skipping picasso
# ***
# king adjustable bed including mattress -- predicted:Furniture != expected:No Category Fits
# prec (N=212) -- 0.5660377358490566
# coverage 0.44166666666666665
# ***
# navy and peach bedding -- predicted:Bed & Bath != expected:No Category Fits
# prec (N=213) -- 0.5633802816901409
# coverage 0.44375
# ***
# wall art fiji -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=214) -- 0.5607476635514018
# coverage 0.44583333333333336
# ***
# nursery end table -- predicted:Baby & Kids != expected:No Category Fits
# prec (N=218) -- 0.5642201834862385
# coverage 0.45416666666666666
# ***
# mobley zero gravity adjustable bed with wireless remote -- predicted:Furniture != expected:Bed & Bath
# prec (N=219) -- 0.5616438356164384
# coverage 0.45625
# ***
# outdoor seat/back cushion -- predicted:Outdoor != expected:
# prec (N=221) -- 0.5610859728506787
# coverage 0.46041666666666664
# Skipping dual monitor stand
# ***
# porcelain loaf pan -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=223) -- 0.5605381165919282
# coverage 0.46458333333333335
# ***
# round outdoor patio cover -- predicted:Outdoor != expected:No Category Fits
# prec (N=226) -- 0.5619469026548672
# coverage 0.4708333333333333
# ***
# 7 draw white dresser -- predicted:Furniture != expected:No Category Fits
# prec (N=227) -- 0.5594713656387665
# coverage 0.47291666666666665
# Skipping brunk ship wheel
# ***
# pictures to hang over fireplace -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=229) -- 0.5589519650655022
# coverage 0.47708333333333336
# ***
# black frame 22 x 36 -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=230) -- 0.5565217391304348
# coverage 0.4791666666666667
# ***
# carolyn console table -- predicted:Furniture != expected:No Category Fits
# prec (N=233) -- 0.5579399141630901
# coverage 0.48541666666666666
# ***
# kraus kitchen sink faucet oletto kpf 2820 sfs -- predicted:Kitchen & Tabletop != expected:Home Improvement
# prec (N=235) -- 0.5574468085106383
# coverage 0.4895833333333333
# ***
# full metal bed rose gold -- predicted:Furniture != expected:Baby & Kids
# prec (N=236) -- 0.5550847457627118
# coverage 0.49166666666666664
# ***
# biycicle plant stands -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=237) -- 0.5527426160337553
# coverage 0.49375
# ***
# patio design -- predicted:Outdoor != expected:No Category Fits
# prec (N=240) -- 0.5541666666666667
# coverage 0.5
# Skipping camper
# Skipping dinosaur
# ***
# gracie oaks 62 oller 14 ceiling fan -- predicted:Lighting != expected:No Category Fits
# prec (N=244) -- 0.5573770491803278
# coverage 0.5083333333333333
# ***
# mila task chair -- predicted:Furniture != expected:No Category Fits
# prec (N=245) -- 0.5551020408163265
# coverage 0.5104166666666666
# ***
# salon chair -- predicted:Commercial Business Furniture != expected:No Category Fits
# prec (N=250) -- 0.56
# coverage 0.5208333333333334
# Skipping 12v dirt bike
# ***
# pantry grey -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=252) -- 0.5595238095238095
# coverage 0.525
# ***
# lowes tile -- predicted:Home Improvement != expected:No Category Fits
# prec (N=253) -- 0.5573122529644269
# coverage 0.5270833333333333
# ***
# blue faux throw with pillows -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=254) -- 0.5551181102362205
# coverage 0.5291666666666667
# ***
# shoe bench entryway -- predicted:Furniture != expected:No Category Fits
# prec (N=255) -- 0.5529411764705883
# coverage 0.53125
# ***
# auburn throw pillows -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=256) -- 0.55078125
# coverage 0.5333333333333333
# ***
# high weight capacity bunk beds -- predicted:Furniture != expected:Baby & Kids
# prec (N=260) -- 0.5538461538461539
# coverage 0.5416666666666666
# ***
# china clock -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=266) -- 0.5601503759398496
# coverage 0.5541666666666667
# ***
# meade mirror -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=268) -- 0.5597014925373134
# coverage 0.5583333333333333
# Skipping monthly calendar
# Skipping 5 gang light switch
# ***
# platform bed side table -- predicted:Furniture != expected:No Category Fits
# prec (N=269) -- 0.5576208178438662
# coverage 0.5604166666666667
# ***
# brockham solid blackout thermal grommet curtain panels -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=270) -- 0.5555555555555556
# coverage 0.5625
# ***
# small ladies rocker swivel recliner -- predicted:Furniture != expected:No Category Fits
# prec (N=271) -- 0.5535055350553506
# coverage 0.5645833333333333
# ***
# filaret outdoor sofa -- predicted:Outdoor != expected:No Category Fits
# prec (N=272) -- 0.5514705882352942
# coverage 0.5666666666666667
# ***
# hardwood beds -- predicted:Furniture != expected:No Category Fits
# prec (N=273) -- 0.5494505494505495
# coverage 0.56875
# Skipping bee
# Skipping owl
# ***
# candace wingback upholstered bed -- predicted:Furniture != expected:No Category Fits
# prec (N=278) -- 0.5539568345323741
# coverage 0.5791666666666667
# ***
# westling coffee table -- predicted:Furniture != expected:No Category Fits
# prec (N=282) -- 0.5567375886524822
# coverage 0.5875
# Skipping coffee container
# Skipping drudge report
# Skipping alter furniture
# ***
# propane gas dryer -- predicted:Appliances != expected:No Category Fits
# prec (N=286) -- 0.5594405594405595
# coverage 0.5958333333333333
# ***
# moen 5995 arbor one -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=288) -- 0.5590277777777778
# coverage 0.6
# Skipping edge chair mat
# Skipping large bases
# ***
# twin over full bunk beds cool desins -- predicted:Furniture != expected:Baby & Kids
# prec (N=289) -- 0.5570934256055363
# coverage 0.6020833333333333
# ***
# kitchen islands with seating -- predicted:Kitchen & Tabletop != expected:Furniture
# prec (N=292) -- 0.5582191780821918
# coverage 0.6083333333333333
# Skipping minnestrista
# ***
# rack glass -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=293) -- 0.5563139931740614
# coverage 0.6104166666666667
# ***
# cream queen duvet cover -- predicted:Bed & Bath != expected:No Category Fits
# prec (N=294) -- 0.5544217687074829
# coverage 0.6125
# ***
# cushion replacement insert -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=295) -- 0.5525423728813559
# coverage 0.6145833333333334
# Skipping odum velvet
# Skipping indoor water fountain
# ***
# jordanna solid wood rocking -- predicted:Furniture != expected:Outdoor
# prec (N=297) -- 0.5521885521885522
# coverage 0.61875
# Skipping music plug wall plate
# ***
# mission double vanity -- predicted:Home Improvement != expected:No Category Fits
# prec (N=299) -- 0.5518394648829431
# coverage 0.6229166666666667
# ***
# pastel pink desk chair -- predicted:Furniture != expected:No Category Fits
# prec (N=300) -- 0.55
# coverage 0.625
# ***
# johan desk by laurel foundry -- predicted:Furniture != expected:No Category Fits
# prec (N=301) -- 0.5481727574750831
# coverage 0.6270833333333333
# ***
# door pulls bronze matte 4 inch -- predicted:Home Improvement != expected:No Category Fits
# prec (N=302) -- 0.5463576158940397
# coverage 0.6291666666666667
# ***
# outdoor light fixtures -- predicted:Outdoor != expected:Lighting
# prec (N=304) -- 0.5460526315789473
# coverage 0.6333333333333333
# Skipping white abstract
# Skipping gurney  slade 56
# ***
# togo chair -- predicted:Furniture != expected:No Category Fits
# prec (N=308) -- 0.5487012987012987
# coverage 0.6416666666666667
# Skipping lunch bag
# Skipping sinks bed frame
# ***
# body pillow case -- predicted:Décor & Pillows != expected:Bed & Bath
# prec (N=313) -- 0.5527156549520766
# coverage 0.6520833333333333
# ***
# sheffield home bath set -- predicted:Bed & Bath != expected:Home Improvement
# prec (N=315) -- 0.5523809523809524
# coverage 0.65625
# Skipping verden callan
# ***
# super bright lights -- predicted:Lighting != expected:No Category Fits
# prec (N=316) -- 0.5506329113924051
# coverage 0.6583333333333333
# ***
# nautical platters -- predicted:Kitchen & Tabletop != expected:No Category Fits
# prec (N=317) -- 0.5488958990536278
# coverage 0.6604166666666667
# Skipping sugar canister
# ***
# belchertown table lamp -- predicted:Lighting != expected:No Category Fits
# prec (N=326) -- 0.558282208588957
# coverage 0.6791666666666667
# ***
# bubble guppies chair -- predicted:Baby & Kids != expected:No Category Fits
# prec (N=328) -- 0.5579268292682927
# coverage 0.6833333333333333
# ***
# aloe vera plant pot -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=329) -- 0.5562310030395137
# coverage 0.6854166666666667
# Skipping amarillo
# ***
# flour and sugar containers -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=333) -- 0.5585585585585585
# coverage 0.69375
# ***
# elephant framed -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=336) -- 0.5595238095238095
# coverage 0.7
# ***
# wayfair coffee table -- predicted:Furniture != expected:No Category Fits
# prec (N=337) -- 0.5578635014836796
# coverage 0.7020833333333333
# Skipping meditation
# ***
# outdoor sectional doning -- predicted:Outdoor != expected:No Category Fits
# prec (N=338) -- 0.5562130177514792
# coverage 0.7041666666666667
# ***
# cliffside 5 light candle style drum chandelier -- predicted:Lighting != expected:No Category Fits
# prec (N=339) -- 0.5545722713864307
# coverage 0.70625
# ***
# laundry vanity cabinet -- predicted:Storage & Organization != expected:No Category Fits
# prec (N=341) -- 0.5542521994134897
# coverage 0.7104166666666667
# Skipping itchington butterfly
# ***
# olive green console table -- predicted:Furniture != expected:No Category Fits
# prec (N=342) -- 0.5526315789473685
# coverage 0.7125
# ***
# large cushion outdoor chair -- predicted:Outdoor != expected:No Category Fits
# prec (N=344) -- 0.5523255813953488
# coverage 0.7166666666666667
# Skipping delta trinsic
# Skipping flamingo
# ***
# delta trinsic double towel hook in champagne bronze -- predicted:Home Improvement != expected:No Category Fits
# prec (N=347) -- 0.553314121037464
# coverage 0.7229166666666667
# ***
# blk 18x18 seat cushions -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=350) -- 0.5542857142857143
# coverage 0.7291666666666666
# Skipping bohemian
# ***
# stainless steel free standing shower caddy -- predicted:Storage & Organization != expected:Home Improvement
# prec (N=356) -- 0.5589887640449438
# coverage 0.7416666666666667
# Skipping toilet paper stand
# ***
# town & country living curtains -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=358) -- 0.5586592178770949
# coverage 0.7458333333333333
# ***
# pull out sleeper loveseat -- predicted:Furniture != expected:No Category Fits
# prec (N=359) -- 0.5571030640668524
# coverage 0.7479166666666667
# Skipping dumbbells
# Skipping rattan truck
# ***
# wand bunk beds -- predicted:Furniture != expected:No Category Fits
# prec (N=365) -- 0.5616438356164384
# coverage 0.7604166666666666
# ***
# pennfield playhouse -- predicted:Baby & Kids != expected:
# prec (N=367) -- 0.5613079019073569
# coverage 0.7645833333333333
# ***
# moen matte black hooks -- predicted:Home Improvement != expected:No Category Fits
# prec (N=368) -- 0.5597826086956522
# coverage 0.7666666666666667
# ***
# kitchen anti fatigue mats -- predicted:Kitchen & Tabletop != expected:Rugs
# prec (N=370) -- 0.5594594594594594
# coverage 0.7708333333333334
# ***
# outdoor lounge cushions -- predicted:Outdoor != expected:
# prec (N=377) -- 0.5649867374005305
# coverage 0.7854166666666667
# ***
# osgood mirror -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=378) -- 0.5634920634920635
# coverage 0.7875
# ***
# sunflower -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=379) -- 0.5620052770448549
# coverage 0.7895833333333333
# ***
# mud room sign -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=380) -- 0.5605263157894737
# coverage 0.7916666666666666
# Skipping wood floor protector mat
# ***
# dorel vanity -- predicted:Furniture != expected:Home Improvement
# prec (N=385) -- 0.5636363636363636
# coverage 0.8020833333333334
# ***
# butcher block island -- predicted:Kitchen & Tabletop != expected:Furniture
# prec (N=387) -- 0.5633074935400517
# coverage 0.80625
# ***
# kohler whitehaven farmhouse kitchen sink -- predicted:Kitchen & Tabletop != expected:Home Improvement
# prec (N=388) -- 0.5618556701030928
# coverage 0.8083333333333333
# ***
# outdoor waterproof chest -- predicted:Outdoor != expected:Storage & Organization
# prec (N=390) -- 0.5615384615384615
# coverage 0.8125
# ***
# serta kleinmon -- predicted:Furniture != expected:Bed & Bath
# prec (N=393) -- 0.5623409669211196
# coverage 0.81875
# ***
# nesting tray set -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=400) -- 0.5675
# coverage 0.8333333333333334
# ***
# maryford queen tufted bed -- predicted:Furniture != expected:No Category Fits
# prec (N=401) -- 0.5660847880299252
# coverage 0.8354166666666667
# ***
# croscill ashton -- predicted:Décor & Pillows != expected:No Category Fits
# prec (N=405) -- 0.5679012345679012
# coverage 0.84375
# ***
# ottoman bed queen -- predicted:Furniture != expected:No Category Fits
# prec (N=406) -- 0.5665024630541872
# coverage 0.8458333333333333
# ***
# royal blue counter height chairs -- predicted:Furniture != expected:No Category Fits
# prec (N=408) -- 0.5661764705882353
# coverage 0.85
# Skipping penny round tile
# ***
# light wood nightstand with silver accents -- predicted:Furniture != expected:No Category Fits
# prec (N=410) -- 0.5658536585365853
# coverage 0.8541666666666666
# (0.5658536585365853, 0.8541666666666666)

# %% [markdown]
# ## Run Category search strategy with classifier
#
# Our search strategy here is identical, **however note** when the LLM does not predict a category / sub category we do not provide a boost.

# %%
from searcharray import SearchArray
from cheat_at_search.tokenizers import snowball_tokenizer
from cheat_at_search.strategy.strategy import SearchStrategy
import numpy as np


class CategorySearch(SearchStrategy):
    def __init__(self, products, query_to_cat,
                 name_boost=9.3,
                 description_boost=4.1,
                 category_boost=10,
                 sub_category_boost=5):
        super().__init__(products)
        self.index = products
        self.index['product_name_snowball'] = SearchArray.index(
            products['product_name'], snowball_tokenizer)
        self.index['product_description_snowball'] = SearchArray.index(
            products['product_description'], snowball_tokenizer)

        cat_split = products['category hierarchy'].fillna('').str.split("/")

        products['category'] = cat_split.apply(
            lambda x: x[0].strip() if len(x) > 0 else ""
        )
        products['subcategory'] = cat_split.apply(
            lambda x: x[1].strip() if len(x) > 1 else ""
        )
        self.index['category_snowball'] = SearchArray.index(
            products['category'], snowball_tokenizer
        )
        self.index['subcategory_snowball'] = SearchArray.index(
            products['subcategory'], snowball_tokenizer
        )

        self.query_to_cat = query_to_cat
        self.name_boost = name_boost
        self.description_boost = description_boost
        self.category_boost = category_boost
        self.sub_category_boost = sub_category_boost

    def search(self, query, k=10):
        """Dumb baseline lexical search, but add a constant boost when
           the desired category or subcategory"""
        bm25_scores = np.zeros(len(self.index))
        structured = self.query_to_cat(query)
        tokenized = snowball_tokenizer(query)

        # ****
        # Baseline BM25 search from before
        for token in tokenized:
            bm25_scores += self.index['product_name_snowball'].array.score(token) * self.name_boost
            bm25_scores += self.index['product_description_snowball'].array.score(
                token) * self.description_boost

        # ****
        # If there's a subcategory, boost that by a constant amount
        if structured.sub_category and structured.sub_category != "No SubCategory Fits":     # CHANGED -- CHECK IF WE MADE A PREDICTION
            tokenized_subcategory = snowball_tokenizer(structured.sub_category)
            subcategory_match = np.ones(len(self.index))
            if tokenized_subcategory:
                subcategory_match = self.index['subcategory_snowball'].array.score(tokenized_subcategory) > 0
            bm25_scores[subcategory_match] += self.sub_category_boost

        # ****
        # If there's a category, boost that by a constant amount
        if structured.category and structured.category != "No Category Fits":     #  CHANGED -- CHECK IF WE MADE A PREDICTION
            tokenized_category = snowball_tokenizer(structured.category)
            category_match = np.ones(len(self.index))
            if tokenized_category:
                category_match = self.index['category_snowball'].array.score(tokenized_category) > 0
            bm25_scores[category_match] += self.category_boost

        top_k = np.argsort(-bm25_scores)[:k]
        scores = bm25_scores[top_k]

        return top_k, scores

# %%
categorized_search = CategorySearch(products, categorized_with_unknown)
graded_categorized = run_strategy(categorized_search)
graded_categorized
# Out:
# 2025-10-13 17:19:43,063 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-10-13 17:19:43,089 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-10-13 17:19:43,093 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-10-13 17:19:44,400 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-10-13 17:19:45,698 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-10-13 17:19:46,556 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-10-13 17:19:47,426 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-10-13 17:19:47,788 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-10-13 17:19:47,804 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-10-13 17:19:47,821 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-10-13 17:19:47,897 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-10-13 17:19:48,008 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-10-13 17:19:48,014 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-10-13 17:19:48,079 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-10-13 17:19:48,163 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-10-13 17:19:48,210 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-10-13 17:19:48,226 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-10-13 17:19:51,430 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-10-13 17:19:54,336 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-10-13 17:19:55,872 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-10-13 17:19:57,159 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-10-13 17:19:58,005 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-10-13 17:19:58,043 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-10-13 17:19:58,079 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-10-13 17:19:58,925 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-10-13 17:19:59,267 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-10-13 17:19:59,270 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-10-13 17:19:59,602 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-10-13 17:20:00,259 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-10-13 17:20:00,271 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-10-13 17:20:00,275 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-10-13 17:20:00,602 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-10-13 17:20:00,809 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-10-13 17:20:00,986 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-10-13 17:20:01,191 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-10-13 17:20:01,352 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-10-13 17:20:01,355 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-10-13 17:20:01,361 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-10-13 17:20:01,372 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-10-13 17:20:01,381 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-10-13 17:20:01,382 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-10-13 17:20:01,404 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# 2025-10-13 17:20:01,416 - searcharray.indexing - INFO - Indexing begins w/ 4 workers
# INFO:searcharray.indexing:Indexing begins w/ 4 workers
# 2025-10-13 17:20:01,426 - searcharray.indexing - INFO - 0 Batch Start tokenization
# INFO:searcharray.indexing:0 Batch Start tokenization
# 2025-10-13 17:20:01,428 - searcharray.indexing - INFO - Tokenizing 42994 documents
# INFO:searcharray.indexing:Tokenizing 42994 documents
# 2025-10-13 17:20:01,648 - searcharray.indexing - INFO - Tokenized 10000 (23.259059403637718%)
# INFO:searcharray.indexing:Tokenized 10000 (23.259059403637718%)
# 2025-10-13 17:20:01,859 - searcharray.indexing - INFO - Tokenized 20000 (46.518118807275435%)
# INFO:searcharray.indexing:Tokenized 20000 (46.518118807275435%)
# 2025-10-13 17:20:02,065 - searcharray.indexing - INFO - Tokenized 30000 (69.77717821091315%)
# INFO:searcharray.indexing:Tokenized 30000 (69.77717821091315%)
# 2025-10-13 17:20:02,303 - searcharray.indexing - INFO - Tokenized 40000 (93.03623761455087%)
# INFO:searcharray.indexing:Tokenized 40000 (93.03623761455087%)
# 2025-10-13 17:20:02,471 - searcharray.indexing - INFO - Tokenization -- vstacking
# INFO:searcharray.indexing:Tokenization -- vstacking
# 2025-10-13 17:20:02,474 - searcharray.indexing - INFO - Tokenization -- DONE
# INFO:searcharray.indexing:Tokenization -- DONE
# 2025-10-13 17:20:02,478 - searcharray.indexing - INFO - Inverting docs->terms
# INFO:searcharray.indexing:Inverting docs->terms
# 2025-10-13 17:20:02,492 - searcharray.indexing - INFO - Encoding positions to bit array
# INFO:searcharray.indexing:Encoding positions to bit array
# 2025-10-13 17:20:02,502 - searcharray.indexing - INFO - Batch tokenization complete
# INFO:searcharray.indexing:Batch tokenization complete
# 2025-10-13 17:20:02,510 - searcharray.indexing - INFO - (main thread) Processing 1 batch results
# INFO:searcharray.indexing:(main thread) Processing 1 batch results
# 2025-10-13 17:20:02,533 - searcharray.indexing - INFO - Indexing from tokenization complete
# INFO:searcharray.indexing:Indexing from tokenization complete
# Searching: 100%|██████████| 480/480 [00:13<00:00, 36.28it/s]
#       product_id                                       product_name  \
# 0           7465                                   hair salon chair
# 1          25431                      barberpub salon massage chair
# 2           7468  mercer41 hair salon chair hydraulic styling ch...
# 3          39461         professional salon reclining massage chair
# 4           9234                            beauty salon task chair
# ...          ...                                                ...
# 4795       22194                                    wine glass rack
# 4796       40243                    madisen hanging wine glass rack
# 4797       40244                       kena hanging wine glass rack
# 4798       39976                       wall mounted wine glass rack
# 4799       40247                       winn hanging wine glass rack
#
#                  product_class  \
# 0     Massage Chairs|Recliners
# 1               Massage Chairs
# 2               Massage Chairs
# 3               Massage Chairs
# 4                          NaN
# ...                        ...
# 4795      Kitchen Sink Storage
# 4796                Wine Racks
# 4797                Wine Racks
# 4798                Wine Racks
# 4799                Wine Racks
#
#                                      category hierarchy  \
# 0     Furniture / Living Room Furniture / Chairs & S...
# 1     Furniture / Living Room Furniture / Chairs & S...
# 2     Furniture / Living Room Furniture / Chairs & S...
# 3     Furniture / Living Room Furniture / Chairs & S...
# 4          Furniture / Office Furniture / Office Chairs
# ...                                                 ...
# 4795  Kitchen & Tabletop / Kitchen Organization / Co...
# 4796  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4797  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4798  Kitchen & Tabletop / Tableware & Drinkware / B...
# 4799  Kitchen & Tabletop / Tableware & Drinkware / B...
#
#                                     product_description  \
# 0     offers a wide selection of professional salon ...
# 1     salon chairs are a wonderful avenue for hairst...
# 2     mercer41 beauty offers a wide selection profes...
# 3     new and in a good condition . first-rate metal...
# 4     applicable scene : office , home life , beauty...
# ...                                                 ...
# 4795  drip-dry up to eight wineglasses with this cle...
# 4796  complement your farmhouse kitchen decor with t...
# 4797  spruce up your farmhouse kitchen decor with th...
# 4798  the latest addition to this collection , this ...
# 4799  are you looking for a safe and decorative solu...
#
#                                        product_features  rating_count  \
# 0     fauxleathertype : pu|legheight-toptobottom:18|...          69.0
# 1     supplierintendedandapproveduse : non residenti...           4.0
# 2     seatfillmaterial : foam|waterrepellant : no re...           1.0
# 3     overalldepth-fronttoback:39.4|warrantylength:1...           NaN
# 4     overallheight-toptobottom:37|backcolor : brown...           NaN
# ...                                                 ...           ...
# 4795  glasscapacity:8|countryoforigin : united state...           5.0
# 4796  producttype : wine glass rack|overallwidth-sid...          29.0
# 4797  warrantylength:1 year|producttype : wine glass...          23.0
# 4798  overallheight-toptobottom:4|design : wall moun...          34.0
# 4799  overallheight-toptobottom:1.5|overallwidth-sid...         305.0
#
#       average_rating  review_count  \
# 0                4.5          53.0
# 1                5.0           4.0
# 2                5.0           1.0
# 3                NaN           NaN
# 4                NaN           NaN
# ...              ...           ...
# 4795             4.5           3.0
# 4796             5.0          20.0
# 4797             5.0          18.0
# 4798             4.5          18.0
# 4799             5.0         187.0
#
#                                                features  ... query_id rank  \
# 0     [fauxleathertype : pu, legheight-toptobottom:1...  ...        0    1
# 1     [supplierintendedandapproveduse : non resident...  ...        0    2
# 2     [seatfillmaterial : foam, waterrepellant : no ...  ...        0    3
# 3     [overalldepth-fronttoback:39.4, warrantylength...  ...        0    4
# 4     [overallheight-toptobottom:37, backcolor : bro...  ...        0    5
# ...                                                 ...  ...      ...  ...
# 4795  [glasscapacity:8, countryoforigin : united sta...  ...      487    6
# 4796  [producttype : wine glass rack, overallwidth-s...  ...      487    7
# 4797  [warrantylength:1 year, producttype : wine gla...  ...      487    8
# 4798  [overallheight-toptobottom:4, design : wall mo...  ...      487    9
# 4799  [overallheight-toptobottom:1.5, overallwidth-s...  ...      487   10
#
#          query_class     id    label grade  discounted_gain      idcg  \
# 0     Massage Chairs   80.0    Exact   2.0             3.00  8.786905
# 1     Massage Chairs   29.0    Exact   2.0             1.50  8.786905
# 2     Massage Chairs  104.0    Exact   2.0             1.00  8.786905
# 3     Massage Chairs  114.0    Exact   2.0             0.75  8.786905
# 4     Massage Chairs   32.0  Partial   1.0             0.20  8.786905
# ...              ...    ...      ...   ...              ...       ...
# 4795             NaN    NaN      NaN   0.0             0.00  8.786905
# 4796             NaN    NaN      NaN   0.0             0.00  8.786905
# 4797             NaN    NaN      NaN   0.0             0.00  8.786905
# 4798             NaN    NaN      NaN   0.0             0.00  8.786905
# 4799             NaN    NaN      NaN   0.0             0.00  8.786905
#
#           dcg      ndcg
# 0     8.10119  0.921962
# 1     8.10119  0.921962
# 2     8.10119  0.921962
# 3     8.10119  0.921962
# 4     8.10119  0.921962
# ...       ...       ...
# 4795  0.00000  0.000000
# 4796  0.00000  0.000000
# 4797  0.00000  0.000000
# 4798  0.00000  0.000000
# 4799  0.00000  0.000000
#
# [4800 rows x 26 columns]

# %% [markdown]
# ### Analyze results
#
# We note:
# 1. NDCG down a bit from earlier
# 2. Though fewer queries have been harmed

# %%
ndcgs(graded_bm25).mean(), ndcgs(graded_categorized).mean()
# Out:
# (np.float64(0.5411098691836396), np.float64(0.55962898357645))

# %%
deltas = ndcg_delta(graded_categorized, graded_bm25)
deltas
# Out:
# query
# bathroom freestanding cabinet    0.692589
# non slip shower floor tile       0.477081
# outdoor lounge chair             0.456442
# modern outdoor furniture         0.365533
# twin bed frame                   0.359391
#                                    ...
# whimsical solar lights          -0.142257
# outdoor welcome rug             -0.158244
# sheffield home bath set         -0.219708
# outdoor lounge cushions         -0.471391
# chair pillow cushion            -0.487874
# Name: ndcg, Length: 195, dtype: float64

# %%
sig_improved = len(deltas[deltas > 0.1])
print(f"Num Significatly Improved: {sig_improved}")
deltas[deltas > 0.1]
# Out:
# Num Significatly Improved: 38
# query
# bathroom freestanding cabinet                                      0.692589
# non slip shower floor tile                                         0.477081
# outdoor lounge chair                                               0.456442
# modern outdoor furniture                                           0.365533
# twin bed frame                                                     0.359391
# desk for kids                                                      0.344262
# wood rack wide                                                     0.335320
# outdoor light fixtures                                             0.311069
# turquoise chair                                                    0.298334
# bedroom accessories                                                0.280721
# dining table vinyl cloth                                           0.254573
# accent leather chair                                               0.248882
# glass doors for bath                                               0.244140
# ayesha curry kitchen                                               0.243689
# storage dresser                                                    0.236147
# hardwood beds                                                      0.235334
# wooden chair outdoor                                               0.200063
# china clock                                                        0.189044
# beds that have leds                                                0.186289
# family lamp                                                        0.178612
# dark gray dresser                                                  0.175902
# bathroom lighting                                                  0.167547
# carpet 5x6                                                         0.158831
# town & country living curtains                                     0.154089
# driftwood mirror                                                   0.151199
# oriental vanity                                                    0.149347
# acrylic clear chair                                                0.142257
# above toilet cabinet                                               0.138238
# closet storage with zipper                                         0.138193
# bedroom wall decor floral, multicolored with some teal (prints)    0.136883
# light and navy blue decorative pillow                              0.124690
# auburn throw pillows                                               0.122341
# medium size chandelier                                             0.119812
# foutains with brick look                                           0.118683
# small wardrobe grey                                                0.113806
# industrial pipe dining  table                                      0.110419
# midcentury tv unit                                                 0.102425
# floating bed                                                       0.101928
# Name: ndcg, dtype: float64

# %%
sig_harmed = len(deltas[deltas < -0.1])
print(f"Num Significatly Harmed: {sig_harmed}")
print(f"Prop improved/harmed: {sig_improved / (sig_harmed + sig_improved)} | {sig_harmed / (sig_harmed + sig_improved)}")
deltas[deltas < -0.1]
# Out:
# Num Significatly Harmed: 8
# Prop improved/harmed: 0.8260869565217391 | 0.17391304347826086
# query
# zodiac pillow              -0.113806
# papasan chair frame only   -0.123290
# tall storage cabinet       -0.127715
# whimsical solar lights     -0.142257
# outdoor welcome rug        -0.158244
# sheffield home bath set    -0.219708
# outdoor lounge cushions    -0.471391
# chair pillow cushion       -0.487874
# Name: ndcg, dtype: float64

# %% [markdown]
# ### Analyze a query
#
# Let's look at a negative query to see how its harmed.

# %%
QUERY = "chair pillow cushion"
graded_bm25[graded_bm25['query'] == QUERY][['product_name', 'product_description', 'category hierarchy', 'grade']]
# Out:
#                                            product_name  \
# 4660   replacement pillows outdoor lounge chair cushion
# 4661  indoor/outdoor dining chair cushion and pillow...
# 4662                   abbottsmoor dining chair cushion
# 4663                     zipparoll indoor chair cushion
# 4664                               indoor chair cushion
# 4665                                  chair pad cushion
# 4666                          chair indoor seat cushion
# 4667                         chair outdoor seat cushion
# 4668                               dining chair cushion
# 4669              tropical outdoor lounge chair cushion
#
#                                     product_description  \
# 4660  this replacement pillows outdoor lounge chair ...
# 4661  go bold and spicy with a fun geometric print o...
# 4662  the dining chair cushion ( set of 4 ) is apt f...
# 4663  zips from round pillow to flat pillow . the zi...
# 4664  brighten your indoor seating area with this se...
# 4665  are your dining chair ’ s feeling a little sti...
# 4666  add a splash of vibrant color and radiant styl...
# 4667  add a splash of vibrant color and radiant styl...
# 4668  add a splash of personality and create a cozy ...
# 4669  enhance your outdoor space with the addition o...
#
#                                      category hierarchy  grade
# 4660                                                NaN    2.0
# 4661  Outdoor / Outdoor Décor / Outdoor Pillows & Cu...    2.0
# 4662                                                NaN    2.0
# 4663  Kitchen & Tabletop / Tableware & Drinkware / T...    2.0
# 4664                                                NaN    2.0
# 4665                                                NaN    2.0
# 4666                                                NaN    2.0
# 4667                                                NaN    2.0
# 4668  Kitchen & Tabletop / Tableware & Drinkware / T...    2.0
# 4669                                                NaN    2.0

# %%
graded_categorized[graded_categorized['query'] == QUERY][['product_name', 'product_description', 'category hierarchy', 'grade']]
# Out:
#                                            product_name  \
# 4660   replacement pillows outdoor lounge chair cushion
# 4661  indoor/outdoor dining chair cushion and pillow...
# 4662                               peacock throw pillow
# 4663                          two ocztopus throw pillow
# 4664                         cancer zodiac throw pillow
# 4665                     velvet ikat 3 '' lumbar pillow
# 4666                            finesse ii throw pillow
# 4667                                  navy throw pillow
# 4668                   marble petroleum ii throw pillow
# 4669                                marble throw pillow
#
#                                     product_description  \
# 4660  this replacement pillows outdoor lounge chair ...
# 4661  go bold and spicy with a fun geometric print o...
# 4662  decorative pillow – designed by suren nersisya...
# 4663  decorative pillow – designed by suren nersisya...
# 4664  decorative pillow – designed by emanuela carra...
# 4665  bring the world to your sofa with this pillow ...
# 4666  this decorative pillow is designed by pi creat...
# 4667  solid navy decorative accent throw pillows fro...
# 4668  decorative pillow – designed by pi creative ar...
# 4669  black and white marble collection decorative a...
#
#                                      category hierarchy  grade
# 4660                                                NaN    2.0
# 4661  Outdoor / Outdoor Décor / Outdoor Pillows & Cu...    2.0
# 4662  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4663  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4664  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4665  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4666  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4667  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4668  Décor & Pillows / Decorative Pillows & Blanket...    0.0
# 4669  Décor & Pillows / Decorative Pillows & Blanket...    0.0

# %%
categorized_with_unknown(QUERY)
# Out:
# QueryCategoryWithUnknown(keywords='chair pillow cushion', category='Décor & Pillows', sub_category='Decorative Pillows & Blankets')

# %% [markdown]
# ### Analyze Ground Truth for important queries
#
# It's a bit surprising given higher precision in our classifier, NDCG would not improve.
#
# Let's focus in on the relevant queries to see how they're impacted.

# %%
impacted_queries = [
 'drum picture',
 'bathroom freestanding cabinet',
 'outdoor lounge chair',
 'wood rack wide',
 'outdoor light fixtures',
 'bathroom vanity knobs',
 'door jewelry organizer',
 'beds that have leds',
 'non slip shower floor tile',
 'turquoise chair',
 'modern outdoor furniture',
 'podium with locking cabinet',
 'closet storage with zipper',
 'barstool patio sets',
 'ayesha curry kitchen',
 'led 60',
 'wisdom stone river 3-3/4',
 'liberty hardware francisco',
 'french molding',
 'glass doors for bath',
 'accent leather chair',
 'dark gray dresser',
 'wainscoting ideas',
 'floating bed',
 'dining table vinyl cloth',
 'entrance table',
 'storage dresser',
 'almost heaven sauna',
 'toddler couch fold out',
 'outdoor welcome rug',
 'wooden chair outdoor',
 'emma headboard',
 'outdoor privacy wall',
 'driftwood mirror',
 'white abstract',
 'bedroom accessories',
 'bathroom lighting',
 'light and navy blue decorative pillow',
 'gnome fairy garden',
 'medium size chandelier',
 'above toilet cabinet',
 'odum velvet',
 'ruckus chair',
 'modern farmhouse lighting semi flush mount',
 'teal chair',
 'bedroom wall decor floral, multicolored with some teal (prints)',
 'big basket for dirty cloths',
 'milk cow chair',
 'small wardrobe grey',
 'glow in the dark silent wall clock',
 'medium clips',
 'desk for kids tjat ate 10 year old',
 'industrial pipe dining  table',
 'itchington butterfly',
 'midcentury tv unit',
 'gas detector',
 'fleur de lis living candle wall sconce bronze',
 'zodiac pillow',
 'papasan chair frame only',
 'bed side table']
prec, coverage = prec_cat(ground_truth_cat[ground_truth_cat['query'].isin(impacted_queries)],
                              'category', 'No Category Fits', categorized_with_unknown, N=500)
prec
# Out:
# Skipping milk cow chair
# ***
# podium with locking cabinet -- predicted:Commercial Business Furniture != expected:School Furniture and Supplies
# prec (N=2) -- 0.5
# coverage 0.03333333333333333
# Skipping french molding
# Skipping liberty hardware francisco
# Skipping ruckus chair
# ***
# emma headboard -- predicted:Furniture != expected:Baby & Kids
# prec (N=6) -- 0.6666666666666666
# coverage 0.1
# Skipping wisdom stone river 3-3/4
# Skipping itchington butterfly
# ***
# door jewelry organizer -- predicted:Storage & Organization != expected:Furniture
# prec (N=11) -- 0.7272727272727273
# coverage 0.18333333333333332
# ***
# gnome fairy garden -- predicted:Décor & Pillows != expected:Outdoor
# prec (N=19) -- 0.7894736842105263
# coverage 0.31666666666666665
# Skipping white abstract
# Skipping odum velvet
# ***
# outdoor welcome rug -- predicted:Outdoor != expected:Rugs
# prec (N=22) -- 0.7727272727272727
# coverage 0.36666666666666664
# Skipping wainscoting ideas
# Skipping gas detector
# ***
# outdoor light fixtures -- predicted:Outdoor != expected:Lighting
# prec (N=30) -- 0.8
# coverage 0.5
# 0.88
